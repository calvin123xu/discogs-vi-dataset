# %% [markdown]
# 90% of Da-TACOS cliques found in Discogs-VI
#
# 91% of SHS100K cliques found in Discogs-VI

# %%
import os
import sys
import csv
import json
from collections import defaultdict

import numpy as np

PROJECT_DIR = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(PROJECT_DIR)

from utilities.utils import soft_clean_text, hard_clean_text, clean_parentheses, collect_writer_artists, collect_performance_artists

DATA_DIR = os.path.join(PROJECT_DIR, "data")
METADATA_DIR = os.path.join(DATA_DIR, "discogs_metadata")

# %%
# NOTE: My goal was to load these existing methods and variables but relative imports etc. were difficult to handle
# from discogs_vi.parse_releases_to_tracks import remove_disogs_pattern
# from discogs_vi.variables import EXCLUDE_ARTISTS
# from discogs_vi_yt.query_yt.utils_query import get_youtube_id

import re
def remove_disogs_pattern(artist):
    """Removes the Discogs pattern from the artist name. 'Oguz (3)' type of Discogs convention"""
    return re.sub(r"\s\(\d+?\)", "", artist)

VARIOUS = "194"
UNKNOWN = "355"
NO_ARTIST = "118760"
ARTIST_WITHOUT_PAGE = '0'

EXCLUDE_ARTISTS = {VARIOUS, UNKNOWN, NO_ARTIST, ARTIST_WITHOUT_PAGE}

def get_youtube_id(url):
    return url.split("/watch?v=")[1]

# %%
dump_date = "20240701"

use_discogs_vi = True # If false use discogs_vi_yt

# %%
dump_name = f"discogs_{dump_date}"

dump_dir = os.path.join(METADATA_DIR, dump_name)
print(os.path.abspath(dump_dir))

artists_json = os.path.join(dump_dir, f"{dump_name}_artists.xml.json.clean")

discogs_vi_json = os.path.join(dump_dir, f"Discogs-VI-{dump_date}.jsonl")
discogs_vi_yt_json = os.path.join(dump_dir, f"Discogs-VI-YT-{dump_date}.jsonl")

datacos_benchmark_json_path = os.path.join(DATA_DIR, "other_datasets", 'da-tacos_benchmark_subset_metadata.json')
shs100k_csv_path = os.path.join(DATA_DIR, "other_datasets", 'SHS100K2', 'meta', 'list')
shs100k_train_csv_path = os.path.join(DATA_DIR, "other_datasets", 'SHS100K2', 'meta', 'SHS100K-TRAIN')
shs100k_test_csv_path = os.path.join(DATA_DIR, "other_datasets", 'SHS100K2', 'meta', 'SHS100K-TEST')
shs100k_val_csv_path = os.path.join(DATA_DIR, "other_datasets", 'SHS100K2', 'meta', 'SHS100K-VAL')

shs100k_test_cliques_json_path = os.path.join(DATA_DIR, "other_datasets", 'SHS100K2-TEST-cliques.json')

if use_discogs_vi:
    discogs_json = discogs_vi_json
    output_txt = os.path.join(dump_dir, f'Discogs-VI-{dump_date}-DaTACOS-SHS100K2_TEST-lost_cliques.txt')
else:
    discogs_json = discogs_vi_yt_json
    output_txt = os.path.join(dump_dir, f'Discogs-VI-YT-{dump_date}-DaTACOS-SHS100K2_TEST-lost_cliques.txt')
# Out:
# /home/oaraz/discotube-dataset/data/discogs_metadata/discogs_20240701

# %% [markdown]
# ## Discogs-VI-YT
#
# Here we gather detailed track artist and writer artist information from the discogs metadata and store them in a clique related dict. We use discogs_vi_yt_json for simplicity.

# %%
# Load the artists data
artists_dict = {}
with open(artists_json, encoding='utf-8') as infile:
    for jsonline in infile:
        artist = json.loads(jsonline)
        if artist['name'] is not None:
            artist['name'] = soft_clean_text(remove_disogs_pattern(artist['name']))
        artists_dict[artist["id"]] = artist
        del artists_dict[artist["id"]]["id"]

# %%
discogs_cliques = defaultdict(list)
discogs_clique_sizes = dict()
with open(discogs_json, encoding='utf-8') as in_f:
    for jline in in_f:
        clique = json.loads(jline)

        # Record the clique sizes for saving time
        discogs_clique_sizes[clique['clique_id']] = len(clique['versions'])

        # For Da-TACOS we do not use the versions but for SHS100K we have to
        versions = []

        # Collect all the writers of the work. Since between the versions of a clique, 
        # the writers of the work might not be exactly the same
        work_writers = set()
        for version in clique['versions']:

            # Collect all the performers of the work. Since between the versions of a clique,
            # the performers of the work might not be exactly the same
            performer_artists = set()
            for track in version['tracks']:

                # Get all the writer artists of the track
                writer_ids = collect_writer_artists(track, artists_dict)
                # Skip the version if it has any of the excluded artists
                if writer_ids & EXCLUDE_ARTISTS:
                    continue
                # Get the names of the writer artists
                work_writers.update(
                    {artists_dict[artist_id]['name'] for artist_id in writer_ids if artist_id in artists_dict}
                    )

                # Get the title of the track. This can change between the tracks of a 
                # version but we do not use this information
                t_title = soft_clean_text(track['track_title'])

                # Get all the performer artists of the track
                t_artist_ids = collect_performance_artists(track, artists_dict)
                # Get the names of the artists
                t_artist_names = {
                    artists_dict[artist_id]['name'] for artist_id in t_artist_ids if artist_id in artists_dict
                    }
                performer_artists.update(t_artist_names)

            # A version in this case is the title of the track and the performer artists
            versions.append((t_title, performer_artists))

        # All the members of the clique share the same track_title_cleaned
        discogs_cliques[track['track_title_cleaned']].append({
            'work_writer': work_writers, 
            'clique_id': clique['clique_id'],
            'versions': versions
            })

# %% [markdown]
# ## Da-TACOS Benchmark
#
# Here we analyze the datacos benchmark dataset and compare it with Discogs-VI.

# %%
# Load the datacos benchmark json file
with open(datacos_benchmark_json_path) as f:
    benchmark_json = json.load(f)

# %%
# Format the metadata and collect the datacos info
datacos_info = []
for work_id, performances_dict in benchmark_json.items():
    # Differencing between the noise and clique performances
    if len(performances_dict) == 1:
        _type = 'noise'
    else:
        _type = 'clique'

    titles = set()
    for performance_id, performance in performances_dict.items():
        work_title = hard_clean_text(clean_parentheses(performance['work_title']))
        performance_title = hard_clean_text(clean_parentheses(performance['perf_title']))
        # Add both the work title and the performance title
        titles.add(work_title)
        titles.add(performance_title)
    work_artist = soft_clean_text(performance['work_artist'])
    # Each work artist has a single name but the performance can have multiple artists and names
    datacos_info.append((titles, work_artist, _type, work_id))

# %%
datacos_matched_cliques_ids, datacos_matched_noise_cliques_ids = set(), set()
datacos_matched_work_ids, datacos_matched_noise_work_ids = set(), set()

# Iterate over the datacos works and find the matching Discogs-VI cliques
for datacos_work_titles, datacos_work_writer, _type, work_id in datacos_info:
    # Compare each work title with the Discogs-VI cliques
    for datacos_work_title in datacos_work_titles:
        # There can be multiple cliques in dicsogs with the same title
        for discogs_clique in discogs_cliques.get(datacos_work_title, []):
            # Check if the work writer is in the clique
            if datacos_work_writer in discogs_clique['work_writer']:
                # Seperate into noise and music works
                if _type == 'noise':
                    datacos_matched_noise_cliques_ids.add(discogs_clique['clique_id'])
                    datacos_matched_noise_work_ids.add(work_id)
                else:
                    datacos_matched_cliques_ids.add(discogs_clique['clique_id'])
                    datacos_matched_work_ids.add(work_id)

print(f'{len(datacos_matched_work_ids):>5,} Datacos works are matched to Discogs-VI-YT cliques.')
print(f'{len(datacos_matched_noise_work_ids):>5,} Datacos noise works are matched to Discogs-VI-YT cliques.')

print()
print(f'{len(datacos_matched_cliques_ids):>5,} Discogs-VI-YT cliques are matched with Datacos works.')
print(f'{len(datacos_matched_noise_cliques_ids):>5,} Discogs-VI-YT cliques are matched with Datacos noise works.')

datacos_matched_cliques_ids = set(datacos_matched_cliques_ids)
datacos_matched_noise_cliques_ids = set(datacos_matched_noise_cliques_ids)

all_datacos_matched_clique_ids = datacos_matched_cliques_ids | datacos_matched_noise_cliques_ids
print(f'{len(all_datacos_matched_clique_ids):>5,} Discogs-VI-YT cliques are matched with Datacos works and noise works.')
# Out:
#   935 Datacos works are matched to DiscogsVI-YT cliques.
# 1,412 Datacos noise works are matched to DiscogsVI-YT cliques.
#
# 1,231 DiscogsVI-YT cliques are matched with Datacos works.
# 1,472 DiscogsVI-YT cliques are matched with Datacos noise works.
# 2,703 DiscogsVI-YT cliques are matched with Datacos works and noise works.

# %%
datacos_lost_versions = 0
for clique_id in datacos_matched_cliques_ids:
    datacos_lost_versions += discogs_clique_sizes[clique_id]
print(f"{datacos_lost_versions:>5,} versions are lost to the real works of Da-TACOS benchmark subset.")

datacos_noise_lost_versions = 0
for clique_id in datacos_matched_noise_cliques_ids:
    datacos_noise_lost_versions += discogs_clique_sizes[clique_id]
print(f"{datacos_noise_lost_versions:>5,} versions are lost to the noise works of Da-TACOS benchmark subset.")
# Out:
# 195,743 versions are lost to the real works of Da-TACOS benchmark subset.
# 30,190 versions are lost to the noise works of Da-TACOS benchmark subset.

# %% [markdown]
# ## SHS100K-TEST
#
# Here we find the intersection between SHS100K-Test with Discogs-VI-YT

# %%
# Read the csv file it is tab separated
with open(shs100k_csv_path, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    shs100k_data = list(reader)

shs100K_dict = dict()
for row in shs100k_data:
    if row[0] not in shs100K_dict:
        shs100K_dict[row[0]] = [row[1]]
    else:
        shs100K_dict[row[0]].append(row[1])
SHS100K_clique_sizes = [len(v) for v in shs100K_dict.values()]
print(sum(SHS100K_clique_sizes)/len(SHS100K_clique_sizes))
print(max(SHS100K_clique_sizes))
print(np.median(SHS100K_clique_sizes))

with open(shs100k_test_csv_path, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    shs100k_test_indices = list(reader)
print(f'{len(set([int(i[0]) for i in shs100k_test_indices])):>6,} SHS100K2-TEST cliques are used.')
print(f'{len(shs100k_test_indices):>6,} SHS100K2-TEST versions are used.')
# Out:
# 12.432204295330697
# 387
# 8.0
#  1,692 SHS100K2-TEST cliques are used.
# 10,547 SHS100K2-TEST versions are used.

# %%
# Seperate the test data
shs100k_test_data = []
for row_i in shs100k_test_indices:
    for row_j in shs100k_data:
        if row_i[0] == row_j[0] and row_i[1] == row_j[1]:
            shs100k_test_data.append(row_j)
            break
assert len(shs100k_test_data) == len(shs100k_test_indices)

# Create a clique data structure for the test data
shs_test_cliques = dict()
for i, (clique_id, version_id, _, _, url, _) in enumerate(shs100k_test_data):
    yt_id = get_youtube_id(url)
    dct = {'version_id': version_id, 'youtube_id': yt_id}
    if clique_id not in shs_test_cliques:
        shs_test_cliques[clique_id] = [dct]
    else:
        shs_test_cliques[clique_id].append(dct)

# Format the test data
shs100k_test_dict = {}
for row in shs100k_test_data:
    clique_id = row[0]
    title = hard_clean_text(clean_parentheses(row[2]))
    artist = soft_clean_text(row[3])
    if clique_id in shs100k_test_dict:
        shs100k_test_dict[clique_id][0].add(title)
        shs100k_test_dict[clique_id][1].add(artist)
    else:
        shs100k_test_dict[clique_id] = [{title}, {artist}]

# %%
# Match the SHS100K2 test data with the Discogs-VI cliques
shs_matched_clique_ids, discogs_matched_shs_clique_ids = set(), set()
for shs_clique_id, (shs_titles, shs_artists) in shs100k_test_dict.items():
    for shs_title in shs_titles:
        for discogs_clique in discogs_cliques.get(shs_title, []):
            # Compare each SHS artist
            for shs_artist in shs_artists:
                # With each Discogs version's artists
                for _, discogs_artists in discogs_clique['versions']:
                    if shs_artist in discogs_artists:
                        shs_matched_clique_ids.add(discogs_clique['clique_id'])
                        discogs_matched_shs_clique_ids.add(shs_clique_id)
print(f'{len(discogs_matched_shs_clique_ids):<5,} SHS100K2-TEST cliques are matched with Discogs-VI-YT cliques')
print(f'{len(shs_matched_clique_ids):<5,} Discogs-VI-YT cliques are matched with SHS100K2-TEST cliques')
# Out:
# 1,555 SHS100K2-TEST cliques are matched with DiscogsVI-YT cliques
# 1,996 DiscogsVI-YT cliques are matched with SHS100K2-TEST cliques

# %%
shs100k_lost_versions = 0
for clique_id in shs_matched_clique_ids:
    shs100k_lost_versions += discogs_clique_sizes[clique_id]
print(f"{shs100k_lost_versions:>5,} versions in Discogs-VI-YT are lost to the SHS100K2-TEST..")
# Out:
# 50,258 versions in DiscogsVI-YT are lost to the SHS100K2-TEST..

# %% [markdown]
# ## Merge Da-TACOS and SHS100K

# %%
all_lost_clique_ids = set(shs_matched_clique_ids).union(set(all_datacos_matched_clique_ids))
print(f"{len(all_lost_clique_ids):>6,} cliques are lost to the SHS100K2-TEST set and Da-TACOS benchmark subset in total.")

all_lost_versions = 0
for clique_id in all_lost_clique_ids:
    all_lost_versions += discogs_clique_sizes[clique_id]
print(f"{all_lost_versions:>6,} versions in Discogs-VI-YT are lost to the SHS100K2-TEST and Da-TACOS benchmark sets in total.")

print(f'Writing the lost clique IDs to {output_txt}')
with open(output_txt, 'w') as out_f:
    for clique_id in all_lost_clique_ids:
        out_f.write(clique_id+'\n')
# Out:
#  4,557 cliques are lost to the SHS100K2-TEST set and Da-TACOS benchmark subset in total.
# 264,566 versions in DiscogsVI-YT are lost to the SHS100K2-TEST and Da-TACOS benchmark sets in total.
# Writing the lost clique IDs to /home/oaraz/discotube-dataset/data/discogs_metadata/discogs_20240701/DiscogsVI-20240701-DaTACOS-SHS100K2_TEST-lost_cliques.txt

# %%
all_lost_versions_list = []
with open(discogs_json, encoding='utf-8') as in_f:
    for jline in in_f:
        clique = json.loads(jline)
        if clique['clique_id'] in all_lost_clique_ids:
            all_lost_versions_list.append(len(clique['versions']))
print()
print(np.mean(all_lost_versions_list))
print(np.median(all_lost_versions_list))
print(np.max(all_lost_versions_list))
print(np.min(all_lost_versions_list))
# Out:
# 58.05705508009655
# 16.0
# 1837
# 2

# %% [markdown]
# ## Format for testing

# %%
# Seperate the test data
shs100k_test_data = []
for row_i in shs100k_test_indices:
    for row_j in shs100k_data:
        if row_i[0] == row_j[0] and row_i[1] == row_j[1]:
            shs100k_test_data.append(row_j)
            break
assert len(shs100k_test_data) == len(shs100k_test_indices)

# %%
# Create a clique data structure for the test data
shs_test_cliques = dict()
for i, (clique_id, version_id, _, _, url, _) in enumerate(shs100k_test_data):
    yt_id = get_youtube_id(url)
    dct = {'version_id': version_id, 'youtube_id': yt_id}
    if clique_id not in shs_test_cliques:
        shs_test_cliques[clique_id] = [dct]
    else:
        shs_test_cliques[clique_id].append(dct)

# %%
shs_test_cliques
# Out:
# {'8110': [{'version_id': '0', 'youtube_id': 'pesIGuV9DDk'},
#   {'version_id': '1', 'youtube_id': '6vZyiOsOAOY'},
#   {'version_id': '2', 'youtube_id': 'cZPdr5MY6Gw'},
#   {'version_id': '3', 'youtube_id': 'VCjeTJu-tfY'},
#   {'version_id': '4', 'youtube_id': 'AcDmo4yTDHE'}],
#  '8112': [{'version_id': '0', 'youtube_id': 'eq7jlJyz8-8'},
#   {'version_id': '1', 'youtube_id': 'lMCKULtrRRA'},
#   {'version_id': '2', 'youtube_id': 'xADupK4xL-Y'},
#   {'version_id': '3', 'youtube_id': 'R8A8WgMcVqg'},
#   {'version_id': '4', 'youtube_id': 'S4St3Jk1u9M'}],
#  '8113': [{'version_id': '0', 'youtube_id': '40bTOCv3_ak'},
#   {'version_id': '1', 'youtube_id': 'T_V0S-7Modw'},
#   {'version_id': '2', 'youtube_id': '1mlY7djK-hU'},
#   {'version_id': '3', 'youtube_id': 'WEnC3fyDVWw'},
#   {'version_id': '4', 'youtube_id': 'ksBGApo0UvI'},
#   {'version_id': '5', 'youtube_id': '-blXxtQQvWs'},
#   {'version_id': '6', 'youtube_id': '2Vh3noCDx5E'},
#   {'version_id': '7', 'youtube_id': 'Um8nXe-ZRCE'},
#   {'version_id': '8', 'youtube_id': '1LNEr0EgPcU'}],
#  '8115': [{'version_id': '0', 'youtube_id': 'sYmnJ--sAnk'},
#   {'version_id': '1', 'youtube_id': 'dghe_d8qVC0'}],
#  '8117': [{'version_id': '0', 'youtube_id': 'GRz4FY0ZcwI'},
#   {'version_id': '3', 'youtube_id': 'rnG_5BzuweY'},
#   {'version_id': '4', 'youtube_id': 'Bw3tYiAFVfg'},
#   {'version_id': '6', 'youtube_id': 'ixOj_83IkEQ'},
#   {'version_id': '7', 'youtube_id': 'hIli-iCndyM'}],
#  '8119': [{'version_id': '0', 'youtube_id': '4C2K889u_90'},
#   {'version_id': '1', 'youtube_id': 'UluwAZOW0ok'},
#   {'version_id': '3', 'youtube_id': 'IoECO-HOiZc'},
#   {'version_id': '4', 'youtube_id': 'kQFKaNvH7tE'},
#   {'version_id': '5', 'youtube_id': 'OQOLIVizkbk'},
#   {'version_id': '6', 'youtube_id': 'Xk9wWj8Wh30'}],
#  '8120': [{'version_id': '0', 'youtube_id': 'NjMl1tjXJNQ'},
#   {'version_id': '1', 'youtube_id': 'Vj17TYGSi58'},
#   {'version_id': '2', 'youtube_id': 'BT6G0O6mgww'}],
#  '8122': [{'version_id': '0', 'youtube_id': 'N2wmRi100Wg'},
#   {'version_id': '1', 'youtube_id': 'HLQt3Jg-aWA'},
#   {'version_id': '2', 'youtube_id': 'FCWfJrkumZM'},
#   {'version_id': '4', 'youtube_id': 'K9AyNN3CKMs'},
#   {'version_id': '5', 'youtube_id': 't1I9a4fKwlg'}],
#  '8123': [{'version_id': '0', 'youtube_id': 'wOUSNVTHoAI'},
#   {'version_id': '1', 'youtube_id': 'UJNOwErzDPQ'},
#   {'version_id': '2', 'youtube_id': '5lY6SSLPgwM'}],
#  '8124': [{'version_id': '0', 'youtube_id': 'y9Mse62NFl4'},
#   {'version_id': '1', 'youtube_id': 'JSx2H10WJec'},
#   {'version_id': '2', 'youtube_id': 'NEeZK9j0AQU'},
#   {'version_id': '3', 'youtube_id': 'n5L3i4nXbFY'},
#   {'version_id': '4', 'youtube_id': 'MH-WPWnSxZc'}],
#  '8125': [{'version_id': '0', 'youtube_id': 'FG3ib9t-bnQ'},
#   {'version_id': '1', 'youtube_id': 'FCeN6Pj4TI0'},
#   {'version_id': '2', 'youtube_id': 'YcOYWaXwUQM'}],
#  '8126': [{'version_id': '0', 'youtube_id': 'JLmMsQsp5ZM'},
#   {'version_id': '1', 'youtube_id': '-v42pkodIlw'},
#   {'version_id': '2', 'youtube_id': 'aZe1fcYLwBg'},
#   {'version_id': '3', 'youtube_id': 'dy5fm4gxq-s'},
#   {'version_id': '4', 'youtube_id': '7ZIYtCwDuwE'},
#   {'version_id': '5', 'youtube_id': 'WAcx5iUyeWY'},
#   {'version_id': '6', 'youtube_id': 'G5KRO3OQelw'},
#   {'version_id': '7', 'youtube_id': '9Wlr07_b3VI'},
#   {'version_id': '8', 'youtube_id': 'lL2IxuUKZ-c'},
#   {'version_id': '11', 'youtube_id': 'TxusXnen8-Q'}],
#  '8127': [{'version_id': '0', 'youtube_id': 'swZZ94yAc7g'},
#   {'version_id': '1', 'youtube_id': 'cLNTQHTt4Es'},
#   {'version_id': '2', 'youtube_id': 'UiMSfTyytQE'},
#   {'version_id': '3', 'youtube_id': 'Mguq7u6MsUs'},
#   {'version_id': '4', 'youtube_id': 'PiELvMgIeZc'},
#   {'version_id': '5', 'youtube_id': '_iBjSSUxxiM'},
#   {'version_id': '6', 'youtube_id': '54PpM4o5D7w'},
#   {'version_id': '7', 'youtube_id': 'vSt_vpvJrvU'},
#   {'version_id': '8', 'youtube_id': '-Qwv7QYYnY8'}],
#  '8128': [{'version_id': '0', 'youtube_id': 'i4ODuHjbSTw'},
#   {'version_id': '1', 'youtube_id': 'Dw6gmLag3TQ'},
#   {'version_id': '2', 'youtube_id': '6H-OD6CFoDI'}],
#  '8129': [{'version_id': '0', 'youtube_id': 'yzuLCUL3C3s'},
#   {'version_id': '1', 'youtube_id': 'nzDRWWfQLXg'},
#   {'version_id': '2', 'youtube_id': 'upcdjSgPTPE'},
#   {'version_id': '3', 'youtube_id': 'wGiLICe0kL4'}],
#  '8131': [{'version_id': '0', 'youtube_id': 'DPzNkxFNWDk'},
#   {'version_id': '2', 'youtube_id': 'MQf58hrYFi0'},
#   {'version_id': '3', 'youtube_id': 'm5hhFT-88DY'}],
#  '8132': [{'version_id': '0', 'youtube_id': 'HG_426jnh_M'},
#   {'version_id': '1', 'youtube_id': 'HG_426jnh_M'},
#   {'version_id': '2', 'youtube_id': 'qWUxsEoWEZE'}],
#  '8133': [{'version_id': '0', 'youtube_id': '7cKPchRDaVM'},
#   {'version_id': '1', 'youtube_id': 'GNLSbkAo2LU'},
#   {'version_id': '2', 'youtube_id': 'niFAtgg-6ec'},
#   {'version_id': '3', 'youtube_id': '_ljUkEmrue0'},
#   {'version_id': '4', 'youtube_id': 'Ur12PuDoNnA'},
#   {'version_id': '5', 'youtube_id': '3j6G1ObxTok'}],
#  '8134': [{'version_id': '0', 'youtube_id': '98WtmW-lfeE'},
#   {'version_id': '1', 'youtube_id': 'FEBG4S4PdlU'},
#   {'version_id': '2', 'youtube_id': 'yr1p7BvCQ0U'},
#   {'version_id': '3', 'youtube_id': 'rbgD8l6E-Bs'},
#   {'version_id': '4', 'youtube_id': 'yAUMU3QQE6w'},
#   {'version_id': '6', 'youtube_id': 'ZUSApQG-hrA'},
#   {'version_id': '7', 'youtube_id': 'jZVrsvT_u-4'}],
#  '8136': [{'version_id': '0', 'youtube_id': '_w_KzoDBYZs'},
#   {'version_id': '1', 'youtube_id': 'jBIqDMYVE2U'},
#   {'version_id': '2', 'youtube_id': 'kavK05Tm9_A'}],
#  '8137': [{'version_id': '0', 'youtube_id': '24mLaK--e2A'},
#   {'version_id': '1', 'youtube_id': 'oYpKc2oEOp4'},
#   {'version_id': '2', 'youtube_id': 'ifKrT2TTllo'},
#   {'version_id': '3', 'youtube_id': '9phQO0zSkUs'},
#   {'version_id': '4', 'youtube_id': '5hQ2NHgVKHk'}],
#  '8138': [{'version_id': '0', 'youtube_id': 'erJIVTlhjQk'},
#   {'version_id': '1', 'youtube_id': 'BSbqWO9JjuE'},
#   {'version_id': '2', 'youtube_id': 'vPeuVo3tS6k'},
#   {'version_id': '3', 'youtube_id': '-Yo3v3h2g0Y'}],
#  '8139': [{'version_id': '0', 'youtube_id': '-JjiaRJqKIU'},
#   {'version_id': '1', 'youtube_id': 'owxRpV7l8Dc'},
#   {'version_id': '2', 'youtube_id': 'ofkZs91EkI0'}],
#  '8140': [{'version_id': '0', 'youtube_id': 'qNjVY72qaGw'},
#   {'version_id': '1', 'youtube_id': 'e97ZLt7aF0g'},
#   {'version_id': '2', 'youtube_id': '37sTuYmAqYU'},
#   {'version_id': '3', 'youtube_id': 'fqn6YAPIkAE'}],
#  '8141': [{'version_id': '0', 'youtube_id': 'xdzEtH72ze0'},
#   {'version_id': '1', 'youtube_id': 'kqi4GIuDYJk'},
#   {'version_id': '2', 'youtube_id': 'HT8ET7Nt8qg'},
#   {'version_id': '3', 'youtube_id': '-9zt4CfFp6A'},
#   {'version_id': '4', 'youtube_id': '1f7u7ggniH4'}],
#  '8142': [{'version_id': '0', 'youtube_id': 'i1YtImqPW8c'},
#   {'version_id': '1', 'youtube_id': 'ShEFzu6zTzA'}],
#  '8143': [{'version_id': '0', 'youtube_id': 'rEXhAMtbaec'},
#   {'version_id': '1', 'youtube_id': '2UUm2HF_L4Q'},
#   {'version_id': '2', 'youtube_id': 'M3AGzyn67fM'},
#   {'version_id': '3', 'youtube_id': '0BRf2YlvXy8'},
#   {'version_id': '4', 'youtube_id': 'oIJIBN3XQOc'},
#   {'version_id': '5', 'youtube_id': 'F6QNCuMYcpA'},
#   {'version_id': '6', 'youtube_id': 'tclhZ2FxgMg'},
#   {'version_id': '7', 'youtube_id': 'i47c9tQyvqY'}],
#  '8145': [{'version_id': '0', 'youtube_id': 'QRuCPS_-_IA'},
#   {'version_id': '1', 'youtube_id': 'aWSzoNkqDWA'}],
#  '8146': [{'version_id': '0', 'youtube_id': 'TF1jH6Cv0tk'},
#   {'version_id': '1', 'youtube_id': 'j49Qh3WGtLs'}],
#  '8147': [{'version_id': '0', 'youtube_id': 'eeuVS6vnN7w'},
#   {'version_id': '1', 'youtube_id': 'OCL1Sht2xdI'},
#   {'version_id': '2', 'youtube_id': 'gxKl6T8env4'},
#   {'version_id': '3', 'youtube_id': 'FjtQf0KGdAQ'},
#   {'version_id': '4', 'youtube_id': '3L0UafFjt3g'},
#   {'version_id': '5', 'youtube_id': 'OYFmJyMflCk'}],
#  '8148': [{'version_id': '0', 'youtube_id': 'HrdGgCWcWjo'},
#   {'version_id': '1', 'youtube_id': 'NNmIxFDt7kU'}],
#  '8149': [{'version_id': '1', 'youtube_id': 'qkR5HXwtF4w'},
#   {'version_id': '2', 'youtube_id': 'S5Kjreqx_Dc'},
#   {'version_id': '3', 'youtube_id': '0Ulh-Ih8FQY'}],
#  '8150': [{'version_id': '0', 'youtube_id': 'c5yqV97C-PA'},
#   {'version_id': '1', 'youtube_id': 'nfCe_F25ows'},
#   {'version_id': '2', 'youtube_id': '3-lh9gVlLdQ'},
#   {'version_id': '3', 'youtube_id': 'lalAL8KpmBI'},
#   {'version_id': '4', 'youtube_id': 'UWqCOwH1zFk'}],
#  '8151': [{'version_id': '0', 'youtube_id': 'YtW11gGokuw'},
#   {'version_id': '1', 'youtube_id': 'Wpz0e69lNBc'}],
#  '8152': [{'version_id': '0', 'youtube_id': 'IaBjY-zm0sI'},
#   {'version_id': '1', 'youtube_id': 'hQC6TMazIxk'},
#   {'version_id': '2', 'youtube_id': 'g2dpjcqMp60'},
#   {'version_id': '3', 'youtube_id': 'QCruuS_qps8'}],
#  '8154': [{'version_id': '0', 'youtube_id': 'C7-PpvbWP9g'},
#   {'version_id': '1', 'youtube_id': 'mJpP5R6-7Iw'},
#   {'version_id': '2', 'youtube_id': 't8-BD6xIQAU'},
#   {'version_id': '3', 'youtube_id': 'vnn7Hs6aHEM'},
#   {'version_id': '4', 'youtube_id': 'CHyILaHQolU'},
#   {'version_id': '5', 'youtube_id': 'eJpc9RHbAPs'},
#   {'version_id': '6', 'youtube_id': 'GvOsLrBiI4g'},
#   {'version_id': '7', 'youtube_id': 'd1HQRqlsFyc'}],
#  '8155': [{'version_id': '0', 'youtube_id': 'QuqLdkiY2Dg'},
#   {'version_id': '1', 'youtube_id': '7hqqb2OHkEQ'},
#   {'version_id': '2', 'youtube_id': 'hDLRV585FkM'}],
#  '8156': [{'version_id': '0', 'youtube_id': '3Af4SYHAQTs'},
#   {'version_id': '1', 'youtube_id': 'PEeVKkO2A90'},
#   {'version_id': '2', 'youtube_id': 'lVYA6r_s5GA'},
#   {'version_id': '3', 'youtube_id': 'ibYzUVkXxVY'},
#   {'version_id': '4', 'youtube_id': 'uhe4BFz5rvM'},
#   {'version_id': '5', 'youtube_id': 'P7UWbnZ5w1M'}],
#  '8158': [{'version_id': '0', 'youtube_id': 'EE-EFKv1qn8'},
#   {'version_id': '1', 'youtube_id': '4plMmd8EE7k'},
#   {'version_id': '2', 'youtube_id': 'QyOUZtGwlog'},
#   {'version_id': '3', 'youtube_id': 'mnDZYLmn_SM'},
#   {'version_id': '4', 'youtube_id': 'Fs24VbAN1a8'},
#   {'version_id': '5', 'youtube_id': '31IoHQzqMOc'},
#   {'version_id': '6', 'youtube_id': 'p8e_YwyaDzk'}],
#  '8159': [{'version_id': '0', 'youtube_id': 'byUsulKVyn8'},
#   {'version_id': '1', 'youtube_id': 'yZiSyNicwPI'},
#   {'version_id': '2', 'youtube_id': '6ago2Z0-tWE'},
#   {'version_id': '3', 'youtube_id': 'lZZBHcStFEA'},
#   {'version_id': '4', 'youtube_id': 'MRcPjbk_nxM'}],
#  '8160': [{'version_id': '1', 'youtube_id': 'HUwzjj7J77U'},
#   {'version_id': '2', 'youtube_id': 'ssRIb46u-M8'},
#   {'version_id': '3', 'youtube_id': 'X56IGwjvzBA'}],
#  '8161': [{'version_id': '0', 'youtube_id': '0G4kT6HK6oI'},
#   {'version_id': '1', 'youtube_id': 'gC2ANVKTWqQ'},
#   {'version_id': '2', 'youtube_id': '5ZMGBii53lw'},
#   {'version_id': '3', 'youtube_id': 'd7RxF_P4QFg'},
#   {'version_id': '4', 'youtube_id': '8AvjwxHZ-0s'},
#   {'version_id': '5', 'youtube_id': 'zlzmITuaEso'},
#   {'version_id': '6', 'youtube_id': 'mRuZe8J3SII'}],
#  '8162': [{'version_id': '0', 'youtube_id': 'z31kXINGMGo'},
#   {'version_id': '1', 'youtube_id': 'YOxVExh1ULI'},
#   {'version_id': '2', 'youtube_id': 'F1ltDtOZIug'},
#   {'version_id': '3', 'youtube_id': 'zgBdAWEfeW0'},
#   {'version_id': '4', 'youtube_id': 'zshorX7g1aM'},
#   {'version_id': '5', 'youtube_id': 'akbm_566Ayc'},
#   {'version_id': '6', 'youtube_id': 'WG32FvsN81o'}],
#  '8163': [{'version_id': '0', 'youtube_id': 'qMxX-QOV9tI'},
#   {'version_id': '1', 'youtube_id': 'l_YGacjpZWg'},
#   {'version_id': '2', 'youtube_id': 'H4GkGMPzYYo'},
#   {'version_id': '3', 'youtube_id': '0XC_rkEamHY'},
#   {'version_id': '4', 'youtube_id': 'w1zUiHSenw4'},
#   {'version_id': '5', 'youtube_id': '-fQT1CBgqdU'},
#   {'version_id': '6', 'youtube_id': 'SYeTjJXeX6Y'},
#   {'version_id': '7', 'youtube_id': 'RJtki7lIGiI'}],
#  '8164': [{'version_id': '1', 'youtube_id': '1BVhbdyUvzI'},
#   {'version_id': '2', 'youtube_id': 'zKNXm3_LmGI'},
#   {'version_id': '3', 'youtube_id': 'Tej8nYYjYiQ'},
#   {'version_id': '4', 'youtube_id': 'unu33z7fsfU'},
#   {'version_id': '5', 'youtube_id': 'rewnvqVA6jo'}],
#  '8165': [{'version_id': '0', 'youtube_id': 'Mntp8LgUbJU'},
#   {'version_id': '3', 'youtube_id': 'DlKaQNXay78'},
#   {'version_id': '4', 'youtube_id': '8mFyW4TaSL0'},
#   {'version_id': '5', 'youtube_id': 'f_p4j3X-dOY'}],
#  '8166': [{'version_id': '0', 'youtube_id': '4I9K62crylA'},
#   {'version_id': '1', 'youtube_id': 'R1SKYZnosc4'}],
#  '8169': [{'version_id': '0', 'youtube_id': '8jErbpY9iiQ'},
#   {'version_id': '1', 'youtube_id': '92iVi1tqdME'},
#   {'version_id': '2', 'youtube_id': 'WP5TsJAyFJc'},
#   {'version_id': '3', 'youtube_id': 'VjiqErAQvdc'},
#   {'version_id': '4', 'youtube_id': 'OkZbNvbDE_c'},
#   {'version_id': '5', 'youtube_id': 'uFPhas3yQFM'},
#   {'version_id': '6', 'youtube_id': 'CkQZ_jpmsGg'},
#   {'version_id': '7', 'youtube_id': 'QYxoW85X5vw'}],
#  '8170': [{'version_id': '0', 'youtube_id': 'G7YgHqc_PvQ'},
#   {'version_id': '1', 'youtube_id': 'opFcv14q2bU'},
#   {'version_id': '2', 'youtube_id': '0OaI8qlalnE'},
#   {'version_id': '3', 'youtube_id': 'jAqUEjP6Lw4'},
#   {'version_id': '4', 'youtube_id': 'RGCaBhbw9HE'},
#   {'version_id': '5', 'youtube_id': 'EwHk3SapSE4'}],
#  '8172': [{'version_id': '0', 'youtube_id': '5Ok_Ux-BidE'},
#   {'version_id': '1', 'youtube_id': 'q7HnSbjCFag'},
#   {'version_id': '2', 'youtube_id': 'RkG86q-NPaw'},
#   {'version_id': '3', 'youtube_id': 'PP_xm1Qr34M'}],
#  '8173': [{'version_id': '0', 'youtube_id': 'TZfT2T1wRzo'},
#   {'version_id': '1', 'youtube_id': 'fkFQirhsxRw'},
#   {'version_id': '2', 'youtube_id': 'Z4yYnoTOruQ'},
#   {'version_id': '3', 'youtube_id': '2h_Yd4VtBLQ'},
#   {'version_id': '4', 'youtube_id': 'BsGFJOhfh1E'}],
#  '8174': [{'version_id': '0', 'youtube_id': 'bxROkkm02AQ'},
#   {'version_id': '1', 'youtube_id': '1BZiLAD0YI8'},
#   {'version_id': '2', 'youtube_id': 'DmOCKzB7dAA'},
#   {'version_id': '3', 'youtube_id': '9auIDF1zg3I'}],
#  '8175': [{'version_id': '0', 'youtube_id': 'voEMDg0GBAo'},
#   {'version_id': '1', 'youtube_id': 'yGfMLHKw868'},
#   {'version_id': '3', 'youtube_id': 'alRN4NTTv74'},
#   {'version_id': '4', 'youtube_id': 'cJGmCFVDC3o'},
#   {'version_id': '5', 'youtube_id': 'I8qJMvfXyEo'},
#   {'version_id': '6', 'youtube_id': 'tN3wBSb3u2s'},
#   {'version_id': '7', 'youtube_id': 'mVpSHcp4BM0'},
#   {'version_id': '8', 'youtube_id': '9m3TTBK0NVw'},
#   {'version_id': '9', 'youtube_id': 'ng6y3tYImCc'}],
#  '8176': [{'version_id': '0', 'youtube_id': 'qQkBeOisNM0'},
#   {'version_id': '1', 'youtube_id': '_AfTBoCKJbU'},
#   {'version_id': '2', 'youtube_id': 'b4vZKHsWVT0'},
#   {'version_id': '3', 'youtube_id': 'LlFDVQoH9OM'},
#   {'version_id': '4', 'youtube_id': 'kQsN-pvokrw'},
#   {'version_id': '6', 'youtube_id': 'L9RG3s-Q0hk'},
#   {'version_id': '7', 'youtube_id': 'bDzlJJfhfeg'},
#   {'version_id': '8', 'youtube_id': '-72uhdJkmcU'}],
#  '8177': [{'version_id': '0', 'youtube_id': 'bZWtOCe382k'},
#   {'version_id': '1', 'youtube_id': 'lc1tQ5rT18o'},
#   {'version_id': '2', 'youtube_id': '0l9hwX0bKz4'},
#   {'version_id': '3', 'youtube_id': '-0zjvVLfFxE'},
#   {'version_id': '4', 'youtube_id': 'RbH5GGC2jfE'},
#   {'version_id': '5', 'youtube_id': 'ERmE02XbvwY'}],
#  '8179': [{'version_id': '0', 'youtube_id': 'rMhND4E9Jho'},
#   {'version_id': '1', 'youtube_id': 'QCZX98i_7xI'},
#   {'version_id': '2', 'youtube_id': 'CmBEGVi4ycM'},
#   {'version_id': '3', 'youtube_id': '3v96D34CEFg'},
#   {'version_id': '4', 'youtube_id': 'HnZPxn97I-Q'},
#   {'version_id': '5', 'youtube_id': '_DgV2I7medY'},
#   {'version_id': '6', 'youtube_id': 'hq-6C9J6c_s'},
#   {'version_id': '7', 'youtube_id': 'fYIZDe_be_8'}],
#  '8180': [{'version_id': '0', 'youtube_id': 'yD-ffhvefsw'},
#   {'version_id': '1', 'youtube_id': 'KqmkZT-Jqmw'},
#   {'version_id': '2', 'youtube_id': 'UgJd695K1Qc'}],
#  '8181': [{'version_id': '0', 'youtube_id': 'kGHJ30YmDQE'},
#   {'version_id': '1', 'youtube_id': 'NNLXiDo9elA'},
#   {'version_id': '2', 'youtube_id': '8CJHt927moc'},
#   {'version_id': '3', 'youtube_id': 'PLUW271vcq8'}],
#  '8182': [{'version_id': '0', 'youtube_id': 'TAOQgxOJLC4'},
#   {'version_id': '1', 'youtube_id': 'SxPJ5mxiBFw'},
#   {'version_id': '2', 'youtube_id': 'PGamY3MDclw'},
#   {'version_id': '3', 'youtube_id': 'Eize65KLq7c'},
#   {'version_id': '4', 'youtube_id': 'n11_00_jI2A'},
#   {'version_id': '5', 'youtube_id': 'qMf4wlcpmfU'}],
#  '8183': [{'version_id': '0', 'youtube_id': 'D2bHgUOsbm4'},
#   {'version_id': '1', 'youtube_id': 'iWbK1kU9XZY'},
#   {'version_id': '2', 'youtube_id': 'N8eZWs8UQf0'},
#   {'version_id': '3', 'youtube_id': 'az59BqslOAE'},
#   {'version_id': '4', 'youtube_id': 'NyXybFP50CI'},
#   {'version_id': '5', 'youtube_id': 'PJ7RvMzVYwM'}],
#  '8184': [{'version_id': '0', 'youtube_id': '3OMEWH8vilU'},
#   {'version_id': '1', 'youtube_id': 'fsbo_tBAXiA'},
#   {'version_id': '2', 'youtube_id': '62CmjkDZAq0'}],
#  '8185': [{'version_id': '0', 'youtube_id': 'gZyEbyccYgA'},
#   {'version_id': '1', 'youtube_id': 'VQpaEKAl7s0'},
#   {'version_id': '2', 'youtube_id': 'ZcmpdeFo8q8'},
#   {'version_id': '3', 'youtube_id': 'CepwJq29YEA'},
#   {'version_id': '4', 'youtube_id': 'Fpi28GBcf5c'}],
#  '8186': [{'version_id': '0', 'youtube_id': 'CEym6eJ8fa0'},
#   {'version_id': '1', 'youtube_id': 'o-gmQdNrDiM'},
#   {'version_id': '2', 'youtube_id': '6z0HMew4vmU'},
#   {'version_id': '3', 'youtube_id': 'he_UUbp6A5M'},
#   {'version_id': '4', 'youtube_id': 'cydUkwwdsRY'},
#   {'version_id': '5', 'youtube_id': '2ZoGqAWFvMk'},
#   {'version_id': '6', 'youtube_id': 'zv8g2Onv_nc'},
#   {'version_id': '7', 'youtube_id': 'FGwDdGzV3c4'},
#   {'version_id': '8', 'youtube_id': 'hSMj0h6GpAc'}],
#  '8187': [{'version_id': '0', 'youtube_id': 'MIeutRREg78'},
#   {'version_id': '1', 'youtube_id': '22chSvkQDE0'},
#   {'version_id': '2', 'youtube_id': 'oREmbGD84Kw'},
#   {'version_id': '3', 'youtube_id': 'J1hXhQtTrgM'}],
#  '8188': [{'version_id': '1', 'youtube_id': 'b9-KcK_CjwA'},
#   {'version_id': '3', 'youtube_id': 'El48DvZQoLs'},
#   {'version_id': '4', 'youtube_id': 'iyfHjzZJLLE'},
#   {'version_id': '5', 'youtube_id': '-ylyBq1OFaY'},
#   {'version_id': '6', 'youtube_id': 'jPVrFwMErD4'},
#   {'version_id': '7', 'youtube_id': 'sZoFlyojp3Y'},
#   {'version_id': '8', 'youtube_id': 'Q_G_Ya6dfig'},
#   {'version_id': '10', 'youtube_id': 'ZFvTTzbQF28'}],
#  '8189': [{'version_id': '0', 'youtube_id': 'iGK0xWddnNk'},
#   {'version_id': '1', 'youtube_id': 'a048BaQ5AOg'},
#   {'version_id': '3', 'youtube_id': 'KiyzpBHUGQQ'},
#   {'version_id': '4', 'youtube_id': 'ZjIF2T87hHA'},
#   {'version_id': '5', 'youtube_id': 'ktEiZ9AlDRY'}],
#  '8190': [{'version_id': '1', 'youtube_id': 'eX7nMCRSqJU'},
#   {'version_id': '2', 'youtube_id': 'Qdc-qlw_Ayk'},
#   {'version_id': '3', 'youtube_id': 'hX8msgp71EA'},
#   {'version_id': '4', 'youtube_id': 'iXbLYNJVKSE'},
#   {'version_id': '5', 'youtube_id': 'MwvMjiOCyqY'},
#   {'version_id': '6', 'youtube_id': 'EnkcgzY4sBA'},
#   {'version_id': '7', 'youtube_id': '46YkD5Kas_8'},
#   {'version_id': '8', 'youtube_id': 'Th5VrhJffic'},
#   {'version_id': '9', 'youtube_id': 'A7v0jV2UZio'}],
#  '8191': [{'version_id': '0', 'youtube_id': 'Ow00BrG6K9I'},
#   {'version_id': '1', 'youtube_id': 'P99Sb3bFmcQ'},
#   {'version_id': '2', 'youtube_id': 'RofrFgdXggc'},
#   {'version_id': '3', 'youtube_id': 'NIu_1KQAEvs'},
#   {'version_id': '4', 'youtube_id': 'zMHeC3VNXlw'}],
#  '8193': [{'version_id': '0', 'youtube_id': '2kNJBnhJPO8'},
#   {'version_id': '1', 'youtube_id': 'aPeuH6zs_3Q'},
#   {'version_id': '2', 'youtube_id': '4ok_2yhRkhQ'},
#   {'version_id': '3', 'youtube_id': '5hpwt8R5qyI'},
#   {'version_id': '4', 'youtube_id': 'lW3wqKSGdUg'},
#   {'version_id': '5', 'youtube_id': '6qzFXG0GdBc'}],
#  '8194': [{'version_id': '0', 'youtube_id': '8LNuk0OgWhQ'},
#   {'version_id': '1', 'youtube_id': 'rBzgTOV_Z6s'}],
#  '8195': [{'version_id': '0', 'youtube_id': '1WxOZ4F5PMA'},
#   {'version_id': '1', 'youtube_id': 'tWZ5tzk_tQw'},
#   {'version_id': '2', 'youtube_id': 'IALGX4wgjr8'}],
#  '8196': [{'version_id': '0', 'youtube_id': 'Ag4NhsfemvE'},
#   {'version_id': '1', 'youtube_id': 'aRyINBuZq0k'},
#   {'version_id': '2', 'youtube_id': 'DIRVsdOGTy0'},
#   {'version_id': '3', 'youtube_id': '_6seaI9k_ys'},
#   {'version_id': '4', 'youtube_id': 'gl8oPYLtlyQ'}],
#  '8197': [{'version_id': '0', 'youtube_id': '-tRdBsnX4N4'},
#   {'version_id': '1', 'youtube_id': 'D4R9FiKE0Tk'},
#   {'version_id': '2', 'youtube_id': 'B-weJHEwwrw'},
#   {'version_id': '3', 'youtube_id': 'Rd9RptGbyoM'},
#   {'version_id': '4', 'youtube_id': 'op_7hWplb50'}],
#  '8198': [{'version_id': '0', 'youtube_id': '5-Eawo2c-rk'},
#   {'version_id': '1', 'youtube_id': 'y0f90usXNtg'},
#   {'version_id': '2', 'youtube_id': 'AQpgxwKGdK0'},
#   {'version_id': '3', 'youtube_id': 'anF_WzW-TbQ'},
#   {'version_id': '4', 'youtube_id': 'SGbdhUf4mjk'},
#   {'version_id': '5', 'youtube_id': 'mmSKBt4B2hM'}],
#  '8199': [{'version_id': '0', 'youtube_id': 'XxORna-KHeQ'},
#   {'version_id': '1', 'youtube_id': 'a9qSlyy8suo'},
#   {'version_id': '2', 'youtube_id': 's_5PHTZa5Kg'},
#   {'version_id': '3', 'youtube_id': 'O2OckTAWsWM'},
#   {'version_id': '4', 'youtube_id': 'TkRS5FuhFVg'}],
#  '8201': [{'version_id': '0', 'youtube_id': 'wUVk3ji0UnM'},
#   {'version_id': '2', 'youtube_id': 'C29Ymmq06ng'},
#   {'version_id': '3', 'youtube_id': 'I7DHCMs3Ld8'}],
#  '8202': [{'version_id': '0', 'youtube_id': 'akmjOZ6-3Xg'},
#   {'version_id': '1', 'youtube_id': '-rKQEmzFJFM'},
#   {'version_id': '2', 'youtube_id': 'FYfzc2taG50'},
#   {'version_id': '3', 'youtube_id': 'MCSRb1R6-Ls'},
#   {'version_id': '4', 'youtube_id': 'c5DZgsQjIGw'},
#   {'version_id': '5', 'youtube_id': 'FWvSSbcOa5k'}],
#  '8204': [{'version_id': '0', 'youtube_id': '2uiFE_yKJsc'},
#   {'version_id': '1', 'youtube_id': '501brqzP5CY'},
#   {'version_id': '2', 'youtube_id': '9MxCSGDu-lQ'},
#   {'version_id': '3', 'youtube_id': '7WfWhDEeoZ4'}],
#  '8205': [{'version_id': '0', 'youtube_id': 'diYAc7gB-0A'},
#   {'version_id': '1', 'youtube_id': 'deqk-Cemz6Q'},
#   {'version_id': '2', 'youtube_id': 'sEtuqwT9x80'},
#   {'version_id': '3', 'youtube_id': 'kGDzddaB16g'},
#   {'version_id': '4', 'youtube_id': 'mA0lDZq3rcE'}],
#  '8207': [{'version_id': '0', 'youtube_id': 'wdTlRg1u3s0'},
#   {'version_id': '1', 'youtube_id': 'UH7kqPlshQQ'}],
#  '8208': [{'version_id': '0', 'youtube_id': 'uncDDG87NOY'},
#   {'version_id': '1', 'youtube_id': 'YFDl6x3neG8'},
#   {'version_id': '2', 'youtube_id': 'MdXt18Yfphw'}],
#  '8209': [{'version_id': '0', 'youtube_id': 'AgFeZr5ptV8'},
#   {'version_id': '1', 'youtube_id': 'YrqOd-_MrNk'},
#   {'version_id': '2', 'youtube_id': 'XpINuwLTfLY'},
#   {'version_id': '3', 'youtube_id': '-Qg-CXvIGWM'},
#   {'version_id': '4', 'youtube_id': 'rJYVBnoS6oQ'},
#   {'version_id': '5', 'youtube_id': 'QKSHTKL4cI0'},
#   {'version_id': '6', 'youtube_id': 'anchxwcOQBM'},
#   {'version_id': '7', 'youtube_id': 'Cpu35i2yqC0'},
#   {'version_id': '8', 'youtube_id': '-3VkOmPVKPQ'},
#   {'version_id': '9', 'youtube_id': 'XBBH9CsPScM'}],
#  '8210': [{'version_id': '0', 'youtube_id': 'YkrB4oL3SW0'},
#   {'version_id': '1', 'youtube_id': '5C-DShN82mc'},
#   {'version_id': '2', 'youtube_id': 'XEesD8Pvw1M'},
#   {'version_id': '4', 'youtube_id': 'carEyRDcUAU'}],
#  '8211': [{'version_id': '0', 'youtube_id': 'f0cipp5sGUQ'},
#   {'version_id': '1', 'youtube_id': 'ZD_scy7aF_o'}],
#  '8212': [{'version_id': '0', 'youtube_id': 'xUeI-9jo4Go'},
#   {'version_id': '1', 'youtube_id': 'JeJtK6LfLvo'},
#   {'version_id': '2', 'youtube_id': 'Tx-844d-GNY'},
#   {'version_id': '3', 'youtube_id': 'ejyS_yjkmE0'}],
#  '8214': [{'version_id': '0', 'youtube_id': 'dwEgH1FkzR4'},
#   {'version_id': '1', 'youtube_id': '3n4X6lY-jWg'},
#   {'version_id': '2', 'youtube_id': 'rswiT9xNIME'},
#   {'version_id': '3', 'youtube_id': '9fTzO1XU6I0'},
#   {'version_id': '4', 'youtube_id': 'aAkB1kB2fps'}],
#  '8215': [{'version_id': '0', 'youtube_id': 'D4aob4zlhIk'},
#   {'version_id': '1', 'youtube_id': 'qqS1IHFe9NY'},
#   {'version_id': '2', 'youtube_id': 'iEXYSxT4phw'},
#   {'version_id': '3', 'youtube_id': 'x2bDBUD4J60'},
#   {'version_id': '4', 'youtube_id': 'l4xwD86Puew'},
#   {'version_id': '5', 'youtube_id': '4_0YHY2fmb8'}],
#  '8216': [{'version_id': '0', 'youtube_id': 'U3qvY7EFkDM'},
#   {'version_id': '1', 'youtube_id': '3AJOGUeGPto'},
#   {'version_id': '2', 'youtube_id': 'IcXdgBptul8'},
#   {'version_id': '3', 'youtube_id': '1z1jXEU5GYg'},
#   {'version_id': '4', 'youtube_id': 'yWWZGr2LFac'},
#   {'version_id': '5', 'youtube_id': 'TgT6b8wDw-E'}],
#  '8217': [{'version_id': '0', 'youtube_id': 'oCgmhrJtMFI'},
#   {'version_id': '1', 'youtube_id': 'YanSbMspYxU'},
#   {'version_id': '2', 'youtube_id': 'BCjbxLkZVg4'},
#   {'version_id': '3', 'youtube_id': '6-1hCbXrNEU'},
#   {'version_id': '4', 'youtube_id': 'QPA47ovEmPY'},
#   {'version_id': '5', 'youtube_id': '1V72cdD8ERo'},
#   {'version_id': '6', 'youtube_id': 'kI6bYiqxSBs'}],
#  '8218': [{'version_id': '0', 'youtube_id': 'rsqKdZ3JZ2k'},
#   {'version_id': '2', 'youtube_id': 'YFs44me-Ugc'},
#   {'version_id': '3', 'youtube_id': 'D1es3lUGrsc'},
#   {'version_id': '4', 'youtube_id': '_YuMurfToqg'},
#   {'version_id': '5', 'youtube_id': 'oaiI-aVxtMQ'}],
#  '8219': [{'version_id': '0', 'youtube_id': 'P6doKN91sb8'},
#   {'version_id': '1', 'youtube_id': 'UUzzKgTs--A'}],
#  '8221': [{'version_id': '0', 'youtube_id': 'Ui7Dc7M1xgo'},
#   {'version_id': '1', 'youtube_id': 'dPhfyGTBe8c'},
#   {'version_id': '2', 'youtube_id': 'XlCgkJhfiAA'},
#   {'version_id': '3', 'youtube_id': '1sUEZ6lurK8'},
#   {'version_id': '4', 'youtube_id': 'nAArjydzHIw'},
#   {'version_id': '5', 'youtube_id': '6IY7YjOEN-Y'}],
#  '8222': [{'version_id': '0', 'youtube_id': 'r_8ydghbGSg'},
#   {'version_id': '1', 'youtube_id': 'wDsI3yI1GV8'},
#   {'version_id': '2', 'youtube_id': 'Ytd4MY6brKw'},
#   {'version_id': '3', 'youtube_id': 'UknNKQZvyj8'},
#   {'version_id': '4', 'youtube_id': 'XkMJvOrNaeU'},
#   {'version_id': '5', 'youtube_id': 'JQ3r-rXUABI'},
#   {'version_id': '6', 'youtube_id': 'Zjsln7XG9b8'},
#   {'version_id': '7', 'youtube_id': 'Xz46HGTiLoc'},
#   {'version_id': '8', 'youtube_id': 'sPkEKCLL-wU'},
#   {'version_id': '9', 'youtube_id': '9wnyOVHGj_g'},
#   {'version_id': '10', 'youtube_id': 'XyE6zrXaVVA'},
#   {'version_id': '12', 'youtube_id': 'VglXSnsb_Ng'}],
#  '8223': [{'version_id': '0', 'youtube_id': '1uby6jFCDjE'},
#   {'version_id': '1', 'youtube_id': 'dTvygtjsla0'},
#   {'version_id': '2', 'youtube_id': 'wOwPRM2ZZYg'},
#   {'version_id': '3', 'youtube_id': '72OLupNWNho'}],
#  '8224': [{'version_id': '0', 'youtube_id': 'rAEglE08Ojs'},
#   {'version_id': '1', 'youtube_id': 'UEhlq7Gd9qs'}],
#  '8226': [{'version_id': '0', 'youtube_id': 'Fd_4sx9ChsE'},
#   {'version_id': '1', 'youtube_id': 'NUX99hUJhTE'},
#   {'version_id': '2', 'youtube_id': 'RSFZPCzzHIU'},
#   {'version_id': '3', 'youtube_id': 'SVNP1aFoTC0'},
#   {'version_id': '4', 'youtube_id': 'q4g5A9SchRw'},
#   {'version_id': '5', 'youtube_id': 'BeYSZN0xVPE'}],
#  '8227': [{'version_id': '0', 'youtube_id': 'HNqQAz3srDg'},
#   {'version_id': '1', 'youtube_id': '8sbp_qmKjWU'},
#   {'version_id': '2', 'youtube_id': 'BlCkBUop0wc'},
#   {'version_id': '3', 'youtube_id': 'w1OXJGQO8UI'},
#   {'version_id': '4', 'youtube_id': 'wLRPT2lc6M8'},
#   {'version_id': '5', 'youtube_id': 'VDcjPR48E1w'},
#   {'version_id': '6', 'youtube_id': 'FaI-2S_ja08'}],
#  '8228': [{'version_id': '0', 'youtube_id': 'q-7WhDI6kYU'},
#   {'version_id': '1', 'youtube_id': 'GqrM28Kn4e8'}],
#  '8229': [{'version_id': '0', 'youtube_id': '9ygi1F9spZ8'},
#   {'version_id': '1', 'youtube_id': 'kb_8_ZOIHVg'},
#   {'version_id': '2', 'youtube_id': 'dYuOPXrr3nQ'},
#   {'version_id': '3', 'youtube_id': 'xjJ2g3IVbUE'},
#   {'version_id': '4', 'youtube_id': 'C9r4XA4zK0Y'}],
#  '8230': [{'version_id': '0', 'youtube_id': 'zFAy2LOaIAk'},
#   {'version_id': '1', 'youtube_id': 'K92LGl-LCC8'},
#   {'version_id': '2', 'youtube_id': 'WlhdT5PbW8c'},
#   {'version_id': '3', 'youtube_id': 'heX2p_-0HQk'},
#   {'version_id': '4', 'youtube_id': 'b6wy3-Yh1gQ'},
#   {'version_id': '5', 'youtube_id': 'Lac29U6AcdU'}],
#  '8231': [{'version_id': '0', 'youtube_id': '8I8iRblpdDA'},
#   {'version_id': '1', 'youtube_id': 'IcBARXsku5k'},
#   {'version_id': '2', 'youtube_id': 'xkipXs8ov-g'},
#   {'version_id': '3', 'youtube_id': 'fdkwLJKg9nA'},
#   {'version_id': '5', 'youtube_id': 'wy4sjIN_E9k'}],
#  '8232': [{'version_id': '0', 'youtube_id': 'Jg0oRp7Dqa0'},
#   {'version_id': '1', 'youtube_id': 'PkxwDK1Mzuo'},
#   {'version_id': '2', 'youtube_id': 'qWjmITH4nao'},
#   {'version_id': '3', 'youtube_id': '3gwHaXMxuJc'},
#   {'version_id': '4', 'youtube_id': 'w2OrvmmUG5Y'}],
#  '8233': [{'version_id': '0', 'youtube_id': 'yqV6W0J8N1Y'},
#   {'version_id': '2', 'youtube_id': 'CQ5sWYSzDfI'},
#   {'version_id': '3', 'youtube_id': 'FUVLVenPbRU'}],
#  '8234': [{'version_id': '0', 'youtube_id': 'zo-VUL6V4EQ'},
#   {'version_id': '1', 'youtube_id': 'o_h96aVE8b4'},
#   {'version_id': '2', 'youtube_id': 's8qSth-FxZI'},
#   {'version_id': '3', 'youtube_id': 'l_8x04zqdRA'},
#   {'version_id': '4', 'youtube_id': 'iQC2_NJj2iA'},
#   {'version_id': '5', 'youtube_id': 'Hy7pct6iJBE'},
#   {'version_id': '6', 'youtube_id': 'g-KAoogSLZ4'}],
#  '8235': [{'version_id': '0', 'youtube_id': 'R13yQwbOnLU'},
#   {'version_id': '1', 'youtube_id': '403CLD-wtVo'},
#   {'version_id': '2', 'youtube_id': 'AD4E5IvN1Bg'},
#   {'version_id': '3', 'youtube_id': 'M687idxKkj0'},
#   {'version_id': '4', 'youtube_id': 'HA0-dMVdJXo'}],
#  '8236': [{'version_id': '0', 'youtube_id': '4pZD1Six5XI'},
#   {'version_id': '1', 'youtube_id': 'A8szdi1D7OE'}],
#  '8238': [{'version_id': '0', 'youtube_id': 'QzEN61mhEW0'},
#   {'version_id': '1', 'youtube_id': 'ZWPwYQq23PQ'},
#   {'version_id': '2', 'youtube_id': 'kqxoAr1lx7c'},
#   {'version_id': '3', 'youtube_id': 'Q0xmbjb6t_w'},
#   {'version_id': '4', 'youtube_id': '6_QnxTWBcaE'},
#   {'version_id': '5', 'youtube_id': 'u6CvuITH5ws'},
#   {'version_id': '6', 'youtube_id': '_QWETK6d4oE'},
#   {'version_id': '7', 'youtube_id': 'pbPABgHNVLE'}],
#  '8239': [{'version_id': '0', 'youtube_id': 'GHCaxVCXNIc'},
#   {'version_id': '1', 'youtube_id': 'XNkQXVFpB4w'},
#   {'version_id': '2', 'youtube_id': '21EqGA50KNw'},
#   {'version_id': '3', 'youtube_id': 'pWeykhKw7rU'}],
#  '8240': [{'version_id': '0', 'youtube_id': 'iS1g8G_njx8'},
#   {'version_id': '1', 'youtube_id': 'WGXSnE3lpdo'},
#   {'version_id': '2', 'youtube_id': 'C87KxG81fBo'},
#   {'version_id': '3', 'youtube_id': 'YSoHzEShGVQ'},
#   {'version_id': '4', 'youtube_id': '4Z9b2HiW_L8'},
#   {'version_id': '5', 'youtube_id': 'mGvURCt1aUQ'},
#   {'version_id': '6', 'youtube_id': 'CNdTk8Y9iUs'},
#   {'version_id': '7', 'youtube_id': 'rvl8yGmgXdQ'},
#   {'version_id': '9', 'youtube_id': 'W_sA3QwwUVk'},
#   {'version_id': '10', 'youtube_id': '4p_l2g1BZ_c'}],
#  '8242': [{'version_id': '0', 'youtube_id': '5pamroqTMKg'},
#   {'version_id': '1', 'youtube_id': 'w-F1U3-m00k'},
#   {'version_id': '2', 'youtube_id': 'jv8Cxb2w9UA'},
#   {'version_id': '3', 'youtube_id': 'FGDocC6hVeg'},
#   {'version_id': '4', 'youtube_id': 'iw-7gZ2HvNs'},
#   {'version_id': '5', 'youtube_id': 'f0MYAK-k6XM'},
#   {'version_id': '6', 'youtube_id': 'YCEe0ld_YVY'},
#   {'version_id': '7', 'youtube_id': 'm2RjGG9Bm60'}],
#  '8243': [{'version_id': '0', 'youtube_id': 'J7Cn5ofhF9E'},
#   {'version_id': '1', 'youtube_id': 'SxozWxvZyA0'},
#   {'version_id': '2', 'youtube_id': 'KvWaCdz5wUs'},
#   {'version_id': '3', 'youtube_id': 'A7AyUVfC2Bc'},
#   {'version_id': '4', 'youtube_id': '2Nhp837cxqI'},
#   {'version_id': '5', 'youtube_id': 'PQuR1MiE-VQ'},
#   {'version_id': '6', 'youtube_id': '2DldzqOAono'}],
#  '8245': [{'version_id': '0', 'youtube_id': '0UWBO4r11AY'},
#   {'version_id': '1', 'youtube_id': 'vO3ueCh4Gw0'},
#   {'version_id': '2', 'youtube_id': 'NKhE8YNU4cQ'}],
#  '8246': [{'version_id': '0', 'youtube_id': 'vHOokpi9hUw'},
#   {'version_id': '1', 'youtube_id': 'FqAh97_BGR0'},
#   {'version_id': '2', 'youtube_id': 'AuvMItKy3E8'},
#   {'version_id': '3', 'youtube_id': 'V8owouBo7CQ'}],
#  '8247': [{'version_id': '0', 'youtube_id': 'fzafBwvL75E'},
#   {'version_id': '1', 'youtube_id': 'nFs8CnxmiWM'},
#   {'version_id': '3', 'youtube_id': 'nFs8CnxmiWM'}],
#  '8248': [{'version_id': '2', 'youtube_id': 'XVe8FVtuf9k'},
#   {'version_id': '3', 'youtube_id': 'dErg2Wai00g'},
#   {'version_id': '4', 'youtube_id': '7IVMo9t2Fzk'},
#   {'version_id': '5', 'youtube_id': '0_SiHhVCnAs'},
#   {'version_id': '6', 'youtube_id': 'MhChdqdYx4E'}],
#  '8249': [{'version_id': '0', 'youtube_id': 'nCkpzqqog4k'},
#   {'version_id': '1', 'youtube_id': '5Qi7fiMPXt8'},
#   {'version_id': '2', 'youtube_id': 'TIIf5Wwfq34'},
#   {'version_id': '3', 'youtube_id': '8T2sE7ZBtRE'},
#   {'version_id': '4', 'youtube_id': 'Fk_3Q_Dq_r4'},
#   {'version_id': '5', 'youtube_id': '_1azJWrtuxQ'},
#   {'version_id': '7', 'youtube_id': '1FF9oe7593w'},
#   {'version_id': '8', 'youtube_id': 'VGHLvmr24Ns'},
#   {'version_id': '9', 'youtube_id': '8-jCTeVfIzQ'},
#   {'version_id': '10', 'youtube_id': '77z7oWTczqI'},
#   {'version_id': '11', 'youtube_id': 'yjAVkUeCRao'},
#   {'version_id': '12', 'youtube_id': 'oQq9vDU4IfU'}],
#  '8250': [{'version_id': '0', 'youtube_id': '8AOD6Tc9BTo'},
#   {'version_id': '1', 'youtube_id': 'GBubx_26LGY'},
#   {'version_id': '2', 'youtube_id': '7vvnDhTbyg4'},
#   {'version_id': '3', 'youtube_id': 'caNb3IiKhmA'},
#   {'version_id': '4', 'youtube_id': '1IKdCb5QO2o'}],
#  '8251': [{'version_id': '0', 'youtube_id': 'a_EmPaC6Gdc'},
#   {'version_id': '1', 'youtube_id': 'ByV4RaWMVhQ'},
#   {'version_id': '2', 'youtube_id': 'Iebv1LZOInc'}],
#  '8252': [{'version_id': '0', 'youtube_id': 'jrXcBot9FbA'},
#   {'version_id': '1', 'youtube_id': 'I0zKqiClt1k'},
#   {'version_id': '2', 'youtube_id': 'c2l3SCFSRDI'}],
#  '8253': [{'version_id': '0', 'youtube_id': 'HB6l4i-zA_Q'},
#   {'version_id': '1', 'youtube_id': '_l8z_JfCWtw'},
#   {'version_id': '3', 'youtube_id': 'wpdnCPJ-EEs'},
#   {'version_id': '4', 'youtube_id': 'kBGLNqE3XYs'},
#   {'version_id': '5', 'youtube_id': 'Y2gq5cL0gXg'}],
#  '8254': [{'version_id': '0', 'youtube_id': 'aYt61lbk0C4'},
#   {'version_id': '1', 'youtube_id': 'LGefphbHPPY'},
#   {'version_id': '2', 'youtube_id': 'Yem_U7lcW3U'},
#   {'version_id': '3', 'youtube_id': '-EJq_tgN0ao'},
#   {'version_id': '4', 'youtube_id': 'CRk_gfWykLE'},
#   {'version_id': '5', 'youtube_id': 'FfKUi2DKSv8'},
#   {'version_id': '6', 'youtube_id': 'k-mw3MHETIs'}],
#  '8256': [{'version_id': '0', 'youtube_id': '88fmUYTWa9g'},
#   {'version_id': '1', 'youtube_id': 'Nt2wf38qTkY'},
#   {'version_id': '2', 'youtube_id': 'UJhKoFR7iD8'},
#   {'version_id': '3', 'youtube_id': 'M5G3L5Ie59k'},
#   {'version_id': '4', 'youtube_id': '1Mrc87c9rgQ'},
#   {'version_id': '5', 'youtube_id': 'I07OomwaPhw'},
#   {'version_id': '6', 'youtube_id': '6FNlEfvop0Y'},
#   {'version_id': '7', 'youtube_id': 'G4_nFBL5IzE'}],
#  '8257': [{'version_id': '1', 'youtube_id': 'XEIMPfeXspo'},
#   {'version_id': '2', 'youtube_id': '-0IdXwb5Gd4'},
#   {'version_id': '3', 'youtube_id': 'QxTxFjuOj3M'},
#   {'version_id': '5', 'youtube_id': 'Igj4GnkXjiA'}],
#  '8258': [{'version_id': '0', 'youtube_id': 'epwqVwoqH7Q'},
#   {'version_id': '1', 'youtube_id': 'XAqo8V2QCIM'},
#   {'version_id': '2', 'youtube_id': 'NLQGHnLtAXM'},
#   {'version_id': '3', 'youtube_id': 'o1ornQ6hUVs'}],
#  '8259': [{'version_id': '0', 'youtube_id': 'u_FD2otXjiY'},
#   {'version_id': '1', 'youtube_id': 'tXyH_EpTCIM'},
#   {'version_id': '2', 'youtube_id': 'ufAn34RfyOY'},
#   {'version_id': '4', 'youtube_id': 'AjRcZqPrRoo'},
#   {'version_id': '5', 'youtube_id': 'f7GvK8G_bGw'},
#   {'version_id': '6', 'youtube_id': 'Zg0jPx9WEWk'}],
#  '8260': [{'version_id': '0', 'youtube_id': 'zJfRRaEcPVw'},
#   {'version_id': '1', 'youtube_id': 'gIUVW-d1Flc'},
#   {'version_id': '2', 'youtube_id': 's8Xeml6Ve44'},
#   {'version_id': '3', 'youtube_id': 'fticPHRdgQw'}],
#  '8262': [{'version_id': '0', 'youtube_id': 'T4veWVjCvS0'},
#   {'version_id': '1', 'youtube_id': 'C4bTCdPLDdo'},
#   {'version_id': '2', 'youtube_id': 'dZ66AW1izNA'}],
#  '8263': [{'version_id': '0', 'youtube_id': 'E6LZLz-fWpo'},
#   {'version_id': '1', 'youtube_id': 'UsHgW-6Lfvg'},
#   {'version_id': '2', 'youtube_id': 'MjVqP4JJgCw'},
#   {'version_id': '3', 'youtube_id': 'pLnvj6IqQkw'},
#   {'version_id': '4', 'youtube_id': '4tvAWJkuQAk'}],
#  '8264': [{'version_id': '0', 'youtube_id': 'USQ0bHBFCRs'},
#   {'version_id': '1', 'youtube_id': 'cJy-LFZHfBw'},
#   {'version_id': '2', 'youtube_id': 'apsEC0PAwQU'},
#   {'version_id': '3', 'youtube_id': 'qa7dLnxt2gU'},
#   {'version_id': '4', 'youtube_id': 'elp4uHkgRko'},
#   {'version_id': '5', 'youtube_id': '3AVTL2s60zw'}],
#  '8268': [{'version_id': '0', 'youtube_id': 'vlagmKjsu18'},
#   {'version_id': '1', 'youtube_id': 'JVxzut75yxo'},
#   {'version_id': '2', 'youtube_id': 'gCx3oAStT8w'},
#   {'version_id': '3', 'youtube_id': 'vP0d-GLZxrI'}],
#  '8269': [{'version_id': '0', 'youtube_id': 'DI9pXrWRbvU'},
#   {'version_id': '1', 'youtube_id': 'gIqSiwz4VHA'},
#   {'version_id': '2', 'youtube_id': '4Dwc_USEnyo'},
#   {'version_id': '3', 'youtube_id': '-SJ0MJUEKtA'},
#   {'version_id': '4', 'youtube_id': 'it_cHmmYrhE'},
#   {'version_id': '5', 'youtube_id': 'IJcKjs_GdRw'},
#   {'version_id': '6', 'youtube_id': 'Uow-RYa1vVQ'}],
#  '8270': [{'version_id': '0', 'youtube_id': 'PQRbeunfbDE'},
#   {'version_id': '1', 'youtube_id': 'NRQvxf6fNIE'},
#   {'version_id': '2', 'youtube_id': 'hNKhqKuEAjI'},
#   {'version_id': '3', 'youtube_id': 'jIapAKvhWRs'},
#   {'version_id': '4', 'youtube_id': 'gMldGaEPxjM'},
#   {'version_id': '5', 'youtube_id': '028hxIcql0U'},
#   {'version_id': '6', 'youtube_id': 'PrTDTwd0VMU'}],
#  '8271': [{'version_id': '0', 'youtube_id': 'CJYFzEjrOuw'},
#   {'version_id': '1', 'youtube_id': '28f5JGYEMFs'},
#   {'version_id': '2', 'youtube_id': '-BzIXuL_Wt8'}],
#  '8272': [{'version_id': '0', 'youtube_id': 'z1wR1hTjR-w'},
#   {'version_id': '1', 'youtube_id': '24WodCcBTmY'},
#   {'version_id': '2', 'youtube_id': 'f16a5S_mwA4'},
#   {'version_id': '3', 'youtube_id': 'zubYNHaYAKc'}],
#  '8273': [{'version_id': '0', 'youtube_id': '5ger8PgN-Os'},
#   {'version_id': '1', 'youtube_id': 'uSrf-1wTZF4'},
#   {'version_id': '3', 'youtube_id': 'H4mkN-BPolU'},
#   {'version_id': '4', 'youtube_id': 'oyuUUpHKy1k'},
#   {'version_id': '5', 'youtube_id': 'AK8SE357b7g'}],
#  '8274': [{'version_id': '0', 'youtube_id': '99cg-54ZNfo'},
#   {'version_id': '2', 'youtube_id': '9DUlzqiDa1w'},
#   {'version_id': '3', 'youtube_id': '5mAEsJjxrFs'},
#   {'version_id': '4', 'youtube_id': '9etB7o1_COk'}],
#  '8275': [{'version_id': '0', 'youtube_id': 'Qb_Uu0eTNWk'},
#   {'version_id': '1', 'youtube_id': 'gwjcXML1U7Q'},
#   {'version_id': '2', 'youtube_id': '4S1eWs0C5Ps'},
#   {'version_id': '3', 'youtube_id': 'YIrBX7Fc2BU'},
#   {'version_id': '4', 'youtube_id': 'WeUkof9a5F4'},
#   {'version_id': '5', 'youtube_id': 'JiEWAGwj7jk'},
#   {'version_id': '6', 'youtube_id': 'THSM6siFmA4'},
#   {'version_id': '7', 'youtube_id': '-tIP78nt2bg'},
#   {'version_id': '8', 'youtube_id': 'PryEJ0Q_oBM'}],
#  '8276': [{'version_id': '0', 'youtube_id': 'QlHG8nP7wK8'},
#   {'version_id': '1', 'youtube_id': 'vkTwRotEQvg'},
#   {'version_id': '2', 'youtube_id': 'G3gawILtncg'},
#   {'version_id': '3', 'youtube_id': 'JfYasUGw34w'}],
#  '8277': [{'version_id': '0', 'youtube_id': 'ErtjbLdmXgY'},
#   {'version_id': '1', 'youtube_id': 'ULyp6TUDCtE'},
#   {'version_id': '2', 'youtube_id': 'lyy04RNlAuY'},
#   {'version_id': '3', 'youtube_id': '0eWMX_M2Wlw'},
#   {'version_id': '4', 'youtube_id': 'YV2BmM46pSE'},
#   {'version_id': '5', 'youtube_id': 'aJ2jDrUC4lw'},
#   {'version_id': '6', 'youtube_id': 'qkWjdF_MBnk'},
#   {'version_id': '7', 'youtube_id': '-PZEVVBGVh4'},
#   {'version_id': '8', 'youtube_id': 'dXlr4h1P-d0'},
#   {'version_id': '9', 'youtube_id': '5UORNKJ8x1M'}],
#  '8278': [{'version_id': '0', 'youtube_id': 'W4KjHZsNSHo'},
#   {'version_id': '1', 'youtube_id': 'sZmUWnJrzco'},
#   {'version_id': '2', 'youtube_id': 'MYCpas_-MBE'},
#   {'version_id': '3', 'youtube_id': 'o-0bOXir4qk'},
#   {'version_id': '4', 'youtube_id': 'mIIzLRu6JC8'},
#   {'version_id': '5', 'youtube_id': 'f0AXjnSAMCs'},
#   {'version_id': '6', 'youtube_id': 'cbW2jX1cVWo'}],
#  '8279': [{'version_id': '0', 'youtube_id': 'AGYDTM29On4'},
#   {'version_id': '1', 'youtube_id': 'YChyzjUqZ78'},
#   {'version_id': '2', 'youtube_id': 'RDW_MvVPSG0'},
#   {'version_id': '3', 'youtube_id': '0qOxYY0dDPQ'}],
#  '8280': [{'version_id': '0', 'youtube_id': 'CgzQy-zXlVo'},
#   {'version_id': '1', 'youtube_id': '9xgAQEKINsI'},
#   {'version_id': '2', 'youtube_id': 'aW-e_y_AK8w'}],
#  '8281': [{'version_id': '0', 'youtube_id': 'i7oQWSGbgrA'},
#   {'version_id': '1', 'youtube_id': 'kibzbQnDuGw'},
#   {'version_id': '2', 'youtube_id': 'c4vvYnbkbHs'},
#   {'version_id': '3', 'youtube_id': 'yJ-011qns_c'},
#   {'version_id': '4', 'youtube_id': 'k4lfzCfyEmM'},
#   {'version_id': '5', 'youtube_id': 'A6wdSO_1Z1U'}],
#  '8282': [{'version_id': '0', 'youtube_id': 'gGJ6aH-uiyY'},
#   {'version_id': '1', 'youtube_id': 'KEhhbpXPxBg'},
#   {'version_id': '2', 'youtube_id': '8bSL8Nf6Oqk'}],
#  '8283': [{'version_id': '0', 'youtube_id': 'iN0_JdTAGtM'},
#   {'version_id': '1', 'youtube_id': 'G0KpWdSI7og'},
#   {'version_id': '2', 'youtube_id': 'xhfm7x1yy34'}],
#  '8284': [{'version_id': '0', 'youtube_id': '6W1dpAkIkc0'},
#   {'version_id': '1', 'youtube_id': 'MhJY0xpEiLY'},
#   {'version_id': '2', 'youtube_id': '7FtwoX9j39I'},
#   {'version_id': '3', 'youtube_id': 'mGgZ4N-INIk'},
#   {'version_id': '4', 'youtube_id': 'eyEmPEdrcbg'},
#   {'version_id': '5', 'youtube_id': '02U5C9Yu2pU'},
#   {'version_id': '6', 'youtube_id': 'QjK-q7ZTYgU'},
#   {'version_id': '7', 'youtube_id': 'h_n1eyb4Xe0'}],
#  '8285': [{'version_id': '0', 'youtube_id': 'J5kCKII8GZE'},
#   {'version_id': '1', 'youtube_id': 'LsCiaxPhtVY'},
#   {'version_id': '2', 'youtube_id': 'kLwQvjH7-Qw'},
#   {'version_id': '3', 'youtube_id': 'HvOzib9jL70'},
#   {'version_id': '4', 'youtube_id': 'suYaRGWITS0'},
#   {'version_id': '5', 'youtube_id': 'gPDeLNL5doo'},
#   {'version_id': '6', 'youtube_id': 'rcvLv1KSAeg'},
#   {'version_id': '7', 'youtube_id': 'Qi0qltstHCw'}],
#  '8286': [{'version_id': '0', 'youtube_id': 'Tj5F4RLdWSg'},
#   {'version_id': '1', 'youtube_id': '6R2NAhKskMA'},
#   {'version_id': '2', 'youtube_id': 'OtoOlqQYjs4'},
#   {'version_id': '3', 'youtube_id': 'C-OZG7w4mqA'}],
#  '8287': [{'version_id': '0', 'youtube_id': 'H1DgWgLp0Pg'},
#   {'version_id': '1', 'youtube_id': 'bSCt5aa09-E'},
#   {'version_id': '2', 'youtube_id': 'jCA6SypmKMY'},
#   {'version_id': '3', 'youtube_id': 'jh6IZ8q42Ig'},
#   {'version_id': '4', 'youtube_id': 'NoeotoQ0cBU'},
#   {'version_id': '5', 'youtube_id': 'SHB03LR9H_c'}],
#  '8288': [{'version_id': '0', 'youtube_id': 'UwSOtNwTavw'},
#   {'version_id': '1', 'youtube_id': 'skQznk9xO70'},
#   {'version_id': '2', 'youtube_id': 'OwJnbfl5yGw'},
#   {'version_id': '3', 'youtube_id': '9A1nwlZse6A'}],
#  '8289': [{'version_id': '0', 'youtube_id': '3wJLiKGYrWo'},
#   {'version_id': '1', 'youtube_id': 'VHjS2IWdgw8'},
#   {'version_id': '2', 'youtube_id': '0_wMl5EwZko'},
#   {'version_id': '3', 'youtube_id': 'WytCrzCanQE'}],
#  '8290': [{'version_id': '0', 'youtube_id': 'waU75jdUnYw'},
#   {'version_id': '1', 'youtube_id': 'HVzmkl-XrCI'},
#   {'version_id': '2', 'youtube_id': 'pK78VBVSn9g'},
#   {'version_id': '3', 'youtube_id': '8F4MyYn82FE'},
#   {'version_id': '4', 'youtube_id': 'Cz2NcRlVJ24'},
#   {'version_id': '5', 'youtube_id': '7VuoaBAPZkE'},
#   {'version_id': '6', 'youtube_id': '-RWl24TUW6g'},
#   {'version_id': '7', 'youtube_id': 'Br-Xvk3-wo8'},
#   {'version_id': '8', 'youtube_id': 'QW45vKsNB18'},
#   {'version_id': '9', 'youtube_id': 'OGg9PwDiXkQ'},
#   {'version_id': '10', 'youtube_id': 'LK9oQVBaL-o'},
#   {'version_id': '11', 'youtube_id': 'eHgoaUEEQAM'}],
#  '8291': [{'version_id': '0', 'youtube_id': 'YhQYtTJgrlk'},
#   {'version_id': '1', 'youtube_id': 'R9y-TP8omc8'}],
#  '8293': [{'version_id': '0', 'youtube_id': '5RnNmJ0WID4'},
#   {'version_id': '1', 'youtube_id': 'tAQUmFMy37I'},
#   {'version_id': '2', 'youtube_id': 'AuIQf2HzKhc'},
#   {'version_id': '3', 'youtube_id': 'TRtyOdFkRVs'}],
#  '8294': [{'version_id': '0', 'youtube_id': 'jdeKliAn1G8'},
#   {'version_id': '1', 'youtube_id': 'tvZlsMxQvzM'}],
#  '8295': [{'version_id': '0', 'youtube_id': 'dD5JW-7Wvgc'},
#   {'version_id': '1', 'youtube_id': 'OBAgQwivQ74'},
#   {'version_id': '2', 'youtube_id': 'xYr1HwmKSVA'},
#   {'version_id': '3', 'youtube_id': 'mq85dJoQyHA'}],
#  '8296': [{'version_id': '0', 'youtube_id': 'fxAaPi3jUqw'},
#   {'version_id': '1', 'youtube_id': 'bQJWOl1CXRg'}],
#  '8297': [{'version_id': '0', 'youtube_id': 'GJV9CN8Vi9I'},
#   {'version_id': '1', 'youtube_id': 'y6MaPSe0tfk'}],
#  '8298': [{'version_id': '0', 'youtube_id': 'HQ2DStNLXYU'},
#   {'version_id': '1', 'youtube_id': 'X-IYVH2ENLQ'},
#   {'version_id': '2', 'youtube_id': 'xdnfYoGDO0Q'}],
#  '8299': [{'version_id': '0', 'youtube_id': 'VQ_oYvOoBck'},
#   {'version_id': '1', 'youtube_id': 'daG-ggP-pgo'},
#   {'version_id': '2', 'youtube_id': 'iuINVJ3wiwI'},
#   {'version_id': '3', 'youtube_id': 'XS6qXGjTltc'},
#   {'version_id': '4', 'youtube_id': 'Ac4MT-Zew8o'}],
#  '8300': [{'version_id': '0', 'youtube_id': 'DDWKuo3gXMQ'},
#   {'version_id': '1', 'youtube_id': 'yflI92v1IDA'},
#   {'version_id': '2', 'youtube_id': 'uzMneO-GfXM'},
#   {'version_id': '3', 'youtube_id': '-rmLFGzlYU8'},
#   {'version_id': '4', 'youtube_id': 'S7SdLny4wAg'},
#   {'version_id': '5', 'youtube_id': 'Csp9h7FS1tQ'},
#   {'version_id': '6', 'youtube_id': 'mV9v7m2Gk6U'},
#   {'version_id': '7', 'youtube_id': 'Wry2NF9AYRw'},
#   {'version_id': '9', 'youtube_id': 'C7ULaQqme74'},
#   {'version_id': '10', 'youtube_id': 'QVwIOWlZSxU'},
#   {'version_id': '11', 'youtube_id': 'X086S3qOOUQ'}],
#  '8301': [{'version_id': '0', 'youtube_id': 'C3z-cz-bURM'},
#   {'version_id': '1', 'youtube_id': 'Y6O6bPUf7ow'},
#   {'version_id': '2', 'youtube_id': 'QkvP_YSbLgI'}],
#  '8302': [{'version_id': '0', 'youtube_id': '4LiiBJ4Co3Y'},
#   {'version_id': '1', 'youtube_id': 'lhZ_LQFLxuU'},
#   {'version_id': '2', 'youtube_id': 'avdkk9ibfqw'},
#   {'version_id': '3', 'youtube_id': 'Ok-ElU0jVq4'},
#   {'version_id': '4', 'youtube_id': '4o4GEz8gMak'},
#   {'version_id': '5', 'youtube_id': 'fYCCyoi2NCE'}],
#  '8303': [{'version_id': '0', 'youtube_id': 'QPHTQgj1t2E'},
#   {'version_id': '1', 'youtube_id': '7NnZZZIWoUY'},
#   {'version_id': '2', 'youtube_id': 'aqQzvymWPNA'},
#   {'version_id': '3', 'youtube_id': 'Fb2f4IFozHo'}],
#  '8304': [{'version_id': '0', 'youtube_id': 'MUxl9ftwuOA'},
#   {'version_id': '2', 'youtube_id': 'zDQlH4gw2Eo'},
#   {'version_id': '3', 'youtube_id': 'Nri7SsMkbm8'},
#   {'version_id': '5', 'youtube_id': 'LRy2T1MDx8g'},
#   {'version_id': '6', 'youtube_id': 'I0GjqWX5Tgs'}],
#  '8305': [{'version_id': '0', 'youtube_id': 'r8Kft3w-7DI'},
#   {'version_id': '1', 'youtube_id': 'aWAYDLaYm-I'},
#   {'version_id': '2', 'youtube_id': 'IjVnk_5Nbu4'},
#   {'version_id': '3', 'youtube_id': 'Gc_19GBn59E'},
#   {'version_id': '4', 'youtube_id': 'f6umd91DGfQ'},
#   {'version_id': '5', 'youtube_id': '7FHIBCpH5-8'}],
#  '8306': [{'version_id': '0', 'youtube_id': 'OtaKTqRFvS4'},
#   {'version_id': '1', 'youtube_id': 'P1BubYJuwD4'},
#   {'version_id': '2', 'youtube_id': 'kFmvxY8XC-A'},
#   {'version_id': '3', 'youtube_id': 'lWQPn6KbW-8'},
#   {'version_id': '4', 'youtube_id': 'gjb85S3FI3k'},
#   {'version_id': '5', 'youtube_id': 'MMYq_HKsHsk'},
#   {'version_id': '6', 'youtube_id': 'mSHd46cT2A8'},
#   {'version_id': '7', 'youtube_id': '7Rk14Q7h5lk'}],
#  '8307': [{'version_id': '0', 'youtube_id': 'CivvdtlZ4ok'},
#   {'version_id': '1', 'youtube_id': 'B9eaCkQdXro'},
#   {'version_id': '2', 'youtube_id': 'UclZhGviuho'},
#   {'version_id': '3', 'youtube_id': 'eWbHhCWX5xw'},
#   {'version_id': '4', 'youtube_id': 'QXga0aifMrs'},
#   {'version_id': '5', 'youtube_id': 'FWQgdR63ygg'},
#   {'version_id': '6', 'youtube_id': 'N1GveflR5Hg'},
#   {'version_id': '7', 'youtube_id': '94GoYwWF7LU'}],
#  '8309': [{'version_id': '0', 'youtube_id': 'zDEua85M_JA'},
#   {'version_id': '1', 'youtube_id': 'em-LTWDzX1o'},
#   {'version_id': '2', 'youtube_id': 'kW99bjzYojo'},
#   {'version_id': '3', 'youtube_id': 'zzKUAMqoKIo'},
#   {'version_id': '4', 'youtube_id': 'G4Rkl9mbNiA'}],
#  '8310': [{'version_id': '0', 'youtube_id': 'GTyN-DB_v5M'},
#   {'version_id': '1', 'youtube_id': 'u55h1R3OnDY'},
#   {'version_id': '2', 'youtube_id': 'EcUJCbXVna0'},
#   {'version_id': '3', 'youtube_id': 'u0mNKb48U30'},
#   {'version_id': '4', 'youtube_id': '_BLIWaEXIvc'},
#   {'version_id': '6', 'youtube_id': 'weloSHHCcVs'},
#   {'version_id': '7', 'youtube_id': 'q3BAE5w8sp0'},
#   {'version_id': '8', 'youtube_id': 'JYEyUDB_s9c'},
#   {'version_id': '9', 'youtube_id': 'C4PEN9AU_tM'},
#   {'version_id': '10', 'youtube_id': '2ho6OXljtOw'},
#   {'version_id': '11', 'youtube_id': 'OaBKv5ZNrD8'}],
#  '8311': [{'version_id': '0', 'youtube_id': 'TOhtZdINkY0'},
#   {'version_id': '1', 'youtube_id': 'IymwtswzvnQ'},
#   {'version_id': '2', 'youtube_id': 't1zxDiFFUtw'},
#   {'version_id': '3', 'youtube_id': 'pWzGuRo78cY'},
#   {'version_id': '4', 'youtube_id': '_qSZP87Oqeo'},
#   {'version_id': '5', 'youtube_id': '6TcG8yBeRNI'},
#   {'version_id': '6', 'youtube_id': 'HxAXAbXYexI'}],
#  '8312': [{'version_id': '0', 'youtube_id': 'HaMq2nn5ac0'},
#   {'version_id': '1', 'youtube_id': 'gCm9aq3W1Nc'},
#   {'version_id': '2', 'youtube_id': 'xBTd5uN-qbQ'},
#   {'version_id': '3', 'youtube_id': 'M2FhdMOd3m8'},
#   {'version_id': '4', 'youtube_id': 'nu33ZJwyYtg'},
#   {'version_id': '5', 'youtube_id': 'jS6N-iGpIK0'},
#   {'version_id': '6', 'youtube_id': '-Qf9nPIg-wA'},
#   {'version_id': '7', 'youtube_id': 'DITukj5jg1A'},
#   {'version_id': '8', 'youtube_id': 'u9yUarWRRfc'},
#   {'version_id': '9', 'youtube_id': 'mwBGGh2fhfU'},
# ...
#   {'version_id': '3', 'youtube_id': 'MT_lJ4dwCNw'},
#   {'version_id': '4', 'youtube_id': 'BoYR3_MIqlo'}],
#  '9230': [{'version_id': '0', 'youtube_id': 'Gbajf_rHzys'},
#   {'version_id': '1', 'youtube_id': 'IZlMUkEvdjs'},
#   {'version_id': '2', 'youtube_id': '3oWb7r_v40k'}],
#  '9231': [{'version_id': '0', 'youtube_id': 'hC8iFrnGoXI'},
#   {'version_id': '1', 'youtube_id': '8Lju3oj0yF8'},
#   {'version_id': '2', 'youtube_id': 'rpgLQpWvxuI'},
#   {'version_id': '3', 'youtube_id': 'WHfpjn1arvg'}],
#  '9234': [{'version_id': '0', 'youtube_id': '75nKyI2FFFI'},
#   {'version_id': '1', 'youtube_id': 'a8QhEC-4rDo'},
#   {'version_id': '2', 'youtube_id': 'vLfK7Og2MXY'},
#   {'version_id': '3', 'youtube_id': 'AI0O2vquvAI'},
#   {'version_id': '4', 'youtube_id': 'ftDHHVh4lYE'},
#   {'version_id': '5', 'youtube_id': 'IO3ZpN7hN30'}],
#  '9235': [{'version_id': '1', 'youtube_id': 'rNd7TFOMMl4'},
#   {'version_id': '2', 'youtube_id': 'vgTSu_zyuLo'},
#   {'version_id': '3', 'youtube_id': 'MOtFA4FEXvY'},
#   {'version_id': '4', 'youtube_id': 'B4eMqY2S7mg'}],
#  '9236': [{'version_id': '0', 'youtube_id': '5Syrv3c4-nQ'},
#   {'version_id': '1', 'youtube_id': 'aPSt2OcKPaY'}],
#  '9237': [{'version_id': '0', 'youtube_id': 'pjsh2j7W6Bo'},
#   {'version_id': '1', 'youtube_id': 'Nl9QIN2zY-4'},
#   {'version_id': '2', 'youtube_id': '4ZULzZnQFok'},
#   {'version_id': '3', 'youtube_id': '1zcie5BFSGs'},
#   {'version_id': '4', 'youtube_id': 'iYk4npajOB4'},
#   {'version_id': '5', 'youtube_id': 'Xeit5k_AGCM'}],
#  '9238': [{'version_id': '0', 'youtube_id': 'dUA9FUTieKA'},
#   {'version_id': '1', 'youtube_id': 'yfDhxvqJVRg'}],
#  '9239': [{'version_id': '0', 'youtube_id': '14ODdLv8ATA'},
#   {'version_id': '1', 'youtube_id': 'vu5OS9nuKuI'},
#   {'version_id': '2', 'youtube_id': 'x9nWQp6GDrA'},
#   {'version_id': '3', 'youtube_id': 'r-Ouax0gmgw'},
#   {'version_id': '4', 'youtube_id': '11FxoDMKa2k'}],
#  '9240': [{'version_id': '0', 'youtube_id': 'G4BjddGS4Dc'},
#   {'version_id': '1', 'youtube_id': 'fnjOFcqlfSI'},
#   {'version_id': '2', 'youtube_id': 'icmD_L21vYs'},
#   {'version_id': '3', 'youtube_id': 'Sf6JHsksWhs'},
#   {'version_id': '4', 'youtube_id': 'KfiHiiBx1Fs'},
#   {'version_id': '5', 'youtube_id': 'r6zPc-94ZVg'},
#   {'version_id': '6', 'youtube_id': 'mDZ4EGKu98A'},
#   {'version_id': '7', 'youtube_id': 'MaMAQ5mMhvo'}],
#  '9241': [{'version_id': '0', 'youtube_id': '999RqGZatPs'},
#   {'version_id': '1', 'youtube_id': '5M0nKL8NFJc'}],
#  '9242': [{'version_id': '0', 'youtube_id': '2IrOUF44SoM'},
#   {'version_id': '1', 'youtube_id': 'm9N8aHgCrQs'},
#   {'version_id': '2', 'youtube_id': 't7hUy1C-tzg'},
#   {'version_id': '4', 'youtube_id': 'b8YcD37XkJ8'},
#   {'version_id': '5', 'youtube_id': 'qXgBD_unpLs'}],
#  '9243': [{'version_id': '0', 'youtube_id': 'gdlhMrHMcRc'},
#   {'version_id': '1', 'youtube_id': 'I-Q8m7zih5o'},
#   {'version_id': '2', 'youtube_id': 'GceKhb6zd0w'},
#   {'version_id': '3', 'youtube_id': 'ykYXt-xyBjI'},
#   {'version_id': '4', 'youtube_id': 'IYIxyCEb3iM'}],
#  '9244': [{'version_id': '0', 'youtube_id': 'N2ICtCO8TCw'},
#   {'version_id': '1', 'youtube_id': '_VrvhvJ31tE'},
#   {'version_id': '2', 'youtube_id': '-MkIpjbR3Lk'},
#   {'version_id': '3', 'youtube_id': 'gVSl1OcZzKI'},
#   {'version_id': '4', 'youtube_id': 'eLGiTV2oP10'},
#   {'version_id': '5', 'youtube_id': 'fAKm7JWZ2xI'}],
#  '9245': [{'version_id': '0', 'youtube_id': 'V6Dfo4zDduI'},
#   {'version_id': '1', 'youtube_id': 'EKQYkkrJKEI'},
#   {'version_id': '2', 'youtube_id': 'o0LHG2LGtXM'},
#   {'version_id': '3', 'youtube_id': 'miQ24KKqFUE'},
#   {'version_id': '4', 'youtube_id': 'XFq9Wz3vCMY'},
#   {'version_id': '5', 'youtube_id': 'X_AWQMYCiZ0'},
#   {'version_id': '6', 'youtube_id': 'LfMPuX2tIcQ'},
#   {'version_id': '7', 'youtube_id': 'MKe453nMVY4'},
#   {'version_id': '8', 'youtube_id': 'tDJj_nKFTKo'}],
#  '9246': [{'version_id': '0', 'youtube_id': 'tj_IrcmaWZo'},
#   {'version_id': '1', 'youtube_id': 'TnROUOT7RPc'},
#   {'version_id': '2', 'youtube_id': 'hVbPLGXocyg'},
#   {'version_id': '3', 'youtube_id': 'Zj136hYpSrc'},
#   {'version_id': '4', 'youtube_id': 'WfbL1DFB95k'},
#   {'version_id': '5', 'youtube_id': 'x_ZT6Qir2LA'},
#   {'version_id': '6', 'youtube_id': 'SoL1L4ImtaY'}],
#  '9248': [{'version_id': '0', 'youtube_id': 'pXSXzlY0Mks'},
#   {'version_id': '1', 'youtube_id': 'qZSHsB6Sjlc'},
#   {'version_id': '2', 'youtube_id': 'EGNhLHEX_78'},
#   {'version_id': '3', 'youtube_id': 'C9uTDV5lp_o'},
#   {'version_id': '4', 'youtube_id': '22wz1O1gnYY'}],
#  '9249': [{'version_id': '0', 'youtube_id': 'seRjsq-FrjE'},
#   {'version_id': '1', 'youtube_id': 'xqPEFcYW7e8'},
#   {'version_id': '2', 'youtube_id': '0ADy3DZL2iY'},
#   {'version_id': '3', 'youtube_id': 'zL6uvdPskiY'},
#   {'version_id': '4', 'youtube_id': 'JrJVY3oZPsE'},
#   {'version_id': '5', 'youtube_id': 'Q_lRkkz2o1Y'}],
#  '9251': [{'version_id': '0', 'youtube_id': 'yc2C0iNinkE'},
#   {'version_id': '1', 'youtube_id': '06DgSEKP1yo'}],
#  '9252': [{'version_id': '0', 'youtube_id': 'iwwyc_ZMPrI'},
#   {'version_id': '2', 'youtube_id': '6mdKC7el_ok'},
#   {'version_id': '3', 'youtube_id': 'sXvOTCRcY24'},
#   {'version_id': '4', 'youtube_id': 'TyQP5NQPxug'},
#   {'version_id': '5', 'youtube_id': 'Ot1KtDQrH_0'}],
#  '9253': [{'version_id': '0', 'youtube_id': 'WZtfsfoKSB0'},
#   {'version_id': '1', 'youtube_id': 'hIuQCOhp0Nk'},
#   {'version_id': '2', 'youtube_id': 'ZFrSwZueGIA'},
#   {'version_id': '3', 'youtube_id': '-nDICOrPydE'},
#   {'version_id': '4', 'youtube_id': 'gnCa-j4O0Yk'},
#   {'version_id': '5', 'youtube_id': 'YkFeazgWBzs'},
#   {'version_id': '6', 'youtube_id': 'mBrI5nRUK8Y'},
#   {'version_id': '7', 'youtube_id': 'PskXxX8rxrI'}],
#  '9254': [{'version_id': '0', 'youtube_id': 'LI7NDDQLvbo'},
#   {'version_id': '1', 'youtube_id': 'OiAyLwqVmyY'},
#   {'version_id': '2', 'youtube_id': 'jNRINGFbXI4'},
#   {'version_id': '3', 'youtube_id': 'pja3zT3d1hw'}],
#  '9255': [{'version_id': '0', 'youtube_id': 'OYJgOt0RQfQ'},
#   {'version_id': '1', 'youtube_id': 'vOrqXX78E68'},
#   {'version_id': '2', 'youtube_id': 'mLmdvOzAvSM'},
#   {'version_id': '3', 'youtube_id': 'n0nkJWF4awc'},
#   {'version_id': '5', 'youtube_id': '6WssngbaSoI'}],
#  '9256': [{'version_id': '0', 'youtube_id': 'O7dGfv87fh4'},
#   {'version_id': '1', 'youtube_id': '4K0GWKJdE58'},
#   {'version_id': '2', 'youtube_id': 'YyChmkPKi0I'},
#   {'version_id': '3', 'youtube_id': 'Q4K_1zmBbY0'},
#   {'version_id': '4', 'youtube_id': 'DJPYtAFoAxQ'},
#   {'version_id': '5', 'youtube_id': '3GjJQDlkEWw'}],
#  '9257': [{'version_id': '0', 'youtube_id': 'god7hAPv8f0'},
#   {'version_id': '1', 'youtube_id': 'Cr1C5Dfcvxg'},
#   {'version_id': '3', 'youtube_id': 'xPOZ4Admhjo'}],
#  '9258': [{'version_id': '0', 'youtube_id': 'uDwkk-rKhAo'},
#   {'version_id': '1', 'youtube_id': 'O7CcXZ9C4Zg'},
#   {'version_id': '2', 'youtube_id': 'uoLZWWGM0EI'},
#   {'version_id': '3', 'youtube_id': 'zvzJ39m4vsA'},
#   {'version_id': '4', 'youtube_id': 'wfdp10r2jxI'}],
#  '9259': [{'version_id': '0', 'youtube_id': 'e2efTlU36Tw'},
#   {'version_id': '1', 'youtube_id': 'ujRJtRhdlqs'},
#   {'version_id': '2', 'youtube_id': '1_zDqwIqNcA'}],
#  '9260': [{'version_id': '0', 'youtube_id': 'sQgd6MccwZc'},
#   {'version_id': '2', 'youtube_id': 'QzwXoz4kD7I'},
#   {'version_id': '3', 'youtube_id': '9YZXPs8uAB0'},
#   {'version_id': '4', 'youtube_id': 'XyfyDBj-ZIw'},
#   {'version_id': '5', 'youtube_id': '5EUkzdrjGWM'}],
#  '9262': [{'version_id': '0', 'youtube_id': 'ulor0uSkBCA'},
#   {'version_id': '1', 'youtube_id': 'BQ6vHM48F9s'},
#   {'version_id': '2', 'youtube_id': '1FicNsc4Nrs'}],
#  '9263': [{'version_id': '0', 'youtube_id': 's1ysoohV_zA'},
#   {'version_id': '1', 'youtube_id': 'PkoUvJDjFI8'},
#   {'version_id': '3', 'youtube_id': 'RKOMnShm1wQ'},
#   {'version_id': '4', 'youtube_id': 'FlPYXakEpi4'},
#   {'version_id': '5', 'youtube_id': 'AFJBZgvbMiU'},
#   {'version_id': '6', 'youtube_id': 'lKhnkRAFalc'}],
#  '9264': [{'version_id': '0', 'youtube_id': 'oqb4yW_75NE'},
#   {'version_id': '1', 'youtube_id': 'DNsgPKSfV6U'},
#   {'version_id': '2', 'youtube_id': 'NNyVmGzldj4'},
#   {'version_id': '3', 'youtube_id': 'hqkoTCkOsFk'},
#   {'version_id': '4', 'youtube_id': 'JeW-viROWNQ'}],
#  '9266': [{'version_id': '0', 'youtube_id': 'R1mioO_EQzU'},
#   {'version_id': '1', 'youtube_id': 'osXrF_jMALU'}],
#  '9267': [{'version_id': '0', 'youtube_id': '5YXVMCHG-Nk'},
#   {'version_id': '1', 'youtube_id': 'eFYYkNacjaw'},
#   {'version_id': '2', 'youtube_id': 'tbtBqhIRgkc'},
#   {'version_id': '3', 'youtube_id': 'eyni32LvWm4'},
#   {'version_id': '4', 'youtube_id': 'em4GdXx05aQ'},
#   {'version_id': '5', 'youtube_id': '4m4ggdBcdyI'},
#   {'version_id': '6', 'youtube_id': 'yNPvR6JGBrU'},
#   {'version_id': '7', 'youtube_id': '3rn2N0ZbLEQ'}],
#  '9268': [{'version_id': '0', 'youtube_id': 'PSzDgKLm3tI'},
#   {'version_id': '1', 'youtube_id': '2TpU6JC--34'},
#   {'version_id': '2', 'youtube_id': 'Cjkjb70dSBI'},
#   {'version_id': '3', 'youtube_id': 'dlHZgKqApjU'},
#   {'version_id': '4', 'youtube_id': 'jQ82uYXLRFo'}],
#  '9269': [{'version_id': '0', 'youtube_id': 'skjvDLpeh4c'},
#   {'version_id': '1', 'youtube_id': 'LJRtu6M6D6o'},
#   {'version_id': '2', 'youtube_id': 'ItkUN1FOERI'},
#   {'version_id': '3', 'youtube_id': 'R9r0R0xUDio'},
#   {'version_id': '5', 'youtube_id': 'a51_ede8C0c'},
#   {'version_id': '6', 'youtube_id': 'aXMZXG8t9iw'},
#   {'version_id': '7', 'youtube_id': 'wA88nzb9j_k'},
#   {'version_id': '8', 'youtube_id': 'V9HOlr0SA2g'},
#   {'version_id': '9', 'youtube_id': 'R4_nP7erBK4'}],
#  '9270': [{'version_id': '0', 'youtube_id': 'F9ARcLTcqoA'},
#   {'version_id': '1', 'youtube_id': 'JSZkaIaVIpE'}],
#  '9271': [{'version_id': '1', 'youtube_id': 'Hvr-d0hAXGs'},
#   {'version_id': '2', 'youtube_id': '5z3l6WgB1hU'},
#   {'version_id': '3', 'youtube_id': 'eJybbSRB464'},
#   {'version_id': '4', 'youtube_id': 'OBE03CFrMIA'},
#   {'version_id': '5', 'youtube_id': '9LQmfXpHWuc'}],
#  '9272': [{'version_id': '0', 'youtube_id': '9cieEFXxNpw'},
#   {'version_id': '1', 'youtube_id': 'gFUYl41gakA'}],
#  '9273': [{'version_id': '0', 'youtube_id': 'kMZPKmY-vXI'},
#   {'version_id': '1', 'youtube_id': 'Nru_-IerpbE'},
#   {'version_id': '2', 'youtube_id': 'qSFsU0j0bAg'},
#   {'version_id': '3', 'youtube_id': 'wk8GZfvr2pc'},
#   {'version_id': '4', 'youtube_id': 'Ts9jsHLuu2g'},
#   {'version_id': '5', 'youtube_id': 'G13JMNkJrQs'}],
#  '9274': [{'version_id': '0', 'youtube_id': 'pWNW0oBTviY'},
#   {'version_id': '1', 'youtube_id': 'gg7l24XCEQY'},
#   {'version_id': '2', 'youtube_id': 'phZoLVQ5WMk'}],
#  '9275': [{'version_id': '0', 'youtube_id': 'nwZlXoJ4dBU'},
#   {'version_id': '1', 'youtube_id': '59zR8qSqaXg'},
#   {'version_id': '2', 'youtube_id': 's3zo30z2Gfs'},
#   {'version_id': '3', 'youtube_id': 'QGweoCvcfq8'},
#   {'version_id': '4', 'youtube_id': 'Esm5NfSDLKU'},
#   {'version_id': '5', 'youtube_id': 'Y-V47lupTKE'},
#   {'version_id': '6', 'youtube_id': 'T6MB0PF9FO8'},
#   {'version_id': '7', 'youtube_id': 'unaizfFeVUg'}],
#  '9277': [{'version_id': '0', 'youtube_id': 'AVUOtH8feoI'},
#   {'version_id': '1', 'youtube_id': 'rqwLq41SfYo'},
#   {'version_id': '2', 'youtube_id': 'VX6DWpsHLt8'},
#   {'version_id': '3', 'youtube_id': 'LOn7OX7CFp4'},
#   {'version_id': '4', 'youtube_id': 'GH4Fjw8CYzU'},
#   {'version_id': '5', 'youtube_id': 'He87aY7PfEE'}],
#  '9281': [{'version_id': '0', 'youtube_id': 'AkPI0ot6OuA'},
#   {'version_id': '1', 'youtube_id': 'QeeHi7VyjO8'},
#   {'version_id': '2', 'youtube_id': 'w7LqmIY5qT8'}],
#  '9282': [{'version_id': '0', 'youtube_id': '-Ny42Mdg5qo'},
#   {'version_id': '1', 'youtube_id': 'mQRIobXjeNc'},
#   {'version_id': '2', 'youtube_id': 'na1SOeuFfMM'},
#   {'version_id': '3', 'youtube_id': 'WiNglWDrfXI'},
#   {'version_id': '4', 'youtube_id': 'VDFwB8HMmck'}],
#  '9283': [{'version_id': '0', 'youtube_id': '3RA4MykPm4s'},
#   {'version_id': '1', 'youtube_id': 'zaE-sBJQixg'},
#   {'version_id': '2', 'youtube_id': 'jiSfmus4EUg'}],
#  '9284': [{'version_id': '0', 'youtube_id': 'JFbS_nVA-KI'},
#   {'version_id': '1', 'youtube_id': 'QdMxaTlvx38'},
#   {'version_id': '2', 'youtube_id': '6ataRbD07uI'},
#   {'version_id': '5', 'youtube_id': 'WIsdCAMoIxk'}],
#  '9285': [{'version_id': '0', 'youtube_id': 'xE8TuBObEYc'},
#   {'version_id': '1', 'youtube_id': 'jwSylBTXrJg'},
#   {'version_id': '2', 'youtube_id': 'OoktzdzCwMg'},
#   {'version_id': '3', 'youtube_id': 'gUIlj2iHLsw'},
#   {'version_id': '5', 'youtube_id': 'wwUh7OVKFxQ'}],
#  '9286': [{'version_id': '0', 'youtube_id': 'KBw4YuBylvs'},
#   {'version_id': '1', 'youtube_id': 'g_DHNDWoR0c'},
#   {'version_id': '2', 'youtube_id': '3seWkNbyKMs'},
#   {'version_id': '3', 'youtube_id': 'fIQECx5X6h4'},
#   {'version_id': '4', 'youtube_id': 'YKuY2Ebe4So'}],
#  '9287': [{'version_id': '0', 'youtube_id': 'L1AkYgBTc4M'},
#   {'version_id': '1', 'youtube_id': 'xLhbwX_fqFc'},
#   {'version_id': '2', 'youtube_id': 'It_PCrARLkc'},
#   {'version_id': '3', 'youtube_id': '7IOjvcRX_U4'},
#   {'version_id': '4', 'youtube_id': 'YjU_-ViIAvA'},
#   {'version_id': '5', 'youtube_id': 'Xr4hjzzq2Gw'},
#   {'version_id': '6', 'youtube_id': 'Yk4VrbhlNPI'}],
#  '9288': [{'version_id': '0', 'youtube_id': 'e9fQ23UXMCE'},
#   {'version_id': '1', 'youtube_id': 'nL-pTNR3J7w'},
#   {'version_id': '2', 'youtube_id': 'HrT3DuZws70'},
#   {'version_id': '3', 'youtube_id': '6tXgiGw2FDY'},
#   {'version_id': '4', 'youtube_id': 'pwUV4_oLi_I'},
#   {'version_id': '5', 'youtube_id': 'blXlb1EIDKY'}],
#  '9290': [{'version_id': '0', 'youtube_id': '3uoycFzgSJE'},
#   {'version_id': '1', 'youtube_id': '05HUX96XCKY'}],
#  '9291': [{'version_id': '0', 'youtube_id': '8iwBM_YB1sE'},
#   {'version_id': '1', 'youtube_id': 'CAPofYaXuPs'},
#   {'version_id': '2', 'youtube_id': 'Q00Rzwv1xaQ'},
#   {'version_id': '3', 'youtube_id': 'rLV1P3PZgMs'},
#   {'version_id': '4', 'youtube_id': 'TZ4JHO-Ji-4'}],
#  '9292': [{'version_id': '0', 'youtube_id': '_MYf383fxgI'},
#   {'version_id': '1', 'youtube_id': 'e2EwRvi36Us'},
#   {'version_id': '2', 'youtube_id': 'Eq40A9fzvE0'}],
#  '9294': [{'version_id': '0', 'youtube_id': 'M6NUFE-GYfs'},
#   {'version_id': '1', 'youtube_id': '-UM-fKjkAT4'},
#   {'version_id': '2', 'youtube_id': 'dc6rhw4mMP4'},
#   {'version_id': '3', 'youtube_id': 'yQQq8bP9goY'},
#   {'version_id': '4', 'youtube_id': 'Cpa8edf8-y0'}],
#  '9295': [{'version_id': '0', 'youtube_id': 'sTj6qCtkemE'},
#   {'version_id': '1', 'youtube_id': 'ixLm9eSYldE'},
#   {'version_id': '2', 'youtube_id': 'aPF4VMdfN74'},
#   {'version_id': '3', 'youtube_id': '1WHCoSMLzlM'},
#   {'version_id': '4', 'youtube_id': 'Sz5-2QR-beY'}],
#  '9296': [{'version_id': '0', 'youtube_id': '1Wchf-j0HPk'},
#   {'version_id': '1', 'youtube_id': 'wTiOS5Pqgm8'},
#   {'version_id': '2', 'youtube_id': '1EApuW1S9pw'},
#   {'version_id': '3', 'youtube_id': 'NN_iqUHK5WE'},
#   {'version_id': '4', 'youtube_id': 'eTruJjnT02c'},
#   {'version_id': '5', 'youtube_id': '8XUsBkdN7Zs'}],
#  '9297': [{'version_id': '1', 'youtube_id': '9PlIxqv7_EA'},
#   {'version_id': '2', 'youtube_id': 'N0-OAxA8Gn8'},
#   {'version_id': '3', 'youtube_id': 'cVNQUonGS0Y'},
#   {'version_id': '4', 'youtube_id': 'KWHtpIDEAaM'},
#   {'version_id': '5', 'youtube_id': 'AIeO6fo1K2o'}],
#  '9298': [{'version_id': '0', 'youtube_id': 'hNNZz3zhnFM'},
#   {'version_id': '1', 'youtube_id': 'rP43WjIWXfE'},
#   {'version_id': '2', 'youtube_id': '9YCZVeIJ8xk'},
#   {'version_id': '3', 'youtube_id': 'O-EHyyIvKEk'},
#   {'version_id': '4', 'youtube_id': 'vqK0xOJb4jg'},
#   {'version_id': '5', 'youtube_id': 'VZwjPIBOtcg'},
#   {'version_id': '6', 'youtube_id': 'pFtXIGBjUyM'},
#   {'version_id': '7', 'youtube_id': 'yaKULv0pZck'}],
#  '9299': [{'version_id': '0', 'youtube_id': 's2HUW1cSfZA'},
#   {'version_id': '1', 'youtube_id': 'UK5MdPRd8_U'},
#   {'version_id': '2', 'youtube_id': '4MjmpjKdf3Y'},
#   {'version_id': '3', 'youtube_id': 'yA-G81xJT3U'},
#   {'version_id': '4', 'youtube_id': 'qjQUblWNy6E'},
#   {'version_id': '5', 'youtube_id': 'dcEM-PB7iYE'},
#   {'version_id': '6', 'youtube_id': 'cIcTgJx-EyQ'},
#   {'version_id': '7', 'youtube_id': 'jXEAVDkUVAQ'},
#   {'version_id': '8', 'youtube_id': 'v4LHFNhSCaI'}],
#  '9301': [{'version_id': '0', 'youtube_id': 'en5GVo2kxtA'},
#   {'version_id': '1', 'youtube_id': 'YQqnAiIQTQQ'},
#   {'version_id': '2', 'youtube_id': 'VEXKZfiWfzY'},
#   {'version_id': '3', 'youtube_id': 'Uzr3xFNeiC8'},
#   {'version_id': '4', 'youtube_id': '3PQYLiGS2oA'}],
#  '9302': [{'version_id': '0', 'youtube_id': 'f4584NjU2vU'},
#   {'version_id': '1', 'youtube_id': 'U2X4GJ0E5ck'},
#   {'version_id': '2', 'youtube_id': 'mcn9viqwO2U'}],
#  ...}

# %%
with open(shs100k_test_cliques_json_path, 'w') as out_f:
    json.dump(shs_test_cliques, out_f)

# %% [markdown]
# ## Analyze
#
# This part is just for inspection

# %% [markdown]
# ### Discogs-VI-YT

# %%
discogs_vi_yt_artist_ids_single = set()
discogs_vi_yt_artist_ids_all = set()

with open(discogs_vi_yt_json, encoding='utf-8') as in_f:
    for jline in in_f:
        clique = json.loads(jline)
        for version in clique['versions']:

            track = version['tracks'][0]
            artist_id = track["track_artist_ids"][0] if len(track["track_artist_ids"])>0 else track['release_artist_ids'][0]
            discogs_vi_yt_artist_ids_single.add(int(artist_id))
            feat_artist_ids = track.get("track_feat_ids", [])
            if len(feat_artist_ids) > 0:
                discogs_vi_yt_artist_ids_single.add(int(feat_artist_ids[0]))

            for track in version['tracks']:
                artist_ids = track["track_artist_ids"] if len(track["track_artist_ids"])>0 else track['release_artist_ids']
                artist_ids = {int(_id) for _id in artist_ids}
                discogs_vi_yt_artist_ids_all.update(artist_ids)
                feat_artist_ids = track.get("track_feat_ids", [])
                feat_artist_ids = {int(_id) for _id in feat_artist_ids}
                discogs_vi_yt_artist_ids_all.update(feat_artist_ids)

print(len(discogs_vi_yt_artist_ids_single))
print(len(discogs_vi_yt_artist_ids_all))
# Out:
# 67345
# 74928

# %%
discogs_vi_artist_ids_single = set()
discogs_vi_artist_ids_all = set()

with open(discogs_vi_json, encoding='utf-8') as in_f:
    for jline in in_f:
        clique = json.loads(jline)
        for version in clique['versions']:
            track = version['tracks'][0]
            artist_id = track["track_artist_ids"][0] if len(track["track_artist_ids"])>0 else track['release_artist_ids'][0]
            discogs_vi_artist_ids_single.add(int(artist_id))
            feat_artist_ids = track.get("track_feat_ids", [])
            if len(feat_artist_ids) > 0:
                discogs_vi_artist_ids_single.add(int(feat_artist_ids[0]))

            for track in version['tracks']:
                artist_ids = track["track_artist_ids"] if len(track["track_artist_ids"])>0 else track['release_artist_ids']
                artist_ids = {int(_id) for _id in artist_ids}
                discogs_vi_artist_ids_all.update(artist_ids)
                feat_artist_ids = track.get("track_feat_ids", [])
                feat_artist_ids = {int(_id) for _id in feat_artist_ids}
                discogs_vi_artist_ids_all.update(feat_artist_ids)
print(len(discogs_vi_artist_ids_single))
print(len(discogs_vi_artist_ids_all))
# Out:
# 239949
# 271152

# %% [markdown]
# ### Da-TACOS

# %%
with open(datacos_benchmark_json_path) as f:
    benchmark_json = json.load(f)

works = list(benchmark_json.keys())
print(f'Found {len(works)} works in benchmark subset')
# Out:
# Found 3000 works in benchmark subset

# %%
datacos_artists = set()
for work, performances in benchmark_json.items():
    if len(performances) == 1:
        continue
    for performance in performances.values():
        datacos_artists.add(performance['perf_artist'])
print(len(datacos_artists))
# Out:
# 6375

# %%
noise_work_ids, music_work_ids = [], []
for work, performences in benchmark_json.items():
    # print(f'Work: {work} {len(performences)} performences')
    if len(performences) == 1:
        noise_work_ids.append(work)
    else:
        music_work_ids.append(work)
print(f'Found {len(noise_work_ids)} noise works and {len(music_work_ids)} music works')

# %%
for noise_work_id in noise_work_ids:
    if len(benchmark_json[noise_work_id]) > 1:
        print('Error: Noise work has more than 1 performance')
        continue

# %%
benchmark_json[noise_work_id]

# %%
mismatches = defaultdict(list)
for work_id, performances_dict in benchmark_json.items():
    for performance_id, performance in performances_dict.items():
        if performance['perf_title'] != performance['work_title']:
            if performance['perf_title'] not in mismatches[performance['work_title']]:
                mismatches[performance['work_title']].append(performance['perf_title'])
            #print(performance['perf_title'], performance['work_title'])

# %%
mismatches

# %%
for work_id, performances_dict in benchmark_json.items():
    for performance_id, performance in performances_dict.items():
        print(performance['work_artist'])

# %% [markdown]
# ### SHS100K

# %%
# Read the csv file it is tab separated
with open(shs100k_csv_path, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    shs100k_data = list(reader)

# %%
shs100k_data
# Out:
# [['0',
#   '0',
#   'Summertime',
#   'Abbie Mitchell',
#   'https://www.youtube.com/watch?v=TMHWEcSKEPI',
#   'True'],
#  ['0',
#   '1',
#   'Summertime',
#   'Helen Jepson',
#   'https://www.youtube.com/watch?v=E3lw8gaHs04',
#   'True'],
#  ['0',
#   '2',
#   'Summertime',
#   'Billie Holiday and Her Orchestra',
#   'https://www.youtube.com/watch?v=aPpJPTJc1lU',
#   'True'],
#  ['0',
#   '3',
#   'Summertime',
#   'Jerry Kruger and Her Orchestra',
#   'https://www.youtube.com/watch?v=J9JctRqcDso',
#   'True'],
#  ['0',
#   '4',
#   'Overture and Summertime',
#   'Anne Brown',
#   'https://www.youtube.com/watch?v=R44waInkjgI',
#   'True'],
#  ['0',
#   '5',
#   'Summertime',
#   'Saunders King Rhythm',
#   'https://www.youtube.com/watch?v=NPRSkMIqgQA',
#   'True'],
#  ['0',
#   '6',
#   'Summertime',
#   'The Ravens',
#   'https://www.youtube.com/watch?v=piVtpRkhJTA',
#   'True'],
#  ['0',
#   '7',
#   'Summertime',
#   'Ethel Waters',
#   'https://www.youtube.com/watch?v=YU0Ip_AefMQ',
#   'True'],
#  ['0',
#   '8',
#   'Summertime',
#   'Jane Powell',
#   'https://www.youtube.com/watch?v=1me2dpYihvM',
#   'True'],
#  ['0',
#   '9',
#   'Summertime',
#   'Sarah Vaughan',
#   'https://www.youtube.com/watch?v=lOSbLk7ugcA',
#   'True'],
#  ['0',
#   '10',
#   'Summertime',
#   'Little Esther',
#   'https://www.youtube.com/watch?v=b-31DtAaE_4',
#   'True'],
#  ['0',
#   '11',
#   'Summertime',
#   'Red Saunders and His Orchestra',
#   'https://www.youtube.com/watch?v=JSJjWsuk3tI',
#   'True'],
#  ['0',
#   '12',
#   'Summertime',
#   'Frances Faye',
#   'https://www.youtube.com/watch?v=4-f0hvHT43Q',
#   'True'],
#  ['0',
#   '13',
#   'Summertime',
#   "The Hi-Lo's",
#   'https://www.youtube.com/watch?v=V9l8GQ2z54U',
#   'True'],
#  ['0',
#   '14',
#   'Summertime/Sometimes I Feel Like a Motherless Child',
#   'Mahalia Jackson',
#   'https://www.youtube.com/watch?v=mc2vVPV_ZTQ',
#   'True'],
#  ['0',
#   '15',
#   'Summertime',
#   'Jimmy Randolph with Hugo Peretti and His Orchestra',
#   'https://www.youtube.com/watch?v=L118-8TOEsg',
#   'True'],
#  ['0',
#   '16',
#   'Summertime',
#   'Georgie Auld',
#   'https://www.youtube.com/watch?v=ZbfCLcFhEXM',
#   'True'],
#  ['0',
#   '17',
#   'Summertime',
#   'Sam Cooke & Bumps Blackwell Orchestra',
#   'https://www.youtube.com/watch?v=srPdCjNN_aQ',
#   'True'],
#  ['0',
#   '18',
#   'Summertime',
#   'Jesse Belvin',
#   'https://www.youtube.com/watch?v=PsA8Wkz2pS4',
#   'True'],
#  ['0',
#   '19',
#   'Summertime',
#   'Ella Fitzgerald & Louis Armstrong',
#   'https://www.youtube.com/watch?v=MIDOEsQL7lA',
#   'True'],
#  ['0',
#   '20',
#   'Summertime',
#   'Dakota Staton',
#   'https://www.youtube.com/watch?v=u2EqNEAlmXw',
#   'True'],
#  ['0',
#   '21',
#   'Summertime',
#   'Lena Horne',
#   'https://www.youtube.com/watch?v=EIHPHMUZoq0',
#   'True'],
#  ['0',
#   '22',
#   'Summertime',
#   'Lana Bittencourt',
#   'https://www.youtube.com/watch?v=MD11HICT2sw',
#   'True'],
#  ['0',
#   '23',
#   'Summertime',
#   'Clara Ward',
#   'https://www.youtube.com/watch?v=CTgVVQYokks',
#   'True'],
#  ['0',
#   '24',
#   'Summertime',
#   'Jimmie Rodgers [1]',
#   'https://www.youtube.com/watch?v=NytUFajJ66Q',
#   'True'],
#  ['0',
#   '25',
#   'Summertime',
#   'Carmen McRae',
#   'https://www.youtube.com/watch?v=TT1iTl7r1g0',
#   'True'],
#  ['0',
#   '26',
#   'Summertime',
#   'Sylvie Mora, Arrangement and Orchestra Conducted by Russell Garcia',
#   'https://www.youtube.com/watch?v=aS7KkD0Q-m8',
#   'True'],
#  ['0',
#   '27',
#   'Summertime',
#   'Nina Simone',
#   'https://www.youtube.com/watch?v=MmrUrEbaYWE',
#   'True'],
#  ['0',
#   '28',
#   'Summertime',
#   'Ella Fitzgerald',
#   'https://www.youtube.com/watch?v=6pdyiK5kziw',
#   'True'],
#  ['0',
#   '29',
#   'Summertime',
#   'Rita Reys and The Pim Jacobs Trio',
#   'https://www.youtube.com/watch?v=iJg7VlEu0yA',
#   'True'],
#  ['0',
#   '30',
#   'Summertime',
#   'Jimmy Ricks',
#   'https://www.youtube.com/watch?v=0wfyQJq5aEk',
#   'True'],
#  ['0',
#   '31',
#   'Summertime',
#   'Carolyn Hester',
#   'https://www.youtube.com/watch?v=QFvzIo6cK5s',
#   'True'],
#  ['0',
#   '32',
#   'Summertime',
#   'The Marcels',
#   'https://www.youtube.com/watch?v=jHPArBRZdr0',
#   'True'],
#  ['0',
#   '33',
#   'Summertime',
#   'Lonnie Johnson',
#   'https://www.youtube.com/watch?v=HPnnA7R_avQ',
#   'True'],
#  ['0',
#   '34',
#   'Summertime',
#   'The Platters',
#   'https://www.youtube.com/watch?v=p7xIkBGFTec',
#   'True'],
#  ['0',
#   '35',
#   'Summertime',
#   'Lloyd Price',
#   'https://www.youtube.com/watch?v=QYacdWrKZ34',
#   'True'],
#  ['0',
#   '36',
#   'Summer Time',
#   'Little G',
#   'https://www.youtube.com/watch?v=qz4cfihFlh8',
#   'True'],
#  ['0',
#   '37',
#   'Summertime',
#   'Rick Nelson',
#   'https://www.youtube.com/watch?v=izsVZup02-4',
#   'True'],
#  ['0',
#   '38',
#   'Summertime',
#   'The Ventures',
#   'https://www.youtube.com/watch?v=LcZCATEmlk8',
#   'True'],
#  ['0',
#   '39',
#   'Summertime',
#   'The Chantels with Sammy Lowe Orch.',
#   'https://www.youtube.com/watch?v=MzWVxplaShs',
#   'True'],
#  ['0',
#   '40',
#   'Summertime',
#   'Dickie Loader & The Blue Jeans',
#   'https://www.youtube.com/watch?v=C6O5RyqsW6I',
#   'True'],
#  ['0',
#   '41',
#   'Summertime',
#   'Vi Redd',
#   'https://www.youtube.com/watch?v=3CT4pnmg-Qk',
#   'False'],
#  ['0',
#   '42',
#   'Summertime',
#   'Marty Robbins',
#   'https://www.youtube.com/watch?v=lhzXGx3HvZs',
#   'True'],
#  ['0',
#   '43',
#   'Summertime',
#   'Leslie Uggams with Mitch Miller and the Sing Along Gang',
#   'https://www.youtube.com/watch?v=0RhjorThKYs',
#   'True'],
#  ['0',
#   '44',
#   'Summertime',
#   'Jeanne Lee & Ran Blake',
#   'https://www.youtube.com/watch?v=FBnIJH-Py5g',
#   'True'],
#  ['0',
#   '45',
#   'Summertime',
#   'Andy Williams',
#   'https://www.youtube.com/watch?v=Ino4OYNVEQc',
#   'True'],
#  ['0',
#   '46',
#   'Summertime',
#   'Gerry and The Pacemakers',
#   'https://www.youtube.com/watch?v=o0dI-tWKGrc',
#   'True'],
#  ['0',
#   '47',
#   'Summertime',
#   'Lou Rawls',
#   'https://www.youtube.com/watch?v=bKzuXZwpLpQ',
#   'True'],
#  ['0',
#   '48',
#   'Summertime',
#   'The Legends [1]',
#   'https://www.youtube.com/watch?v=1j0NwVEZdNw',
#   'True'],
#  ['0',
#   '49',
#   'Summer Time',
#   'Willie Mae (Big Mama) Thornton',
#   'https://www.youtube.com/watch?v=ncfCgx11ciU',
#   'True'],
#  ['0',
#   '50',
#   'Summertime',
#   'Joanie Sommers',
#   'https://www.youtube.com/watch?v=2seDpjAGHgM',
#   'True'],
#  ['0',
#   '51',
#   'Summertime',
#   'Joe & Eddie',
#   'https://www.youtube.com/watch?v=HKo72JS080o',
#   'True'],
#  ['0',
#   '52',
#   'Summertime',
#   'The Tornadoes',
#   'https://www.youtube.com/watch?v=ZCSY5PLJIf8',
#   'True'],
#  ['0',
#   '53',
#   'Summertime',
#   'Frankie Brent Revue featuring Little Linda Lou',
#   'https://www.youtube.com/watch?v=hZnuKrWyvRk',
#   'True'],
#  ['0',
#   '54',
#   'Summertime',
#   'Carl H. Hall',
#   'https://www.youtube.com/watch?v=RfzJr-D58YQ',
#   'True'],
#  ['0',
#   '55',
#   'Summertime',
#   'The Cavaliers [1]',
#   'https://www.youtube.com/watch?v=kjlfaFPn_y0',
#   'True'],
#  ['0',
#   '56',
#   'Summertime',
#   'The Astronauts',
#   'https://www.youtube.com/watch?v=KPLnPEOr9XM',
#   'True'],
#  ['0',
#   '57',
#   'Summertime',
#   'David Troy',
#   'https://www.youtube.com/watch?v=x9qoWMqMrVQ',
#   'True'],
#  ['0',
#   '58',
#   'Summertime',
#   'Frank Wilson and the Cavaliers',
#   'https://www.youtube.com/watch?v=QTdYfsHGf3M',
#   'True'],
#  ['0',
#   '59',
#   'Summer Time',
#   'Nathaniel Mayer',
#   'https://www.youtube.com/watch?v=u-rTYLWk5SE',
#   'True'],
#  ['0',
#   '60',
#   'Summertime',
#   'Ernie Shelby',
#   'https://www.youtube.com/watch?v=cjQTLjDBIok',
#   'True'],
#  ['0',
#   '61',
#   'Summertime',
#   'The Zombies',
#   'https://www.youtube.com/watch?v=RKu2P8zT_F4',
#   'True'],
#  ['0',
#   '62',
#   'Summertime',
#   'Lynne Randell',
#   'https://www.youtube.com/watch?v=BfOcyQ_6ZEE',
#   'True'],
#  ['0',
#   '63',
#   'Summertime',
#   'Julie London with The Gerald Wilson Big Band',
#   'https://www.youtube.com/watch?v=15KJ2OVfJGU',
#   'True'],
#  ['0',
#   '64',
#   'Summertime',
#   'Inge Brandenburg',
#   'https://www.youtube.com/watch?v=6sHhFr3K1h8',
#   'True'],
#  ['0',
#   '65',
#   'Summertime',
#   'The Rokes',
#   'https://www.youtube.com/watch?v=KussdkHNJcs',
#   'True'],
#  ['0',
#   '66',
#   'Summertime',
#   'Bucky Bea',
#   'https://www.youtube.com/watch?v=pdz-t_FfmwI',
#   'True'],
#  ['0',
#   '67',
#   'Summertime',
#   'The Contrasts',
#   'https://www.youtube.com/watch?v=BeQW_E8OaHc',
#   'True'],
#  ['0',
#   '68',
#   'Summertime',
#   'Bootjacks',
#   'https://www.youtube.com/watch?v=A55Y37F3JTc',
#   'True'],
#  ['0',
#   '69',
#   'Summertime',
#   'Jackie De Shannon',
#   'https://www.youtube.com/watch?v=BYb6j-ygBDU',
#   'True'],
#  ['0',
#   '70',
#   'Summertime',
#   'Sheiks',
#   'https://www.youtube.com/watch?v=d8vglAqJR7o',
#   'True'],
#  ['0',
#   '71',
#   'Summertime',
#   'Sonny & Cher',
#   'https://www.youtube.com/watch?v=16fP91O8IwM',
#   'True'],
#  ['0',
#   '72',
#   'Summertime',
#   'Le Grand Mellon',
#   'https://www.youtube.com/watch?v=EyCQy4CtQpg',
#   'True'],
#  ['0',
#   '73',
#   'Summertime',
#   'Dinah Lee',
#   'https://www.youtube.com/watch?v=5QQ0VZv06UU',
#   'True'],
#  ['0',
#   '74',
#   'Summertime',
#   'The Walker Brothers',
#   'https://www.youtube.com/watch?v=fGGJoTmlmAg',
#   'True'],
#  ['0',
#   '75',
#   'Summertime',
#   'Skeeter Davis',
#   'https://www.youtube.com/watch?v=lmbippiQS3g',
#   'True'],
#  ['0',
#   '76',
#   'Summertime',
#   'The Wailers [1]',
#   'https://www.youtube.com/watch?v=nIOh-vEYyX8',
#   'True'],
#  ['0',
#   '77',
#   'Summertime',
#   'The Shake Spears',
#   'https://www.youtube.com/watch?v=fngFhjEidPU',
#   'True'],
#  ['0',
#   '78',
#   'Summertime',
#   'The Buckinghams',
#   'https://www.youtube.com/watch?v=vOVpFVD37UA',
#   'True'],
#  ['0',
#   '79',
#   'Summertime',
#   'Brenda and The Tabulations',
#   'https://www.youtube.com/watch?v=vAgSLVAZE9w',
#   'True'],
#  ['0',
#   '80',
#   'Summertime',
#   'Dionne Warwick',
#   'https://www.youtube.com/watch?v=4t3ffPn3l-k',
#   'True'],
#  ['0',
#   '81',
#   'Summertime',
#   'Toussaint McCall',
#   'https://www.youtube.com/watch?v=9r4IheCTNtU',
#   'True'],
#  ['0',
#   '82',
#   'Summertime',
#   'The Matadors [1]',
#   'https://www.youtube.com/watch?v=mYanAkw_9bI',
#   'True'],
#  ['0',
#   '83',
#   'Summertime',
#   'Quartet Zbigniew Namyslowski',
#   'https://www.youtube.com/watch?v=fom4ZSBNWr0',
#   'True'],
#  ['0',
#   '84',
#   'Summertime',
#   'The Bittersweets [2]',
#   'https://www.youtube.com/watch?v=A4DoYOOlofU',
#   'True'],
#  ['0',
#   '85',
#   'Summertime',
#   'Billy Preston',
#   'https://www.youtube.com/watch?v=mhhKmmXFBFg',
#   'True'],
#  ['0',
#   '86',
#   'Summertime',
#   "Slam Creepers'",
#   'https://www.youtube.com/watch?v=wJ5piAolS6E',
#   'True'],
#  ['0',
#   '87',
#   'Summertime',
#   'Gerry Lockran',
#   'https://www.youtube.com/watch?v=BfbNRGtDSYI',
#   'True'],
#  ['0',
#   '88',
#   'Summertime',
#   'Leaves of Grass',
#   'https://www.youtube.com/watch?v=bKPwyUs91lg',
#   'True'],
#  ['0',
#   '89',
#   'Summertime',
#   'Big Brother & The Holding Company',
#   'https://www.youtube.com/watch?v=twU4n7YeD3M',
#   'True'],
#  ['0',
#   '90',
#   'Summertime',
#   'Love Sculpture',
#   'https://www.youtube.com/watch?v=ou5mcPKsDq8',
#   'True'],
#  ['0',
#   '91',
#   'Summer Time',
#   'Lloyd Clarke',
#   'https://www.youtube.com/watch?v=FFURg_inmSg',
#   'True'],
#  ['0',
#   '92',
#   'Summertime',
#   'The Senate',
#   'https://www.youtube.com/watch?v=tlZyUNpFJao',
#   'True'],
#  ['0',
#   '93',
#   'Summertime',
#   'Dee Dee, Barry & The Movements',
#   'https://www.youtube.com/watch?v=RaQoqjXb3lY',
#   'True'],
#  ['0',
#   '94',
#   'Summertime',
#   'Al Green',
#   'https://www.youtube.com/watch?v=BYfW5Dm1xLI',
#   'True'],
#  ['0',
#   '95',
#   'Summertime',
#   'The Gents',
#   'https://www.youtube.com/watch?v=GyIcI1zB7sk',
#   'True'],
#  ['0',
#   '96',
#   'Summertime',
#   'Yuya Uchida and The Flowers',
#   'https://www.youtube.com/watch?v=AvEZenqE6_o',
#   'True'],
#  ['0',
#   '97',
#   'Summertime',
#   'Brainbox',
#   'https://www.youtube.com/watch?v=CxUaohD3XZU',
#   'True'],
#  ['0',
#   '98',
#   'Summertime',
#   'Ohio Players',
#   'https://www.youtube.com/watch?v=4B_ixzaoehQ',
#   'True'],
#  ['0',
#   '99',
#   'Summertime',
#   'Negative Space',
#   'https://www.youtube.com/watch?v=7onhJIld8ec',
#   'True'],
#  ['0',
#   '100',
#   'Summertime',
#   'Toy Factory',
#   'https://www.youtube.com/watch?v=QIMiXywo0qM',
#   'True'],
#  ['0',
#   '101',
#   'Summertime',
#   'Magic Bubble',
#   'https://www.youtube.com/watch?v=mKyt0lgCnvA',
#   'True'],
#  ['0',
#   '102',
#   'Summertime',
#   'Sammy',
#   'https://www.youtube.com/watch?v=WBaaUqM34do',
#   'True'],
#  ['0',
#   '103',
#   'Summertime',
#   'Doc Watson',
#   'https://www.youtube.com/watch?v=vi8W93aJG_U',
#   'False'],
#  ['0',
#   '104',
#   'Summertime',
#   'Freddy Quinn',
#   'https://www.youtube.com/watch?v=OYG6Rgs5tVw',
#   'True'],
#  ['0',
#   '105',
#   'Summertime',
#   'Corben Simpson',
#   'https://www.youtube.com/watch?v=aWmKqvWDMf8',
#   'True'],
#  ['0',
#   '106',
#   'Summertime',
#   'Kiri Te Kanawa',
#   'https://www.youtube.com/watch?v=yXyw6mG5pj8',
#   'True'],
#  ['0',
#   '107',
#   'Summertime',
#   'Johnny Hartman',
#   'https://www.youtube.com/watch?v=ORPD0jIc7AE',
#   'True'],
#  ['0',
#   '108',
#   'Summertime',
#   'Bu Pleasant, Freddie Waits, Harold Vick, Mickey Bass, Atley Chapman, Ted Dunbar',
#   'https://www.youtube.com/watch?v=KS-MPwNfA1k',
#   'True'],
#  ['0',
#   '109',
#   'Summertime',
#   'Society of Seven',
#   'https://www.youtube.com/watch?v=vQJJ6E8ow_k',
#   'True'],
#  ['0',
#   '110',
#   'Summertime',
#   'Copper Penny',
#   'https://www.youtube.com/watch?v=L3uTDgeZ7YA',
#   'True'],
#  ['0',
#   '111',
#   'Summertime',
#   'Mike Brant',
#   'https://www.youtube.com/watch?v=4CWKzmnqzPI',
#   'True'],
#  ['0',
#   '112',
#   'Summertime',
#   'Blind John Davis',
#   'https://www.youtube.com/watch?v=cS2tsHmy0Sc',
#   'True'],
#  ['0',
#   '113',
#   'Summertime',
#   'Martha and James',
#   'https://www.youtube.com/watch?v=ZYiZ-h5kGLk',
#   'True'],
#  ['0',
#   '114',
#   'Summertime',
#   'Stella Marrs with Roger Van Haverbeke Trio',
#   'https://www.youtube.com/watch?v=L8BNGQzakIs',
#   'True'],
#  ['0',
#   '115',
#   'Summertime',
#   'Eddie Jefferson',
#   'https://www.youtube.com/watch?v=y-4QaEMKV0M',
#   'True'],
#  ['0',
#   '116',
#   'Summertime',
#   'The Blue Velvets',
#   'https://www.youtube.com/watch?v=TteScmNK0YU',
#   'True'],
#  ['0',
#   '117',
#   'Summertime',
#   'Cida Moreira',
#   'https://www.youtube.com/watch?v=PKiLp-9JqJI',
#   'True'],
#  ['0',
#   '118',
#   'Porgy and Bess Medley',
#   'Mel Tormé and Friends',
#   'https://www.youtube.com/watch?v=gJUFeKsMMNA',
#   'True'],
#  ['0',
#   '119',
#   'Summertime',
#   'Fun Boy Three',
#   'https://www.youtube.com/watch?v=eoJDXI0HPjA',
#   'True'],
#  ['0',
#   '120',
#   'Summertime',
#   'Sam & Dave',
#   'https://www.youtube.com/watch?v=EhC2ttQTZEE',
#   'True'],
#  ['0',
#   '121',
#   'Summertime',
#   'The Flying Pickets',
#   'https://www.youtube.com/watch?v=sPWH8V8hysg',
#   'True'],
#  ['0',
#   '122',
#   'Summertime',
#   'Sumiko Yoseyama',
#   'https://www.youtube.com/watch?v=j66P8J39F0s',
#   'True'],
#  ['0',
#   '123',
#   'Summertime',
#   'Swans Way',
#   'https://www.youtube.com/watch?v=cab-A_W7rHE',
#   'True'],
#  ['0',
#   '124',
#   'Summertime',
#   "Howlin' Wilf & The Vee-Jays",
#   'https://www.youtube.com/watch?v=4g6WA5v8HzE',
#   'True'],
#  ['0',
#   '125',
#   'Summertime',
#   'Sissel Kyrkjebø',
#   'https://www.youtube.com/watch?v=o6jreproo44',
#   'True'],
#  ['0',
#   '126',
#   'Summertime',
#   'Kimiko Itoh',
#   'https://www.youtube.com/watch?v=Hk74JHTiHEE',
#   'True'],
#  ['0',
#   '127',
#   'Summertime',
#   'Sylvester',
#   'https://www.youtube.com/watch?v=DsoWvXDMo1c',
#   'True'],
#  ['0',
#   '128',
#   'Summertime',
#   'Deborah Henson-Conant',
#   'https://www.youtube.com/watch?v=g1hA0c1xVTs',
#   'False'],
#  ['0',
#   '129',
#   'Summertime',
#   'Oscar Pettiford',
#   'https://www.youtube.com/watch?v=Mx93Gi14zOw',
#   'True'],
#  ['0',
#   '130',
#   'Summertime',
#   'Paul McCartney',
#   'https://www.youtube.com/watch?v=nEzCxZ1hIwo',
#   'True'],
#  ['0',
#   '131',
#   'Summertime',
#   'Maureen McGovern',
#   'https://www.youtube.com/watch?v=yTUGh1binp4',
#   'True'],
#  ['0',
#   '132',
#   'Summertime',
#   'The Harvard Din & Tonics',
#   'https://www.youtube.com/watch?v=zHq-x6eANE4',
#   'True'],
#  ['0',
#   '133',
#   'Summertime',
#   'R.E.M.',
#   'https://www.youtube.com/watch?v=2HKh0UBrtlM',
#   'True'],
#  ['0',
#   '134',
#   'Summertime',
#   'Lesley Garrett, Philharmonia Orchestra Conducted by Ivor Bolton',
#   'https://www.youtube.com/watch?v=bcqg71RSmuw',
#   'False'],
#  ['0',
#   '135',
#   'Summertime',
#   'Lesley Olsher',
#   'https://www.youtube.com/watch?v=icrtHGXGf1I',
#   'True'],
#  ['0',
#   '136',
#   'Summertime',
#   'Chet Atkins and Jerry Reed',
#   'https://www.youtube.com/watch?v=I3N6Jv8HCqM',
#   'True'],
#  ['0',
#   '137',
#   'Summertime',
#   'Helge Schneider & Hardcore',
#   'https://www.youtube.com/watch?v=0e_IyMhfTgo',
#   'True'],
#  ['0',
#   '138',
#   'Summertime',
#   'Big Time Sarah and The BTS Express',
#   'https://www.youtube.com/watch?v=N_vt4g0N_3I',
#   'True'],
#  ['0',
#   '139',
#   'Summertime',
#   'Peter Gabriel',
#   'https://www.youtube.com/watch?v=4fOgwxJaYQg',
#   'True'],
#  ['0',
#   '140',
#   'Summertime',
#   'Noel Freidline Trio, featuring Renée Dickerson',
#   'https://www.youtube.com/watch?v=EU938D9Ybpo',
#   'False'],
#  ['0',
#   '141',
#   'Summertime',
#   'Carol Kidd',
#   'https://www.youtube.com/watch?v=KQBDEz9KBHk',
#   'True'],
#  ['0',
#   '142',
#   'Summertime',
#   'Linda Hopkins',
#   'https://www.youtube.com/watch?v=7m2PFlbL2aY',
#   'False'],
#  ['0',
#   '143',
#   'Summertime',
#   'Jason Rebello',
#   'https://www.youtube.com/watch?v=9W8AVWbqTwQ',
#   'True'],
#  ['0',
#   '144',
#   'Summer Time',
#   'Sugar Lee Hooper',
#   'https://www.youtube.com/watch?v=MzbiMIKXm5c',
#   'False'],
#  ['0',
#   '145',
#   'Summertime',
#   'Black Raven',
#   'https://www.youtube.com/watch?v=zMf9Nq4_ASY',
#   'True'],
#  ['0',
#   '146',
#   'Summertime',
#   'The Swingle Singers',
#   'https://www.youtube.com/watch?v=eF4Nbe1ZPj4',
#   'True'],
#  ['0',
#   '147',
#   'Summertime',
#   'Wayne Hancock',
#   'https://www.youtube.com/watch?v=sIS9bqmak1s',
#   'True'],
#  ['0',
#   '148',
#   'Summertime (Guajira)',
#   'Ray Barretto',
#   'https://www.youtube.com/watch?v=g2bbtMF2pCs',
#   'True'],
#  ['0',
#   '149',
#   'Summertime',
#   "Segan'",
#   'https://www.youtube.com/watch?v=7X47h4H22eA',
#   'True'],
#  ['0',
#   '150',
#   'Summertime',
#   "Graham Fenton's Matchbox",
#   'https://www.youtube.com/watch?v=f1vItyFPVVM',
#   'False'],
#  ['0',
#   '151',
#   'Summertime',
#   'Anca Parghel',
#   'https://www.youtube.com/watch?v=RZ-LFx1UCbI',
#   'True'],
#  ['0',
#   '152',
#   'Summertime',
#   'Rick Matle & Sheila Landis',
#   'https://www.youtube.com/watch?v=Fd0muYa21Y8',
#   'True'],
#  ['0',
#   '153',
#   'Summertime',
#   'Alexia [1]',
#   'https://www.youtube.com/watch?v=tWqwE9yYCOY',
#   'True'],
#  ['0',
#   '154',
#   'Summertime',
#   'Lino Patruno Jazz Show',
#   'https://www.youtube.com/watch?v=vTivEe9TdcU',
#   'True'],
#  ['0',
#   '155',
#   'Summertime',
#   'Angel Forrest',
#   'https://www.youtube.com/watch?v=oeFWY65sUP8',
#   'True'],
#  ['0',
#   '156',
#   'Summertime',
#   'Ron Kaplan',
#   'https://www.youtube.com/watch?v=96JzAttC9lQ',
#   'True'],
#  ['0',
#   '157',
#   'Summertime',
#   'Stereophonics',
#   'https://www.youtube.com/watch?v=clr7d-gR7NU',
#   'True'],
#  ['0',
#   '158',
#   'Summertime',
#   'Dianne Reeves',
#   'https://www.youtube.com/watch?v=z_iyKq9R3Bo',
#   'False'],
#  ['0',
#   '159',
#   'Summertime (Part One)',
#   'Funky Company',
#   'https://www.youtube.com/watch?v=_4_gj7aRlUY',
#   'True'],
#  ['0',
#   '160',
#   'Summertime',
#   'Bobby Womack & The Roots',
#   'https://www.youtube.com/watch?v=D0IrlwDuUDQ',
#   'True'],
#  ['0',
#   '161',
#   'Summertime',
#   'Morcheeba & Hubert Laws',
#   'https://www.youtube.com/watch?v=cgHTjEbDGzI',
#   'True'],
#  ['0',
#   '162',
#   'Summertime',
#   "Peggy Lee with Buddy Cole's Four of a Kind",
#   'https://www.youtube.com/watch?v=EHtMdaHZEpk',
#   'True'],
#  ['0',
#   '163',
#   'Summertime/Sometimes I Feel Like a Motherless Child',
#   'Mocean Worker',
#   'https://www.youtube.com/watch?v=WceJQ2CGS34',
#   'True'],
#  ['0',
#   '164',
#   'Summertime',
#   'Jim Murple Memorial',
#   'https://www.youtube.com/watch?v=1PzFl1TXY6I',
#   'True'],
#  ['0',
#   '165',
#   'Summertime',
#   'Herbie Hancock',
#   'https://www.youtube.com/watch?v=Nfn1rGM2VRI',
#   'True'],
#  ['0',
#   '166',
#   'Summertime',
#   'Bobby Carcassés',
#   'https://www.youtube.com/watch?v=0rO5TIaYoSg',
#   'True'],
#  ['0',
#   '167',
#   'Summertime',
#   'Carlos and The Bandidos',
#   'https://www.youtube.com/watch?v=JRXO_bUIWxk',
#   'True'],
#  ['0',
#   '168',
#   'Summertime',
#   'Swing Cats',
#   'https://www.youtube.com/watch?v=u-RtNI0sphU',
#   'True'],
#  ['0',
#   '169',
#   'Summertime',
#   'Ruth Nabal',
#   'https://www.youtube.com/watch?v=2c2h_2kvPxI',
#   'False'],
#  ['0',
#   '170',
#   'Summertime',
#   'Charlotte Church',
#   'https://www.youtube.com/watch?v=b49UokjjZ_o',
#   'True'],
#  ['0',
#   '171',
#   'Summertime',
#   'Janis Joplin',
#   'https://www.youtube.com/watch?v=rawsYQitKik',
#   'True'],
#  ['0',
#   '172',
#   'Summertime',
#   'GQ',
#   'https://www.youtube.com/watch?v=gwzS6UYVXIY',
#   'False'],
#  ['0',
#   '173',
#   'Summertime',
#   'Junia Walker',
#   'https://www.youtube.com/watch?v=9XHbLOX3Hto',
#   'True'],
#  ['0',
#   '174',
#   'Summertime',
#   'Skamp',
#   'https://www.youtube.com/watch?v=v9AReuLXhPU',
#   'True'],
#  ['0',
#   '175',
#   'Summertime',
#   'Armand Van Helden',
#   'https://www.youtube.com/watch?v=j0ciRij_4qY',
#   'True'],
#  ['0',
#   '176',
#   'Summertime',
#   'Rossana Casale',
#   'https://www.youtube.com/watch?v=INGEXunm4es',
#   'True'],
#  ['0',
#   '177',
#   'Summertime',
#   'Deep-Dive-Corp.',
#   'https://www.youtube.com/watch?v=ZjkvTGghAh8',
#   'True'],
#  ['0',
#   '178',
#   'Summertime',
#   'Peach Stealing Monkeys',
#   'https://www.youtube.com/watch?v=BovAp4Rcu30',
#   'True'],
#  ['0',
#   '179',
#   'Summertime',
#   'Susie Tallman',
#   'https://www.youtube.com/watch?v=yZjJocWOH8o',
#   'False'],
#  ['0',
#   '180',
#   'Summertime',
#   'Terri White',
#   'https://www.youtube.com/watch?v=Dc_jc-inrTc',
#   'True'],
#  ['0',
#   '181',
#   'Summertime',
#   'Osdalgia',
#   'https://www.youtube.com/watch?v=pmi4sti94JI',
#   'True'],
#  ['0',
#   '182',
#   'Summertime',
#   'Cheryl Porter Group',
#   'https://www.youtube.com/watch?v=wvwXSOdZB38',
#   'True'],
#  ['0',
#   '183',
#   'Summertime',
#   'Molly Johnson',
#   'https://www.youtube.com/watch?v=7tWwvJCVjeY',
#   'True'],
#  ['0',
#   '184',
#   'Summertime',
#   'Sarah Connor',
#   'https://www.youtube.com/watch?v=M6GSIbnEZLs',
#   'True'],
#  ['0',
#   '185',
#   'Summertime',
#   'The Go Getters',
#   'https://www.youtube.com/watch?v=Ri-_4kNkIQs',
#   'True'],
#  ['0',
#   '186',
#   'Summertime',
#   'Aaron Neville',
#   'https://www.youtube.com/watch?v=zntjar4H0Co',
#   'True'],
#  ['0',
#   '187',
#   'Summertime (On Central Avenue)',
#   "Sweet Baby J'ai",
#   'https://www.youtube.com/watch?v=ceLSEOaJlls',
#   'False'],
#  ['0',
#   '188',
#   'Summertime',
#   'Ligia Piro',
#   'https://www.youtube.com/watch?v=MZPqdeBCrAY',
#   'True'],
#  ['0',
#   '189',
#   'Summertime',
#   'Renee Olstead',
#   'https://www.youtube.com/watch?v=3uhuh2cRJAo',
#   'True'],
#  ['0',
#   '190',
#   'Summertime',
#   'Fantasia',
#   'https://www.youtube.com/watch?v=-WWtGpEqpV4',
#   'True'],
#  ['0',
#   '191',
#   'Summertime',
#   'Jill Scott & George Benson',
#   'https://www.youtube.com/watch?v=p9siKWoQShE',
#   'True'],
#  ['0',
#   '192',
#   'Summertime',
#   'Laurent De Wilde',
#   'https://www.youtube.com/watch?v=t4sKGSeVzWA',
#   'True'],
#  ['0',
#   '193',
#   'Summertime',
#   'Michael Bolton',
#   'https://www.youtube.com/watch?v=yu8_uSG8kDE',
#   'True'],
#  ['0',
#   '194',
#   'Summertime',
#   'Rufus Zuphall',
#   'https://www.youtube.com/watch?v=rogwi0tM2d4',
#   'True'],
#  ['0',
#   '195',
#   'Summertime',
#   'The Harvard Krokodiloes',
#   'https://www.youtube.com/watch?v=EQRSGmuKasU',
#   'True'],
#  ['0',
#   '196',
#   'Summertime',
#   'Stephy Haik, Regis Huby',
#   'https://www.youtube.com/watch?v=tUAcfyH-4Do',
#   'True'],
#  ['0',
#   '197',
#   'Summertime (Album Version)',
#   'Erik Sumo',
#   'https://www.youtube.com/watch?v=e6FZkML9UUw',
#   'True'],
#  ['0',
#   '198',
#   'Summertime',
#   'Alina Izquierdo',
#   'https://www.youtube.com/watch?v=xaV7PipU_E0',
#   'True'],
#  ['0',
#   '199',
#   'Summertime',
#   'Tape Five',
#   'https://www.youtube.com/watch?v=N1DxpE_XtBI',
#   'True'],
#  ['0',
#   '200',
#   'Summertime',
#   'Nikki Loney',
#   'https://www.youtube.com/watch?v=34wovqE9M9s',
#   'True'],
#  ['0',
#   '201',
#   'Summertime',
#   'Angelina [1]',
#   'https://www.youtube.com/watch?v=slCXcpKMa10',
#   'True'],
#  ['0',
#   '202',
#   'Summertime',
#   'Bernadette Seacrest & Her Yes Men',
#   'https://www.youtube.com/watch?v=PySJd54Ilx0',
#   'True'],
#  ['0',
#   '203',
#   'Summertime',
#   'Florence K.',
#   'https://www.youtube.com/watch?v=lfmy6G4HH9A',
#   'True'],
#  ['0',
#   '204',
#   'Summertime',
#   'Clairdee',
#   'https://www.youtube.com/watch?v=s816VI0Mgkk',
#   'True'],
#  ['0',
#   '205',
#   'Summertime',
#   'Smoma',
#   'https://www.youtube.com/watch?v=e6FFJRqgNAc',
#   'True'],
#  ['0',
#   '206',
#   'Summertime',
#   'Oscar Klein & Gus Backus',
#   'https://www.youtube.com/watch?v=jHr4lAeU3JY',
#   'False'],
#  ['0',
#   '207',
#   'Summertime',
#   'Groove Society',
#   'https://www.youtube.com/watch?v=wfi-2NT1S5I',
#   'True'],
#  ['0',
#   '208',
#   'Summertime',
#   'Scarlett Johansson',
#   'https://www.youtube.com/watch?v=HVzS_jp86Xw',
#   'True'],
#  ['0',
#   '209',
#   'Summertime',
#   'Jacqui Naylor',
#   'https://www.youtube.com/watch?v=ezA53bjxaEc',
#   'True'],
#  ['0',
#   '210',
#   'Summertime',
#   'Leona',
#   'https://www.youtube.com/watch?v=4hIeFjT95kA',
#   'True'],
#  ['0',
#   '211',
#   'Summertime',
#   'The House Jacks',
#   'https://www.youtube.com/watch?v=DMFvsmbyMPo',
#   'True'],
#  ['0',
#   '212',
#   'Summertime',
#   'Leslie West',
#   'https://www.youtube.com/watch?v=e6poJMnV5eI',
#   'True'],
#  ['0',
#   '213',
#   'Summertime',
#   'Kim Hoorweg',
#   'https://www.youtube.com/watch?v=fmSBYjFjJvA',
#   'True'],
#  ['0',
#   '214',
#   'Summertime',
#   'The Doors',
#   'https://www.youtube.com/watch?v=yfhF3gI_b60',
#   'True'],
#  ['0',
#   '215',
#   'Summertime',
#   'Sheila Landis',
#   'https://www.youtube.com/watch?v=WXtqMNueN0o',
#   'True'],
#  ['0',
#   '216',
#   'Summertime',
#   'Kellye Gray Three',
#   'https://www.youtube.com/watch?v=E23OvkCVgR0',
#   'False'],
#  ['0',
#   '217',
#   'Summer Time',
#   'Marica Hiraga',
#   'https://www.youtube.com/watch?v=05irF5MJeE0',
#   'True'],
#  ['0',
#   '218',
#   'Summertime',
#   'Pura Fé',
#   'https://www.youtube.com/watch?v=NdA7TTyMlHA',
#   'True'],
#  ['0',
#   '219',
#   'Summertime',
#   'Calmus Ensemble',
#   'https://www.youtube.com/watch?v=4g_9weR9Rnk',
#   'False'],
#  ['0',
#   '220',
#   'Summertime',
#   'Tenors Un Limited',
#   'https://www.youtube.com/watch?v=oTAaJDyzB0U',
#   'True'],
#  ['0',
#   '221',
#   'Summertime',
#   'Colin Meloy',
#   'https://www.youtube.com/watch?v=hCVJtyEkgAA',
#   'True'],
#  ['0',
#   '222',
#   'Summer Time',
#   'Karen Aoki',
#   'https://www.youtube.com/watch?v=aNpOyPtpFwQ',
#   'True'],
#  ['0',
#   '223',
#   'Summertime',
#   'Martha High with Shaolin Temple Defenders',
#   'https://www.youtube.com/watch?v=P2uYa2alxoo',
#   'True'],
#  ['0',
#   '224',
#   'Summertime',
#   'Lucie Bílá',
#   'https://www.youtube.com/watch?v=KNEV0wBqjSQ',
#   'False'],
#  ['0',
#   '225',
#   'Summertime',
#   'Kat Edmonson',
#   'https://www.youtube.com/watch?v=8M2Z23BPOtw',
#   'True'],
#  ['0',
#   '226',
#   'Summertime',
#   'Eddie C. Campbell',
#   'https://www.youtube.com/watch?v=GBzV1b1hR5U',
#   'True'],
#  ['0',
#   '227',
#   'Summertime',
#   'Mica Paris',
#   'https://www.youtube.com/watch?v=UrBCOEjnBP8',
#   'True'],
#  ['0',
#   '228',
#   'Summertime',
#   'Jaimee Paul',
#   'https://www.youtube.com/watch?v=VKDtb-l-9ZQ',
#   'True'],
#  ['0',
#   '229',
#   'Summertime',
#   'Beverly Jo Scott',
#   'https://www.youtube.com/watch?v=EedWElRr_vg',
#   'True'],
#  ['0',
#   '230',
#   'Summertime',
#   'Gare du Nord',
#   'https://www.youtube.com/watch?v=6I31lzVYmR8',
#   'True'],
#  ['0',
#   '231',
#   'Summertime',
#   'Blue Valentine',
#   'https://www.youtube.com/watch?v=KkdYMzg7T0g',
#   'True'],
#  ['0',
#   '232',
#   'Summertime',
#   'Viktor Lazlo',
#   'https://www.youtube.com/watch?v=-xqNMbD4kQc',
#   'True'],
#  ['0',
#   '233',
#   'Summertime',
#   'Paul Lamb & The King Snakes',
#   'https://www.youtube.com/watch?v=QAozVRvEt8U',
#   'True'],
#  ['0',
#   '234',
#   'Summertime',
#   'Tok Tok Tok',
#   'https://www.youtube.com/watch?v=PyrOkelXvts',
#   'True'],
#  ['0',
#   '235',
#   'サマータイム [Summertime]',
#   '八代亜紀',
#   'https://www.youtube.com/watch?v=Wviz4FJ0bPA',
#   'True'],
#  ['0',
#   '236',
#   'A Change Is Gonna Come/Summertime',
#   'Nonsequitur',
#   'https://www.youtube.com/watch?v=aVj5996N3Lw',
#   'True'],
#  ['0',
#   '237',
#   'Summertime',
#   'Christine Hart',
#   'https://www.youtube.com/watch?v=t-tnWiLf_ZA',
#   'True'],
#  ['0',
#   '238',
#   'Summertime',
#   'Eels',
#   'https://www.youtube.com/watch?v=p4toTqCwDbw',
#   'True'],
#  ['0',
#   '239',
#   'Summertime',
#   'Anne Ducros',
#   'https://www.youtube.com/watch?v=RGYRloj39zE',
#   'True'],
#  ['0',
#   '240',
#   'Summertime',
#   'Carmen Monarcha',
#   'https://www.youtube.com/watch?v=BBUlozdu3Yk',
#   'True'],
#  ['0',
#   '241',
#   'Summertime',
#   'Lulu Roman',
#   'https://www.youtube.com/watch?v=h0tD5L8Ky64',
#   'True'],
#  ['0',
#   '242',
#   'Summertime',
#   'David Ian featuring Talitha Walters-Wulfing',
#   'https://www.youtube.com/watch?v=QU_W8vHK0Ac',
#   'True'],
#  ['0',
#   '243',
#   'Summertime',
#   'The Moon Loungers',
#   'https://www.youtube.com/watch?v=dA6Co2eGanM',
#   'True'],
#  ['0',
#   '244',
#   'Summertime',
#   'Annie Lennox',
#   'https://www.youtube.com/watch?v=UkKo-jXl2CQ',
#   'True'],
#  ['0',
#   '245',
#   'Summertime',
#   'Letizia Brugnoli',
#   'https://www.youtube.com/watch?v=9ONxmdQQn8Q',
#   'False'],
#  ['0',
#   '246',
#   'Summertime',
#   'Sydney Claire',
#   'https://www.youtube.com/watch?v=wP3eDT5NZyo',
#   'True'],
#  ['0',
#   '247',
#   'Summertime',
#   'Mindi Abair and The Boneshakers',
#   'https://www.youtube.com/watch?v=C4TFgTY1gL0',
#   'True'],
#  ['0',
#   '248',
#   'Summertime',
#   'Annie Moses Band',
#   'https://www.youtube.com/watch?v=SMTMaufwOSk',
#   'True'],
#  ['0',
#   '249',
#   'Summertime',
#   'The Harvard Opportunes',
#   'https://www.youtube.com/watch?v=hzkyiWa1nRM',
#   'True'],
#  ['0',
#   '250',
#   'Summertime',
#   'Simone Waddell',
#   'https://www.youtube.com/watch?v=9wGPNWifFQQ',
#   'True'],
#  ['0',
#   '251',
#   'Summertime',
#   'Willie Nelson',
#   'https://www.youtube.com/watch?v=L5xafQXg1yI',
#   'True'],
#  ['0',
#   '252',
#   'Summertime',
#   'Bob Crosby and His Orchestra',
#   'https://www.youtube.com/watch?v=nk-nu4DNEAA',
#   'True'],
#  ['0',
#   '253',
#   'Summertime',
#   'Joe Sullivan',
#   'https://www.youtube.com/watch?v=fsHJhA8YJHc',
#   'True'],
#  ['0',
#   '254',
#   'Summertime',
#   'Charlie Spivak and His Orchestra',
#   'https://www.youtube.com/watch?v=QM5SoceOGEk',
#   'True'],
#  ['0',
#   '255',
#   'Summertime',
#   'Artie Shaw and His Orchestra',
#   'https://www.youtube.com/watch?v=RAO50k7mi7Q',
#   'True'],
#  ['0',
#   '256',
#   'Summertime',
#   'Boyd Raeburn and His Orchestra',
#   'https://www.youtube.com/watch?v=yBU1f6wncYQ',
#   'True'],
#  ['0',
#   '257',
#   'Summertime',
#   'Joe Venuti',
#   'https://www.youtube.com/watch?v=W8cNqHtnAR8',
#   'True'],
#  ['0',
#   '258',
#   'Summertime',
#   'Jascha Heifetz',
#   'https://www.youtube.com/watch?v=1tEtEk-4RlQ',
#   'True'],
#  ['0',
#   '259',
#   'Summertime',
#   'George Shearing',
#   'https://www.youtube.com/watch?v=3pxbr9GXZoI',
#   'True'],
#  ['0',
#   '260',
#   'Summertime',
#   'Charlie Parker String Ensemble',
#   'https://www.youtube.com/watch?v=7gwl29diADw',
#   'True'],
#  ['0',
#   '261',
#   'Summertime',
#   'Dizzy Gillespie',
#   'https://www.youtube.com/watch?v=r0LKiFTIEv4',
#   'True'],
#  ['0',
#   '262',
#   'Summertime',
#   'Orchester Kurt Edelhagen',
#   'https://www.youtube.com/watch?v=wrR3AsAl3Yk',
#   'True'],
#  ['0',
#   '263',
#   'Summertime',
#   'Eddie Calvert',
#   'https://www.youtube.com/watch?v=ra5qaDnPs4I',
#   'True'],
#  ['0',
#   '264',
#   'Summertime',
#   "Sidney Bechet with Bob Scobey's Frisco Band",
#   'https://www.youtube.com/watch?v=EuEyhTct3Og',
#   'True'],
#  ['0',
#   '265',
#   'Summertime',
#   'Lynn Hope',
#   'https://www.youtube.com/watch?v=Wi7-hCvwMm4',
#   'True'],
#  ['0',
#   '266',
#   'Summertime',
#   'Mat Mathews',
#   'https://www.youtube.com/watch?v=x27eczyTCig',
#   'True'],
#  ['0',
#   '267',
#   'Summertime',
#   'Chet Baker Quartet',
#   'https://www.youtube.com/watch?v=b4yfJccwu2g',
#   'True'],
#  ['0',
#   '268',
#   'Summertime',
#   'Charles Mingus with Hampton Hawes & Danny Richmond',
#   'https://www.youtube.com/watch?v=5GdMQU2nprI',
#   'True'],
#  ['0',
#   '269',
#   'Summertime',
#   'Percy Faith and His Orchestra',
#   'https://www.youtube.com/watch?v=UHdQlKY0P78',
#   'True'],
#  ['0',
#   '270',
#   'Summertime',
#   'Jimmy Smith & Lou Donaldson',
#   'https://www.youtube.com/watch?v=5bd-9Ocm2pI',
#   'True'],
#  ['0',
#   '271',
#   'Summertime',
#   'Raymond Scott',
#   'https://www.youtube.com/watch?v=wAklLKIGtek',
#   'True'],
#  ['0',
#   '272',
#   'Summertime',
#   'Mantovani and His Orchestra',
#   'https://www.youtube.com/watch?v=np5t4YoRpbQ',
#   'True'],
#  ['0',
#   '273',
#   'Summertime',
#   '101 Strings',
#   'https://www.youtube.com/watch?v=m-a6hAuLc4s',
#   'True'],
#  ['0',
#   '274',
#   'Summertime',
#   'Miles Davis',
#   'https://www.youtube.com/watch?v=R_uBCvNKz6I',
#   'True'],
#  ['0',
#   '275',
#   'Summertime',
#   'Santo & Johnny',
#   'https://www.youtube.com/watch?v=W0Cjhaq3mco',
#   'True'],
#  ['0',
#   '276',
#   'Summertime',
#   'Larry Adler Quartet',
#   'https://www.youtube.com/watch?v=ZpnnBHYAhJs',
#   'True'],
#  ['0',
#   '277',
#   'Summertime',
#   'Mundell Lowe and His All Stars',
#   'https://www.youtube.com/watch?v=XLfIg4svQns',
#   'True'],
#  ['0',
#   '278',
#   'Summertime',
#   'The Oscar Peterson Trio',
#   'https://www.youtube.com/watch?v=1Vlrh8V2J6Y',
#   'True'],
#  ['0',
#   '279',
#   'Summertime',
#   'Ray Conniff and His Orchestra and Chorus',
#   'https://www.youtube.com/watch?v=PWeB6kmC6DU',
#   'True'],
#  ['0',
#   '280',
#   'Summertime',
#   'The Billy Longstreet Sextet',
#   'https://www.youtube.com/watch?v=NURO5MJw868',
#   'True'],
#  ['0',
#   '281',
#   'Summertime',
#   "Sam Marowitz with Charles Albertine's Orchestra",
#   'https://www.youtube.com/watch?v=TYC5VozNkCY',
#   'True'],
#  ['0',
#   '282',
#   'Summertime',
#   'Don Randi Trio',
#   'https://www.youtube.com/watch?v=_naanU11O-U',
#   'False'],
#  ['0',
#   '283',
#   'Summertime',
#   'Wes Montgomery',
#   'https://www.youtube.com/watch?v=TKndXzvOfVQ',
#   'True'],
#  ['0',
#   '284',
#   'Summertime',
#   'Shelly Manne & His Men',
#   'https://www.youtube.com/watch?v=fCaN2irGItA',
#   'True'],
#  ['0',
#   '285',
#   'Summertime',
#   'The Three Sounds',
#   'https://www.youtube.com/watch?v=9Tj-RDBj0iA',
#   'True'],
#  ['0',
#   '286',
#   'Summertime',
#   'Billy Vaughn and His Orchestra',
#   'https://www.youtube.com/watch?v=ityDeb6qZs4',
#   'True'],
#  ['0',
#   '287',
#   'Summertime',
#   'Orquesta Maravella',
#   'https://www.youtube.com/watch?v=QI1gEeF1fz8',
#   'True'],
#  ['0',
#   '288',
#   'Summertime',
#   'Toots Thielemans',
#   'https://www.youtube.com/watch?v=ROaz7Vg6c7o',
#   'True'],
#  ['0',
#   '289',
#   'Summertime',
#   'David "Fathead" Newman',
#   'https://www.youtube.com/watch?v=pkoXNPwBOes',
#   'True'],
#  ['0',
#   '290',
#   'Summertime',
#   'John Coltrane',
#   'https://www.youtube.com/watch?v=Z8yTNZlgxjg',
#   'True'],
#  ['0',
#   '291',
#   'Summertime',
#   'The String-A-Longs',
#   'https://www.youtube.com/watch?v=TVqiW-5II8w',
#   'True'],
#  ['0',
#   '292',
#   'Summertime',
#   'Freddie Hubbard',
#   'https://www.youtube.com/watch?v=rZ0STinfrXg',
#   'True'],
#  ['0',
#   '293',
#   'Summertime',
#   'Joe Morello Sextet',
#   'https://www.youtube.com/watch?v=l6iI66M69IQ',
#   'True'],
#  ['0',
#   '294',
#   'Summertime',
#   'Edmundo Ros',
#   'https://www.youtube.com/watch?v=TzFaBJzYPVo',
#   'True'],
#  ['0',
#   '295',
#   'Summertime',
#   'Chris Columbo Quintet',
#   'https://www.youtube.com/watch?v=BAqD17wrLMg',
#   'True'],
#  ['0',
#   '296',
#   'Summertime',
#   'The Page 7',
#   'https://www.youtube.com/watch?v=eDaHIWbRrE4',
#   'True'],
#  ['0',
#   '297',
#   'Summertime',
#   'Joe Pass featuring Clare Fischer',
#   'https://www.youtube.com/watch?v=wjv_TqXgvh0',
#   'True'],
#  ['0',
#   '298',
#   'Summertime',
#   'Gary Burton',
#   'https://www.youtube.com/watch?v=soYP5yNnQNE',
#   'True'],
#  ['0',
#   '299',
#   'Summertime',
#   'The Rocketeers',
#   'https://www.youtube.com/watch?v=GNd1wI3nlxM',
#   'True'],
#  ['0',
#   '300',
#   'Summertime',
#   'Bill Evans Trio',
#   'https://www.youtube.com/watch?v=gNRVQnz6jps',
#   'True'],
#  ['0',
#   '301',
#   'Summertime',
#   'Hank Jacobs',
#   'https://www.youtube.com/watch?v=1ZrL6_5Tbjs',
#   'True'],
#  ['0',
#   '302',
#   'Summertime',
#   'Albert Ayler',
#   'https://www.youtube.com/watch?v=bQXk-0C-wVM',
#   'True'],
#  ['0',
#   '303',
#   'Summertime',
#   'Fausto Papetti',
#   'https://www.youtube.com/watch?v=2CwervpqD1E',
#   'True'],
#  ['0',
#   '304',
#   'Summer Time',
#   'Sam (The Man) Taylor',
#   'https://www.youtube.com/watch?v=MmLf9zd22WM',
#   'True'],
#  ['0',
#   '305',
#   'Summertime',
#   "Booker T. & The M.G.'s",
#   'https://www.youtube.com/watch?v=0Rr_6VNF2To',
#   'True'],
#  ['0',
#   '306',
#   'Summertime',
#   'John Schroeder and Orchestra',
#   'https://www.youtube.com/watch?v=dmiKxNDxhac',
#   'True'],
#  ['0',
#   '307',
#   'Summertime',
#   'Tony Scott and The Indonesian All Stars',
#   'https://www.youtube.com/watch?v=ufGwkTwHo6Y',
#   'True'],
#  ['0',
#   '308',
#   'Summertime',
#   'Günter Noris',
#   'https://www.youtube.com/watch?v=VD3VqKlssxc',
#   'True'],
#  ['0',
#   '309',
#   'Summertime',
#   'Ten Years After',
#   'https://www.youtube.com/watch?v=tI-q8z4SY9M',
#   'True'],
#  ['0',
#   '310',
#   'Summertime',
#   'Terumasa Hino Quartet',
#   'https://www.youtube.com/watch?v=4yAEsJjb2eo',
#   'True'],
#  ['0',
#   '311',
#   'Summertime',
#   'Paul Desmond',
#   'https://www.youtube.com/watch?v=HZkT4sxZ2Og',
#   'True'],
#  ['0',
#   '312',
#   'Summertime',
#   'Lou Donaldson',
#   'https://www.youtube.com/watch?v=0UxUgoCMTGI',
#   'True'],
#  ['0',
#   '313',
#   'Summertime',
#   'Polished Brass of London',
#   'https://www.youtube.com/watch?v=udZoZdLUNy4',
#   'True'],
#  ['0',
#   '314',
#   'Summer Time',
#   'Jackie Mittoo',
#   'https://www.youtube.com/watch?v=fGEDiCh8V-E',
#   'True'],
#  ['0',
#   '315',
#   'Summertime',
#   'One G Plus Three',
#   'https://www.youtube.com/watch?v=ZqcF5qvf-qg',
#   'True'],
#  ['0',
#   '316',
#   'Summertime',
#   'Klaus Wunderlich',
#   'https://www.youtube.com/watch?v=VFOecIMnLfw',
#   'True'],
#  ['0',
#   '317',
#   'Summertime',
#   'Rhoda Scott',
#   'https://www.youtube.com/watch?v=CetehYycfPs',
#   'True'],
#  ['0',
#   '318',
#   'Summertime',
#   'Little Beaver',
#   'https://www.youtube.com/watch?v=cYIpsby31Rw',
#   'True'],
#  ['0',
#   '319',
#   'Summertime',
#   'Hugo Diaz',
#   'https://www.youtube.com/watch?v=vo4IrtulclA',
#   'True'],
#  ['0',
#   '320',
#   "Summertime; It Ain't Necessarily So; Bess, You Is My Woman; I Got Plenty o' Nuttin",
#   'George Feyer',
#   'https://www.youtube.com/watch?v=70gpOMRWjg8',
#   'True'],
#  ['0',
#   '321',
#   'Summertime- De la comédie musicale "Porgy And Bess"',
#   'Georges Jouvin',
#   'https://www.youtube.com/watch?v=FNnYj1n7FO8',
#   'True'],
#  ['0',
#   '322',
#   'Summertime',
#   'Ekseption',
#   'https://www.youtube.com/watch?v=Q5bweWtZXLQ',
#   'True'],
#  ['0',
#   '323',
#   'Summertime',
#   'Gojkovic - Kovacev',
#   'https://www.youtube.com/watch?v=HLrd1_3hxF4',
#   'True'],
#  ['0',
#   '324',
#   'Summertime',
#   'Roy Meriwether',
#   'https://www.youtube.com/watch?v=9HZfcvPyy3E',
#   'True'],
#  ['0',
#   '325',
#   'Summertime',
#   'Adam Makowicz',
#   'https://www.youtube.com/watch?v=BPlHdxjhwhc',
#   'True'],
#  ['0',
#   '326',
#   'Nightmare / Summertime',
#   'John Fahey',
#   'https://www.youtube.com/watch?v=4PNdzq1qKoM',
#   'True'],
#  ['0',
#   '327',
#   'Summertime',
#   'The Allen Toussaint Orchestra',
#   'https://www.youtube.com/watch?v=5MYDJYeW8lo',
#   'False'],
#  ['0',
#   '328',
#   'Summertime',
#   'The Gino Marinello Orchestra',
#   'https://www.youtube.com/watch?v=qnYmrv7RFHM',
#   'False'],
#  ['0',
#   '329',
#   'Summertime',
#   'Randy Sabien',
#   'https://www.youtube.com/watch?v=hDcs14XUGsw',
#   'True'],
#  ['0',
#   '330',
#   'Summertime',
#   'Link Protrudi and the Jaymen',
#   'https://www.youtube.com/watch?v=TR4cmuJ2wC4',
#   'True'],
#  ['0',
#   '331',
#   'Summertime',
#   'Takehiro Honda',
#   'https://www.youtube.com/watch?v=Cv5THHhpzEE',
#   'False'],
#  ['0',
#   '332',
#   'Summertime',
#   'Miles & Quincy',
#   'https://www.youtube.com/watch?v=WR1bOE3Fszo',
#   'True'],
#  ['0',
#   '333',
#   'Summertime',
#   'Stefan Nicolaï',
#   'https://www.youtube.com/watch?v=ud4XITtp4lg',
#   'True'],
#  ['0',
#   '334',
#   '6/8 Summertime',
#   "Ron Levy's Wild Kingdom",
#   'https://www.youtube.com/watch?v=RFkYSVrn2QA',
#   'True'],
#  ['0',
#   '335',
#   'Summertime',
#   'Sir Roland Hanna Quartet',
#   'https://www.youtube.com/watch?v=782b9wUlhXk',
#   'True'],
#  ['0',
#   '336',
#   'Summertime',
#   'Junko Onishi Trio',
#   'https://www.youtube.com/watch?v=HrF8dODjoTI',
#   'True'],
#  ['0',
#   '337',
#   'Summertime',
#   'Courtney Pine',
#   'https://www.youtube.com/watch?v=gSK2Za0FFPU',
#   'True'],
#  ['0',
#   '338',
#   'Summertime',
#   'Mr. Review',
#   'https://www.youtube.com/watch?v=iQCrjxEj9No',
#   'True'],
#  ['0',
#   '339',
#   'Summertime',
#   'Shorty Rogers and Bill Perkins',
#   'https://www.youtube.com/watch?v=fbwOwy83HbI',
#   'False'],
#  ['0',
#   '340',
#   'Summertime',
#   'The Iguanas',
#   'https://www.youtube.com/watch?v=htS3HcGbhWw',
#   'True'],
#  ['0',
#   '341',
#   'Summertime',
#   'Dennis Marcellino & Mark Stefani',
#   'https://www.youtube.com/watch?v=nuaVgJFbOBs',
#   'True'],
#  ['0',
#   '342',
#   'Summertime',
#   'The Hi Hats',
#   'https://www.youtube.com/watch?v=j2BwDPKoH0Y',
#   'True'],
#  ['0',
#   '343',
#   'Summertime',
#   'EZ Louis',
#   'https://www.youtube.com/watch?v=DfXE25Xn9ws',
#   'True'],
#  ['0',
#   '344',
#   'Summertime',
#   'Michael Lowenstern',
#   'https://www.youtube.com/watch?v=fNO4eY4TV1M',
#   'True'],
#  ['0',
#   '345',
#   'Summertime',
#   'Marcus Miller',
#   'https://www.youtube.com/watch?v=iW7Udh7NFbk',
#   'True'],
#  ['0',
#   '346',
#   'Summertime',
#   'Joshua Redman',
#   'https://www.youtube.com/watch?v=J0A9_V6Oi3w',
#   'True'],
#  ['0',
#   '347',
#   'Summertime',
#   'Steven C.',
#   'https://www.youtube.com/watch?v=xdQwpZdVkC0',
#   'True'],
#  ['0',
#   '348',
#   'Summertime',
#   'Eugene Park',
#   'https://www.youtube.com/watch?v=rjCQiSyYPts',
#   'True'],
#  ['0',
#   '349',
#   'Summertime',
#   'Kenny G. feat. George Benson',
#   'https://www.youtube.com/watch?v=XOeZPk16ZDM',
#   'True'],
#  ['0',
#   '350',
#   'Summertime',
#   'Steelasophical',
#   'https://www.youtube.com/watch?v=v_cdTTsskfk',
#   'True'],
#  ['0',
#   '351',
#   'Summertime',
#   'Pearl Street jazz Band',
#   'https://www.youtube.com/watch?v=YfaJGNx1bbA',
#   'False'],
#  ['0',
#   '352',
#   'Summertime',
#   'Antoine Hervé',
#   'https://www.youtube.com/watch?v=zJEKaodBLtE',
#   'True'],
#  ['0',
#   '353',
#   'Summertime',
#   'Soriba Kouyaté',
#   'https://www.youtube.com/watch?v=7oFLWP_AU0Y',
#   'True'],
#  ['0',
#   '354',
#   'Summertime',
#   'Orchestra Jazz Della Sardegna',
#   'https://www.youtube.com/watch?v=qvAOr7PVYis',
#   'True'],
#  ['0',
#   '355',
#   'Summertime',
#   'Ray Brown, John Clayton, Christian McBride',
#   'https://www.youtube.com/watch?v=wB47zV1SM-g',
#   'True'],
#  ['0',
#   '356',
#   'Summertime',
#   'The Great Jazz Trio',
#   'https://www.youtube.com/watch?v=TrPeDMJiFU8',
#   'True'],
#  ['0',
#   '357',
#   'Summertime',
#   'Paolo Fresu',
#   'https://www.youtube.com/watch?v=awLpNDk4pPs',
#   'True'],
#  ['0',
#   '358',
#   'Summertime',
#   'Harold Mabern Trio',
#   'https://www.youtube.com/watch?v=YUXYQCX3slY',
#   'True'],
#  ['0',
#   '359',
#   'Summertime',
#   'John Fahey',
#   'https://www.youtube.com/watch?v=B5zvT7eBJOg',
#   'True'],
#  ['0',
#   '360',
#   'Summertime',
#   'Neil Stacey',
#   'https://www.youtube.com/watch?v=mZ3jcsauQsc',
#   'False'],
#  ['0',
#   '361',
#   'Summertime',
#   'Anthony Molinaro, Howard Levy',
#   'https://www.youtube.com/watch?v=udaHEJ0ff1s',
#   'False'],
#  ['0',
#   '362',
#   'Summertime',
#   "Negroni's Trio",
#   'https://www.youtube.com/watch?v=EgeCwI0arvY',
#   'True'],
#  ['0',
#   '363',
#   'Summertime',
#   'Francesco Cafiso & Strings',
#   'https://www.youtube.com/watch?v=OKlcIDfH4qs',
#   'True'],
#  ['0',
#   '364',
#   'Summertime',
#   'David Garfield, featuring Abraham Laboriel & Luis Conte',
#   'https://www.youtube.com/watch?v=aMwhmTe32T8',
#   'True'],
#  ['0',
#   '365',
#   'Summertime',
#   'Preservation Hall Jazz Band',
#   'https://www.youtube.com/watch?v=S7iBtY0FllY',
#   'True'],
#  ['0',
#   '366',
#   'Summertime',
#   'The Phil Woods Quintet',
#   'https://www.youtube.com/watch?v=5jHUGKeQ6AY',
#   'True'],
#  ['0',
#   '367',
#   'Summertime',
#   'Manu Dibango',
#   'https://www.youtube.com/watch?v=_1v16FERhuA',
#   'True'],
#  ['0',
#   '368',
#   'Summertime',
#   'Samuel Quinto Trio',
#   'https://www.youtube.com/watch?v=PHaBniWswG4',
#   'True'],
#  ['0',
#   '369',
#   'Summertime/Footprints',
#   'Jason Parker Quartet',
#   'https://www.youtube.com/watch?v=gDpBffpFjpA',
#   'True'],
#  ['0',
#   '370',
#   'Summertime Variations',
#   'Fazil Say',
#   'https://www.youtube.com/watch?v=5PRt11e7ojk',
#   'True'],
#  ['0',
#   '371',
#   'Summertime',
#   'Chris Bauer',
#   'https://www.youtube.com/watch?v=YA7Qg-udC2k',
#   'True'],
#  ['0',
#   '372',
#   'Summertime',
#   'David Garrett',
#   'https://www.youtube.com/watch?v=8PbJP3OF0vI',
#   'True'],
#  ['0',
#   '373',
#   'Summertime',
#   'Kenny Dorham, featuring Joe Henderson',
#   'https://www.youtube.com/watch?v=E_MDRRTlAAA',
#   'True'],
#  ['0',
#   '374',
#   'Summertime',
#   'Fedora Strings',
#   'https://www.youtube.com/watch?v=nWP31LhSPEU',
#   'True'],
#  ['0',
#   '375',
#   'Summertime',
#   'Benjamin Herman',
#   'https://www.youtube.com/watch?v=5mO1ztxPa4Q',
#   'True'],
#  ['0',
#   '376',
#   'Summertime',
#   'Basily Boys',
#   'https://www.youtube.com/watch?v=o09y5k6YXTE',
#   'True'],
#  ['0',
#   '377',
#   'Summertime',
#   'Jessica Williams',
#   'https://www.youtube.com/watch?v=hV719vWcX7M',
#   'False'],
#  ['0',
#   '378',
#   'Summertime',
#   'Matthew Shipp',
#   'https://www.youtube.com/watch?v=xMg3CM15zBU',
#   'True'],
#  ['0',
#   '379',
#   'Summertime',
#   'Kevin Eubanks / Stanley Jordan',
#   'https://www.youtube.com/watch?v=4dIO2iwb2BM',
#   'True'],
#  ['0',
#   '380',
#   'Summertime',
#   'Dave Wilson Quartet',
#   'https://www.youtube.com/watch?v=nmdwCkIjeTM',
#   'True'],
#  ['0',
#   '381',
#   "Doin' Time",
#   'Sublime',
#   'https://www.youtube.com/watch?v=tF1628qACPM',
#   'True'],
#  ['0',
#   '382',
#   'Summertime',
#   'Robb Johnson',
#   'https://www.youtube.com/watch?v=qMKAKJFYBvk',
#   'False'],
#  ['0',
#   '383',
#   'Kesäyö',
#   'Tutta Jew',
#   'https://www.youtube.com/watch?v=zqncLTFi8HY',
#   'True'],
#  ['0',
#   '384',
#   'Summertime',
#   'Angélique Kidjo',
#   'https://www.youtube.com/watch?v=KW_L_oLo3-4',
#   'True'],
#  ['0',
#   '385',
#   'Verano',
#   'Tony Ronald',
#   'https://www.youtube.com/watch?v=ryA3nRKCTwE',
#   'True'],
#  ['0',
#   '386',
#   'Summertime',
#   'Soweto String Quartet',
#   'https://www.youtube.com/watch?v=pBzBo-0o6Ew',
#   'True'],
#  ['1',
#   '0',
#   'Stille Nacht! Heilige Nacht!',
#   'Joseph Mohr, Franz Gruber',
#   'https://www.youtube.com/watch?v=3fgaOX7TqWI',
#   'True'],
#  ['1',
#   '1',
#   'Stille Nacht, Heilige Nacht',
#   'Comedian Harmonists',
#   'https://www.youtube.com/watch?v=M7JKtNg_irI',
#   'True'],
#  ['1',
#   '2',
#   'Stille Nacht',
#   'Mireille Mathieu',
#   'https://www.youtube.com/watch?v=TUw-_3SYEmc',
#   'False'],
#  ['1',
#   '3',
#   'Stille Nacht',
#   'Ornella Vanoni',
#   'https://www.youtube.com/watch?v=-TQdFL_7O8M',
#   'True'],
#  ['1',
#   '4',
#   'Stille Nacht',
#   'Audrey Landers',
#   'https://www.youtube.com/watch?v=xb9EmY7_8jc',
#   'True'],
#  ['1',
#   '5',
#   'Silent Night',
#   'John McDermott, duet with Allison Girvan',
#   'https://www.youtube.com/watch?v=Jo5XuACsBhQ',
#   'True'],
#  ['1',
#   '6',
#   'Silent Night',
#   'Dionne Warwick & Plácido Domingo',
#   'https://www.youtube.com/watch?v=Wm_r1WjnUGo',
#   'True'],
#  ['1',
#   '7',
#   'Stille Nacht! Heilige Nacht!',
#   'Die Roten Rosen',
#   'https://www.youtube.com/watch?v=O9bWsEE7R3M',
#   'True'],
#  ['1',
#   '8',
#   'Stille Nacht',
#   'David Krienke',
#   'https://www.youtube.com/watch?v=PAs9OXKc4Uc',
#   'True'],
#  ['1',
#   '9',
#   'Silent Night',
#   'Luke McMaster',
#   'https://www.youtube.com/watch?v=0b1GLf6bKQs',
#   'True'],
#  ['1',
#   '10',
#   'Silent Night',
#   'Anemia',
#   'https://www.youtube.com/watch?v=IMdBopDQzho',
#   'True'],
#  ['1',
#   '11',
#   'Silent Night, Holy Night',
#   'Paul Whiteman and His Orchestra',
#   'https://www.youtube.com/watch?v=lqjlNtmxhMk',
#   'True'],
#  ['1',
#   '12',
#   'Silent Night, Holy Night',
#   'Percy Faith & His Orchestra',
#   'https://www.youtube.com/watch?v=BYojxpeGmmM',
#   'True'],
#  ['1',
#   '13',
#   'Silent Night',
#   'Billy Vaughn',
#   'https://www.youtube.com/watch?v=L60PzPlof4M',
#   'True'],
#  ['1',
#   '14',
#   'Silent Night',
#   'Ken Griffin',
#   'https://www.youtube.com/watch?v=BdJXZ7lRSzk',
#   'True'],
#  ['1',
#   '15',
#   'Silent Night',
#   'Chet Atkins',
#   'https://www.youtube.com/watch?v=RObcvcJ-jzA',
#   'True'],
#  ['1',
#   '16',
#   'Silent Night - Joy to the World',
#   'Arthur Lyman',
#   'https://www.youtube.com/watch?v=seR_f_C837s',
#   'True'],
#  ['1',
#   '17',
#   'Silent Night',
#   'The Incredible Jimmy Smith',
#   'https://www.youtube.com/watch?v=TZrFLfRCVY8',
#   'True'],
#  ['1',
#   '18',
#   'Silent Night, Holy Night',
#   'John Fahey',
#   'https://www.youtube.com/watch?v=lA3XihXYwg8',
#   'True'],
#  ['1',
#   '19',
#   'Silent Night',
#   'The Torero Band',
#   'https://www.youtube.com/watch?v=TfBgd4TQBro',
#   'True'],
#  ['1',
#   '20',
#   'Silent Night',
#   'Can',
#   'https://www.youtube.com/watch?v=iInAuoio-pQ',
#   'True'],
#  ['1',
#   '21',
#   'Silent Night',
#   'The Don Burrows Quintet',
#   'https://www.youtube.com/watch?v=nQIvljJ9jZQ',
#   'True'],
#  ['1',
#   '22',
#   'Silent Night',
#   'Jimmy Martin',
#   'https://www.youtube.com/watch?v=LWH5cC_x-CU',
#   'True'],
#  ['1',
#   '23',
#   'Stille Nacht',
#   'Mannheim Steamroller',
#   'https://www.youtube.com/watch?v=EwlFOx12Nzs',
#   'True'],
#  ['1',
#   '24',
#   'Silent Night',
#   'Kenny G',
#   'https://www.youtube.com/watch?v=HJ2mku_DTz8',
#   'True'],
#  ['1',
#   '25',
#   'Silent Night',
#   'Gary Hoey',
# ...
#   'True'],
#  ['4',
#   '97',
#   'What Child Is This?',
#   'Andrea Bocelli with Mary J. Blige',
#   'https://www.youtube.com/watch?v=4bH6iYBuFq4',
#   'False'],
#  ['4',
#   '98',
#   'What Child Is This?',
#   'Halford',
#   'https://www.youtube.com/watch?v=FccHGngOGDE',
#   'True'],
#  ['4',
#   '99',
#   'What Child Is This?',
#   'Lark & Spur',
#   'https://www.youtube.com/watch?v=BCIfIGmNyAc',
#   'True'],
#  ['4',
#   '100',
#   'What Child Is This',
#   'The Museum',
#   'https://www.youtube.com/watch?v=tVHbOY8w0Qc',
#   'True'],
#  ['4',
#   '101',
#   'What Child Is This?',
#   'Scott Weiland',
#   'https://www.youtube.com/watch?v=qTceR2P9uYA',
#   'True'],
#  ['4',
#   '102',
#   'What Child Is This?',
#   'Keith & Kristyn Getty',
#   'https://www.youtube.com/watch?v=8oblT1rxysU',
#   'True'],
#  ['4',
#   '103',
#   'What Child Is This',
#   'Found Wandering',
#   'https://www.youtube.com/watch?v=aUlSzojAl0w',
#   'True'],
#  ['4',
#   '104',
#   'What Child Is This?',
#   'Jamie Grace with Abandon Kansas',
#   'https://www.youtube.com/watch?v=S9f7cs8MR7c',
#   'True'],
#  ['4',
#   '105',
#   'What Child Is This',
#   'Richard Marx',
#   'https://www.youtube.com/watch?v=nb08lWh4KRI',
#   'True'],
#  ['4',
#   '106',
#   'What Child Is This?',
#   'Folk Angel',
#   'https://www.youtube.com/watch?v=ml5pOCyewpk',
#   'True'],
#  ['4',
#   '107',
#   'What Child Is This?',
#   'Leper',
#   'https://www.youtube.com/watch?v=GA0aD4XvvcE',
#   'True'],
#  ['4',
#   '108',
#   'What Child Is This',
#   'The Modern Post',
#   'https://www.youtube.com/watch?v=zkT74qQWPK0',
#   'True'],
#  ['4',
#   '109',
#   'What Child Is This',
#   'Radha Mehta',
#   'https://www.youtube.com/watch?v=Sms4z5rwHwA',
#   'True'],
#  ['4',
#   '110',
#   'What Child Is This?',
#   'Jazz at Lincoln Center Orchestra with Wynton Marsalis featuring Cécile McLorin Salvant',
#   'https://www.youtube.com/watch?v=83rRIi5iXpw',
#   'True'],
#  ['4',
#   '111',
#   'What Child Is This?',
#   'David Wesley',
#   'https://www.youtube.com/watch?v=GLqcGpNfqGc',
#   'True'],
#  ['4',
#   '113',
#   'What Child Is This',
#   'Amy Grant',
#   'https://www.youtube.com/watch?v=J6tuD-wQ3R4',
#   'True'],
#  ['4',
#   '114',
#   'What Child Is This?',
#   'Peter Hollens',
#   'https://www.youtube.com/watch?v=IGqf5ha_GEA',
#   'True'],
#  ['4',
#   '115',
#   'What Child Is This',
#   'Jordan Smith',
#   'https://www.youtube.com/watch?v=wJFpHpGrjgw',
#   'True'],
#  ['4',
#   '116',
#   'What Child Is This?',
#   'Jaymay',
#   'https://www.youtube.com/watch?v=FRBJHPstUlY',
#   'True'],
#  ['4',
#   '117',
#   'What Child Is This?',
#   'Marc Martel featuring Ron Block',
#   'https://www.youtube.com/watch?v=cIU-FyTRO4I',
#   'True'],
#  ['4',
#   '118',
#   'What Child Is This',
#   'Josh Garrels',
#   'https://www.youtube.com/watch?v=2m1annHJjw4',
#   'True'],
#  ['4',
#   '119',
#   'Stay Away',
#   'Elvis Presley with The Jordanaires',
#   'https://www.youtube.com/watch?v=Cbn3_LcHGHQ',
#   'True'],
#  ['4',
#   '120',
#   'Stay Away',
#   'Number Nine [1]',
#   'https://www.youtube.com/watch?v=UDa3TU0YLlQ',
#   'True'],
#  ['4',
#   '121',
#   'Amsterdam',
#   'Jacques Brel',
#   'https://www.youtube.com/watch?v=n2kkr0e_dTQ',
#   'True'],
#  ['4',
#   '122',
#   'Amsterdam',
#   'Camille [1]',
#   'https://www.youtube.com/watch?v=Nd2Zb8Ci8-8',
#   'True'],
#  ['4',
#   '123',
#   'Amsterdam',
#   'Özdemir Erdoğan',
#   'https://www.youtube.com/watch?v=e3Prlw_XqmQ',
#   'True'],
#  ['4',
#   '124',
#   'Amsterdam',
#   'Angelica Matveeva',
#   'https://www.youtube.com/watch?v=RLvbXui7aL4',
#   'True'],
#  ['4',
#   '125',
#   'Amsterdam',
#   'Diamanda Galás',
#   'https://www.youtube.com/watch?v=GRO3sFTCuQ8',
#   'True'],
#  ['4',
#   '126',
#   'Amsterdam',
#   'Liesbeth List',
#   'https://www.youtube.com/watch?v=7sXS3hHOtZo',
#   'True'],
#  ['4',
#   '127',
#   'Amsterdam',
#   'De Dijk',
#   'https://www.youtube.com/watch?v=ACqVRzyxef4',
#   'True'],
#  ['4',
#   '128',
#   'De stad Amsterdam',
#   'Acda en de Munnik',
#   'https://www.youtube.com/watch?v=mXgyi3FYHak',
#   'True'],
#  ['4',
#   '129',
#   'Vrouwencafé',
#   'Frans Halsema',
#   'https://www.youtube.com/watch?v=SjaHuxHRPgs',
#   'True'],
#  ['4',
#   '130',
#   'Amsterdam',
#   'Scott Walker',
#   'https://www.youtube.com/watch?v=uF_eVJ7WYaY',
#   'True'],
#  ['4',
#   '131',
#   'Amsterdam',
#   'John Denver',
#   'https://www.youtube.com/watch?v=_5pwk3AAjjk',
#   'True'],
#  ['4',
#   '132',
#   'Amsterdam',
#   'David Bowie',
#   'https://www.youtube.com/watch?v=4uPZIG5BHD4',
#   'True'],
#  ['4',
#   '133',
#   'Amsterdam',
#   'Goodbye Mr. Mackenzie',
#   'https://www.youtube.com/watch?v=N7eGriSwCYw',
#   'True'],
#  ['4',
#   '134',
#   'Port of Amsterdam',
#   'Jack Lukeman & The Black Romantics',
#   'https://www.youtube.com/watch?v=X8np2g2WRk0',
#   'True'],
#  ['4',
#   '135',
#   'Amsterdam',
#   'Douwe Heeringa',
#   'https://www.youtube.com/watch?v=uUE25rkSU2w',
#   'True'],
#  ['4',
#   '136',
#   'Amsterdam',
#   'Klaus Hoffmann',
#   'https://www.youtube.com/watch?v=wo7tLk50Fr8',
#   'True'],
#  ['4',
#   '137',
#   'Amsterdam',
#   'Queen Bee',
#   'https://www.youtube.com/watch?v=yTb2O6MnRpo',
#   'True'],
#  ['4',
#   '138',
#   'Das Brautkleid trug sie zur Maienzeit',
#   'Hildegard Knef',
#   'https://www.youtube.com/watch?v=8384RQKSuyw',
#   'True'],
#  ['4',
#   '139',
#   'Greensleeves (Mein Land)',
#   'Ivan Rebroff',
#   'https://www.youtube.com/watch?v=vFAlKx_McDk',
#   'True'],
#  ['5',
#   '0',
#   'White Christmas',
#   'Bing Crosby & Martha Mears',
#   'https://www.youtube.com/watch?v=RhNgZQxKESw',
#   'True'],
#  ['5',
#   '1',
#   'White Christmas',
#   'Bing Crosby with Ken Darby Singers and John Scott Trotter and His Orchestra',
#   'https://www.youtube.com/watch?v=Ny8FJWf2pAg',
#   'True'],
#  ['5',
#   '2',
#   'White Christmas',
#   'Charlie Spivak and His Orchestra - Vocal Chorus by Garry Stevens',
#   'https://www.youtube.com/watch?v=ttd_jMD1g38',
#   'True'],
#  ['5',
#   '3',
#   'White Christmas',
#   'Frank Sinatra',
#   'https://www.youtube.com/watch?v=q_XzZNCDWCA',
#   'True'],
#  ['5',
#   '4',
#   'White Christmas',
#   'Cowboy Copas',
#   'https://www.youtube.com/watch?v=D-Ed7DYyVGk',
#   'True'],
#  ['5',
#   '5',
#   'White Christmas',
#   'Eddy Howard and His Orchestra',
#   'https://www.youtube.com/watch?v=YF2QqL0l7Xc',
#   'True'],
#  ['5',
#   '6',
#   'White Christmas',
#   'Perry Como',
#   'https://www.youtube.com/watch?v=70_ac6bSRLQ',
#   'True'],
#  ['5',
#   '7',
#   'White Christmas',
#   'The Ravens',
#   'https://www.youtube.com/watch?v=U1qY5ZXv-X4',
#   'True'],
#  ['5',
#   '8',
#   'White Christmas',
#   'Ernest Tubb',
#   'https://www.youtube.com/watch?v=PNzvUh-tJRY',
#   'True'],
#  ['5',
#   '9',
#   'White Christmas',
#   'Sister Rosetta Tharpe with Rosette Gospel Singers',
#   'https://www.youtube.com/watch?v=VjY_p-EgHLs',
#   'True'],
#  ['5',
#   '10',
#   'White Christmas',
#   'Patti Page',
#   'https://www.youtube.com/watch?v=E13O3GoAuMQ',
#   'True'],
#  ['5',
#   '11',
#   'White Christmas',
#   'Gustav Winckler m. Statsradiofoniens underholdningsorkester',
#   'https://www.youtube.com/watch?v=FIFUdhc05TU',
#   'True'],
#  ['5',
#   '12',
#   'White Christmas',
#   'Les Paul and Mary Ford',
#   'https://www.youtube.com/watch?v=GL6VWzrklDo',
#   'True'],
#  ['5',
#   '13',
#   'White Christmas',
#   'The Drifters featuring Clyde McPhatter and Bill Pinckney',
#   'https://www.youtube.com/watch?v=6W23iz-YLH0',
#   'True'],
#  ['5',
#   '14',
#   'White Christmas',
#   'Rosemary Clooney with Percy Faith and His Orchestra and The Mellomen',
#   'https://www.youtube.com/watch?v=97xyTviQLq0',
#   'True'],
#  ['5',
#   '15',
#   'White Christmas',
#   'The Four Lovers',
#   'https://www.youtube.com/watch?v=WclBCpCmDCA',
#   'True'],
#  ['5',
#   '16',
#   'White Christmas',
#   'Elvis Presley',
#   'https://www.youtube.com/watch?v=SNLpawUrfcc',
#   'True'],
#  ['5',
#   '17',
#   'White Christmas',
#   'Pat Boone',
#   'https://www.youtube.com/watch?v=mBez_nWNj4I',
#   'True'],
#  ['5',
#   '18',
#   'White Christmas',
#   'Johnny Mathis',
#   'https://www.youtube.com/watch?v=X_kfUed9O84',
#   'True'],
#  ['5',
#   '19',
#   'White Christmas',
#   "Big Maybelle with Ernie Wilkins' Orch.",
#   'https://www.youtube.com/watch?v=q5qH-f98qnY',
#   'True'],
#  ['5',
#   '20',
#   'White Christmas',
#   'Connie Francis',
#   'https://www.youtube.com/watch?v=mVyGPA3vxow',
#   'True'],
#  ['5',
#   '21',
#   'White Christmas',
#   'Dean Martin',
#   'https://www.youtube.com/watch?v=J1M07l9SR_c',
#   'True'],
#  ['5',
#   '22',
#   'White Christmas',
#   'Peggy Lee',
#   'https://www.youtube.com/watch?v=M-DvD4ZI0-0',
#   'True'],
#  ['5',
#   '23',
#   'White Christmas',
#   'Paul Anka',
#   'https://www.youtube.com/watch?v=KkqnF5Zst0Y',
#   'True'],
#  ['5',
#   '24',
#   'White Christmas',
#   'Emile Ford and The Checkmates',
#   'https://www.youtube.com/watch?v=D3hX_e_x8M8',
#   'True'],
#  ['5',
#   '25',
#   'White Christmas',
#   'The Blue Diamonds',
#   'https://www.youtube.com/watch?v=N-zMd5AIIZ0',
#   'True'],
#  ['5',
#   '26',
#   'White Christmas',
#   'The Lennon Sisters',
#   'https://www.youtube.com/watch?v=H0MM2QNtEk0',
#   'True'],
#  ['5',
#   '27',
#   'White Christmas',
#   'Ella Fitzgerald',
#   'https://www.youtube.com/watch?v=6iKKBcCV3NY',
#   'True'],
#  ['5',
#   '28',
#   'White Christmas',
#   'Keely Smith',
#   'https://www.youtube.com/watch?v=njJyikqVRvo',
#   'True'],
#  ['5',
#   '29',
#   'White Christmas',
#   'Lawrence Welk and His Orchestra',
#   'https://www.youtube.com/watch?v=u_3cZ9dOMxk',
#   'True'],
#  ['5',
#   '30',
#   'White Christmas',
#   'The 4 Seasons',
#   'https://www.youtube.com/watch?v=VfO4xzrGunc',
#   'True'],
#  ['5',
#   '31',
#   'White Christmas',
#   'Walter Brennan',
#   'https://www.youtube.com/watch?v=MdMerkMKPU4',
#   'True'],
#  ['5',
#   '32',
#   'White Christmas',
#   'Bobby Vee with The Johnny Mann Singers',
#   'https://www.youtube.com/watch?v=wSwjTzMJzKM',
#   'True'],
#  ['5',
#   '33',
#   'White Christmas',
#   'The Miracles',
#   'https://www.youtube.com/watch?v=QIvYNAAN-dY',
#   'True'],
#  ['5',
#   '34',
#   'White Christmas',
#   'Jackie Wilson',
#   'https://www.youtube.com/watch?v=onzlbw5up94',
#   'True'],
#  ['5',
#   '35',
#   'White Christmas',
#   'Darlene Love',
#   'https://www.youtube.com/watch?v=7BVYDdl2M0A',
#   'False'],
#  ['5',
#   '36',
#   'White Christmas',
#   'Jim Reeves',
#   'https://www.youtube.com/watch?v=RhTG4evp-Bk',
#   'True'],
#  ['5',
#   '37',
#   'White Christmas',
#   'Andy Williams',
#   'https://www.youtube.com/watch?v=idF4-1oGILU',
#   'True'],
#  ['5',
#   '38',
#   'White Christmas',
#   'Bobby Vinton',
#   'https://www.youtube.com/watch?v=ABlus-IarRg',
#   'True'],
#  ['5',
#   '39',
#   'White Christmas',
#   'The Beach Boys',
#   'https://www.youtube.com/watch?v=yTmLY0mGYuM',
#   'True'],
#  ['5',
#   '40',
#   'White Christmas',
#   'Hank Thompson and The Brazos Valley Boys',
#   'https://www.youtube.com/watch?v=kbJQ3z38Yik',
#   'True'],
#  ['5',
#   '41',
#   'White Christmas',
#   'Jack Jones',
#   'https://www.youtube.com/watch?v=AVwyI5kFN3M',
#   'True'],
#  ['5',
#   '42',
#   'White Christmas',
#   'John Gary',
#   'https://www.youtube.com/watch?v=JjdvEt8OWLI',
#   'True'],
#  ['5',
#   '43',
#   'White Christmas',
#   'The Supremes',
#   'https://www.youtube.com/watch?v=eYxiOG7XU3s',
#   'True'],
#  ['5',
#   '44',
#   'White Christmas',
#   'Bob Marley & The Wailers',
#   'https://www.youtube.com/watch?v=98bjIDC8vU4',
#   'True'],
#  ['5',
#   '45',
#   'White Christmas',
#   'Earl Grant',
#   'https://www.youtube.com/watch?v=xtOUg4YBGkA',
#   'True'],
#  ['5',
#   '46',
#   'White Christmas',
#   'P.J. Proby',
#   'https://www.youtube.com/watch?v=jyPue5xE8Yw',
#   'True'],
#  ['5',
#   '47',
#   'White Christmas',
#   'Loretta Lynn',
#   'https://www.youtube.com/watch?v=q8FCYXiI7X0',
#   'True'],
#  ['5',
#   '48',
#   'White Christmas',
#   'The Lettermen',
#   'https://www.youtube.com/watch?v=BPNdHA3KlL4',
#   'False'],
#  ['5',
#   '49',
#   'White Christmas',
#   'Bonnie Guitar',
#   'https://www.youtube.com/watch?v=XscFPayBcvg',
#   'True'],
#  ['5',
#   '50',
#   'White Christmas',
#   'Lena Horne',
#   'https://www.youtube.com/watch?v=Q0CRv8sJNEo',
#   'True'],
#  ['5',
#   '51',
#   'White Christmas',
#   'Catherine McKinnon',
#   'https://www.youtube.com/watch?v=s0Z4t-vrEB4',
#   'True'],
#  ['5',
#   '52',
#   'White Christmas',
#   'Barbra Streisand',
#   'https://www.youtube.com/watch?v=tXmQK7mE3Ck',
#   'True'],
#  ['5',
#   '53',
#   'White Christmas',
#   'The Hep Stars',
#   'https://www.youtube.com/watch?v=OtzYWZ0tpDs',
#   'True'],
#  ['5',
#   '54',
#   'White Christmas',
#   'Otis Redding',
#   'https://www.youtube.com/watch?v=x_k5skKLwb8',
#   'True'],
#  ['5',
#   '55',
#   'White Christmas',
#   'Judith Durham',
#   'https://www.youtube.com/watch?v=kV89vo0HFe4',
#   'True'],
#  ['5',
#   '56',
#   'White Christmas',
#   'Mahalia Jackson',
#   'https://www.youtube.com/watch?v=pN-A0w6bCYM',
#   'True'],
#  ['5',
#   '57',
#   'White Christmas',
#   'The Temptations',
#   'https://www.youtube.com/watch?v=Bowdy4Oqj3A',
#   'True'],
#  ['5',
#   '58',
#   'White Christmas',
#   'Johnny Farnham',
#   'https://www.youtube.com/watch?v=ZK-Gc1veyH0',
#   'True'],
#  ['5',
#   '59',
#   'White Christmas',
#   'Tammy Wynette',
#   'https://www.youtube.com/watch?v=9BuvsR5Pzm0',
#   'True'],
#  ['5',
#   '60',
#   'White Christmas',
#   'Danny Davis and The Nashville Brass',
#   'https://www.youtube.com/watch?v=LttlvkGVbeU',
#   'True'],
#  ['5',
#   '61',
#   'White Christmas',
#   'The Partridge Family',
#   'https://www.youtube.com/watch?v=gHK0do31Hj4',
#   'True'],
#  ['5',
#   '62',
#   'White Christmas',
#   'Merle Haggard',
#   'https://www.youtube.com/watch?v=ZYAeuSwiHk8',
#   'True'],
#  ['5',
#   '63',
#   'White Christmas',
#   'Basic Black And Pearl',
#   'https://www.youtube.com/watch?v=UT3IugOF2DQ',
#   'True'],
#  ['5',
#   '64',
#   'White Christmas',
#   'Vera Lynn',
#   'https://www.youtube.com/watch?v=Nq92wF6SPEI',
#   'True'],
#  ['5',
#   '65',
#   'White Christmas',
#   'Davy Jones',
#   'https://www.youtube.com/watch?v=gsgQSC2Ox9o',
#   'True'],
#  ['5',
#   '66',
#   'White Christmas',
#   'The Mormon Tabernacle Choir',
#   'https://www.youtube.com/watch?v=ad4juBEbkc4',
#   'True'],
#  ['5',
#   '67',
#   'Winter Wonderland/Silver Bells/White Christmas',
#   'Carpenters',
#   'https://www.youtube.com/watch?v=sSrfNX2Qx8s',
#   'True'],
#  ['5',
#   '68',
#   'White Christmas',
#   'The Whispers',
#   'https://www.youtube.com/watch?v=Kvk3zruq9I8',
#   'True'],
#  ['5',
#   '69',
#   'White Christmas',
#   'Willie Nelson',
#   'https://www.youtube.com/watch?v=6GeZYm8Tt5c',
#   'True'],
#  ['5',
#   '70',
#   'White Christmas',
#   'Stiff Little Fingers',
#   'https://www.youtube.com/watch?v=yx2doRHPwkQ',
#   'True'],
#  ['5',
#   '71',
#   'White Christmas',
#   'Slim Whitman',
#   'https://www.youtube.com/watch?v=uC8AOq7S4B0',
#   'True'],
#  ['5',
#   '72',
#   'White Christmas',
#   'The Yobs',
#   'https://www.youtube.com/watch?v=oL2zd1p7z-Q',
#   'True'],
#  ['5',
#   '73',
#   'White Christmas',
#   'Darts',
#   'https://www.youtube.com/watch?v=c0bxPTLYP0E',
#   'True'],
#  ['5',
#   '74',
#   'White Christmas',
#   'Kenny Rogers',
#   'https://www.youtube.com/watch?v=1x0_hSmZJHk',
#   'True'],
#  ['5',
#   '75',
#   'White Christmas',
#   'Boney M.',
#   'https://www.youtube.com/watch?v=W2KXvRyWyGc',
#   'True'],
#  ['5',
#   '76',
#   'White Christmas',
#   'Ronnie Tober',
#   'https://www.youtube.com/watch?v=YBY2u1nO2yM',
#   'True'],
#  ['5',
#   '77',
#   'White Christmas',
#   "St. Winifred's School Choir",
#   'https://www.youtube.com/watch?v=QUNiH1UWMTc',
#   'True'],
#  ['5',
#   '78',
#   'White Christmas',
#   'Al Green',
#   'https://www.youtube.com/watch?v=_iPLfJvGCWs',
#   'True'],
#  ['5',
#   '79',
#   'White Christmas',
#   'Kenny & Dolly',
#   'https://www.youtube.com/watch?v=9VDkjxOyJBQ',
#   'True'],
#  ['5',
#   '80',
#   'White Christmas',
#   'Edwin Hawkins',
#   'https://www.youtube.com/watch?v=u4jSUVRBFNY',
#   'True'],
#  ['5',
#   '81',
#   'White Christmas',
#   'George Strait',
#   'https://www.youtube.com/watch?v=dwo6VFNR6Ko',
#   'True'],
#  ['5',
#   '82',
#   'White Christmas',
#   'Rita Reys',
#   'https://www.youtube.com/watch?v=01p4va6J_Uo',
#   'True'],
#  ['5',
#   '83',
#   'White Christmas',
#   'The Swingles',
#   'https://www.youtube.com/watch?v=GLAzrOuDVyI',
#   'True'],
#  ['5',
#   '84',
#   'White Christmas',
#   'John Holt',
#   'https://www.youtube.com/watch?v=_pYRoQQAoRk',
#   'True'],
#  ['5',
#   '85',
#   'White Christmas',
#   'Ray Price',
#   'https://www.youtube.com/watch?v=X_FaD6mSieA',
#   'True'],
#  ['5',
#   '86',
#   'White Christmas',
#   'Buddy Emmons',
#   'https://www.youtube.com/watch?v=4oYSc6UOKuA',
#   'True'],
#  ['5',
#   '87',
#   'White Christmas',
#   'Air Supply',
#   'https://www.youtube.com/watch?v=H0law9-fpHQ',
#   'True'],
#  ['5',
#   '88',
#   'White Christmas',
#   'Helen Merrill',
#   'https://www.youtube.com/watch?v=shcolH0pqdw',
#   'True'],
#  ['5',
#   '89',
#   'White Christmas',
#   'Leon Redbone',
#   'https://www.youtube.com/watch?v=I_Ooam_DePw',
#   'True'],
#  ['5',
#   '90',
#   'White Christmas',
#   'New Kids on the Block',
#   'https://www.youtube.com/watch?v=XP6DPLdakdk',
#   'True'],
#  ...]

# %%
shs100k_artists = set()
for row in shs100k_data:
    artist_name = row[3]
    shs100k_artists.add(artist_name)
print(len(shs100k_artists))
# Out:
# 34170

# %%
artist_name
# Out:
# 'The Queers'

# %%
from collections import Counter

# %%
with open(shs100k_train_csv_path, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    shs100k_train_indices = list(reader)

with open(shs100k_test_csv_path, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    shs100k_test_indices = list(reader)

with open(shs100k_val_csv_path) as f:
    reader = csv.reader(f, delimiter='\t')
    shs100k_val_indices = list(reader)

# %%
print(len(shs100k_val_indices))
print(f'{len(set([int(i[0]) for i in shs100k_val_indices])):>6,} SHS100K2-VAL cliques are used.')
# Out:
# 10884
#  1,842 SHS100K2-VAL cliques are used.

# %%
shs100k_train_clique_sizes = np.array([[int(i) for i in row] for row in shs100k_train_indices])
shs100k_train_clique_sizes = shs100k_train_clique_sizes[:, 0]
shs100k_train_clique_sizes = np.array(list(Counter(shs100k_train_clique_sizes.tolist()).values()))

print(f'Max: {shs100k_train_clique_sizes.max()}')
print(f'Median {np.median(shs100k_train_clique_sizes)}')
print(f'Mean: {shs100k_train_clique_sizes.mean()}')
print()

shs100k_val_clique_sizes = np.array([[int(i) for i in row] for row in shs100k_val_indices])
shs100k_val_clique_sizes = shs100k_val_clique_sizes[:, 0]
shs100k_val_clique_sizes = np.array(list(Counter(shs100k_val_clique_sizes.tolist()).values()))

print(f'Max: {shs100k_val_clique_sizes.max()}')
print(f'Median {np.median(shs100k_val_clique_sizes)}')
print(f'Mean: {shs100k_val_clique_sizes.mean()}')
print()

shs100k_test_clique_sizes = np.array([[int(i) for i in row] for row in shs100k_test_indices])
shs100k_test_clique_sizes = shs100k_test_clique_sizes[:, 0]
shs100k_test_clique_sizes = np.array(list(Counter(shs100k_test_clique_sizes.tolist()).values()))

print(f'Max: {shs100k_test_clique_sizes.max()}')
print(f'Median {np.median(shs100k_test_clique_sizes)}')
print(f'Mean: {shs100k_test_clique_sizes.mean()}')
# Out:
# Max: 359
# Median 12.0
# Mean: 16.35818933132983
#
# Max: 17
# Median 6.0
# Mean: 5.908794788273616
#
# Max: 162
# Median 5.0
# Mean: 6.233451536643026

# %%
shs100k_train_data = []
for row_i in shs100k_train_indices:
    for row_j in shs100k_data:
        if row_i[0] == row_j[0] and row_i[1] == row_j[1]:
            shs100k_train_data.append(row_j)
            break
print(len(shs100k_train_data))
assert len(shs100k_train_data) == len(shs100k_train_indices)

shs100k_train_dict = {}
for row in shs100k_train_data:
    clique_id = row[0]
    # version_id = row[1]
    title = hard_clean_text(clean_parentheses(row[2]))
    artist = soft_clean_text(row[3])
    if clique_id in shs100k_train_dict:
        shs100k_train_dict[clique_id][0].add(title)
        shs100k_train_dict[clique_id][1].add(artist)
    else:
        shs100k_train_dict[clique_id] = [{title}, {artist}]

# %%
dataset_path = os.path.join(dump_dir, 'dataset.json')
with open(dataset_path+'.test') as in_f:
    test_cliques = json.load(in_f)

# %%
shs_matched_clique_ids = set()
discogs_matched_shs_clique_ids = set()
for shs_clique_id, (shs_titles, shs_artists) in shs100k_train_dict.items():
    for shs_title in shs_titles:
        if shs_title in discogs_cliques:
            for discogs_clique in discogs_cliques[shs_title]:
                # Compare each SHS artist with the version artists of Discogs
                for shs_artist in shs_artists:
                    for discogs_title, discogs_artists in discogs_clique['versions']:
                        if shs_artist in discogs_artists:
                            # print(shs_title, shs_artist, discogs_artists)
                            shs_matched_clique_ids.add(discogs_clique['clique_id'])
                            discogs_matched_shs_clique_ids.add(shs_clique_id)
                #             break
                # break
print(f'{len(shs_matched_clique_ids)} SHS100K2 cliques are matched with Discogs cliques')
print(f'{len(discogs_matched_shs_clique_ids)} Discogs cliques are matched with SHS100K2 cliques')

# %%
len(shs_matched_clique_ids.intersection(set(test_cliques.keys()))) / len(test_cliques) * 100

# %%
val_intersect_versions = []
for clique_id in shs_matched_clique_ids.intersection(set(test_cliques.keys())):
    val_intersect_versions.append(len(test_cliques[clique_id]))

# %%
sum(val_intersect_versions)
